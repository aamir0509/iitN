# %% [markdown]
# #**Day 1**

# %% [markdown]
# **Lab 1**
#
# Ask user for his name and say hello. Also tell him how long his name is.
#
#
# *   Few functions needed:
#   *   print() - prints on screen
#   *   input() - reads one line of input
#   *   len(), str(), float(), int()
# *   Create a program in a file named hello.py

# %%
name=input("Enter the name:")
l=len(name)
print("My Name is {} and the length of my name is {}".format(name,l))
# Out:
# Enter the name:Akshay Singh
# My Name is Akshay Singh and the length of my name is 12

# %% [markdown]
# **Lab 2**
#
# * Write a program that asks user to enter ten words, one at a time and then it prints those words in sorted order
# * Write a program that prints the sum of all even numbers between 1 and 1000

# %%
name=[]
for i in range(1,11):
    n=input("Enter the Name:").title()
    name.append(n)
name.sort()
print(name)

# %%
sum=0
for i in range(1,1001):
    if i%2==0:
        sum=sum+i
    else:
        pass
print("The Sum of Even Numbers between 1 to 1000 is",sum)

# %% [markdown]
# **Lab 3**
#
# * Write a program that read a text file and prints the top 100 most used words
# * Hints
#   * To read a file:
#     * f = open(‘abc.txt’)
#     * text = f.read()
#   * To split text into words:
#     * words = text.split()
#   * To sort a list:
#     * sorted(list, key=func, reverse=True)

# %%
from collections import Counter
def word_count(fname):
        with open(fname) as f:
                return Counter(f.read().split())

print("Number of words in the file :",word_count("abc.txt"))
# Out:
# Number of words in the file : Counter({'the': 601, 'I': 571, 'and': 477, 'to': 452, 'a': 396, 'of': 371, 'my': 310, 'is': 303, 'in': 283, 'that': 265, 'you': 254, 'not': 238, 'me': 236, 'thou': 234, 'And': 229, 'with': 227, 'be': 196, 'it': 177, 'this': 171, 'for': 163, 'Rom': 163, 'O': 147, 'thy': 145, 'her': 137, 'will': 132, 'his': 129, 'thee': 128, 'as': 120, 'Jul': 117, 'have': 115, 'Nurse': 110, 'so': 110, 'love': 109, 'Romeo': 103, 'but': 100, 'What': 98, 'he': 97, 'shall': 94, 'your': 88, 'him': 87, 'she': 87, 'all': 84, 'But': 83, 'To': 81, 'from': 80, 'by': 79, 'Enter': 79, 'That': 77, 'Friar': 75, 'The': 73, 'do': 71, "I'll": 71, 'no': 71, 'on': 66, 'A': 64, 'Ben': 64, 'an': 63, 'at': 62, 'are': 62, 'what': 62, 'Mer': 62, 'good': 60, 'For': 60, 'night': 58, 'am': 57, 'our': 56, 'more': 56, 'if': 54, 'come': 54, 'man': 53, 'Cap': 53, 'hath': 53, 'would': 53, 'here': 51, 'then': 50, 'Juliet': 49, 'now': 49, 'art': 49, 'one': 49, 'My': 49, 'up': 48, 'Tybalt': 47, 'we': 47, 'd
# ...

# %% [markdown]
# Lab 4
#
# Implement accelerate and deaccelerate methods for the car class assume of fix rate of acceleration and deaccelerate make sure car doesn’t move backward when it deaccelerating.
# Simulate a race of 10 cars. All car starts at the same position and accelerates at a random rate between 1 and 5 m/ s2  for a period of between 5 to 10 seconds.

# %%
d=[100,100,100,100]
class car:
  def accelerate(self,d,i):
    d[i]=d-5
    

  def deaccelerate(self,d,i):
    d[i]=d+5


def car1():
  speed=random.randrange(1,3)
  if speed==1:
    a.accelerate(d[0],0)
  else:
    a.deaccelerate(d[0],0)
def car2():
  speed=random.randrange(1,3)
  if speed==1:
    a.accelerate(d[1],1)
  else:
    a.deaccelerate(d[1],1)
def car3():
  speed=random.randrange(1,3)
  if speed==1:
    a.accelerate(d[2],2)
  else:
    a.deaccelerate(d[2],2)
def car4():
  speed=random.randrange(1,3)
  if speed==1:
    a.accelerate(d[3],3)
  else:
    a.deaccelerate(d[3],3)
a=car()

while(True):
  car_num=random.randrange(1,5)
  if car_num==1:
    car1()
    if d[0]==0:
      print("Car1 is the Winner")
      break
  if car_num==2:
    car2()
    if d[1]==0:
      print("Car1 is the Winner")
      break
  if car_num==3:
    car3()
    if d[2]==0:
      print("Car1 is the Winner")
      break
  if car_num==4:
    car4()
    if d[1]==0:
      print("Car1 is the Winner")
      break
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-d0a894b98553> in <module>()
#      48       break
#      49   if car_num==3:
# ---> 50     car3()
#      51     if d[2]==0:
#      52       print("Car1 is the Winner")
#
# <ipython-input-18-d0a894b98553> in car3()
#      24   speed=random.randrange(1,3)
#      25   if speed==1:
# ---> 26     a.accelerate(d[2],2)
#      27   else:
#      28     a.deaccelerate(d[2],2)
#
# <ipython-input-18-d0a894b98553> in accelerate(self, d, i)
#       2 class car:
#       3   def accelerate(self,d,i):
# ----> 4     d[i]=d-5
#       5
#       6
#
# TypeError: 'int' object does not support item assignment

# %%
print(random.randrange(1,3))
# Out:
# 2
