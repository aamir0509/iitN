# %% [markdown]
# #**Day 1**

# %% [markdown]
# **Lab 1**
#
# Ask user for his name and say hello. Also tell him how long his name is.
#
#
# *   Few functions needed:
#   *   print() - prints on screen
#   *   input() - reads one line of input
#   *   len(), str(), float(), int()
# *   Create a program in a file named hello.py

# %%
x=input("What is ur name")
print("Hello"+x)
print(str(len(x)))
# Out:
# What is ur nameabc
# Helloabc

# %%
print(x)
len(x)
# Out:
# hello
# 5

# %% [markdown]
# Lab 1.5 Print table of 5

# %%
z=int(input('enter any number'))
i=1
while i<=10:
  j=i*5
  i=i+1
  print(j)
# Out:
# enter any number5
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# 50

# %% [markdown]
# **Lab 2**
#
# * Write a program that asks user to enter ten words, one at a time and then it prints those words in sorted order
# * Write a program that prints the sum of all even numbers between 1 and 1000

# %%
lst=[]
print("enter 10 words")
for x in range(0,10):
  str=input("enter your word")
  lst.append(str)
  x=x+1
lst.sort()
print(lst)
# Out:
# enter 10 words
# enter your worda
# enter your wordv
# enter your word
# enter your wordm
# enter your wordb
# enter your wordq
# enter your wordj
# enter your wordk
# enter your wordl
# enter your wordx
# ['', 'a', 'b', 'j', 'k', 'l', 'm', 'q', 'v', 'x']

# %%
sum=0
for i in range(1,1001):
  if i%2==0:
    sum=sum+i
print(sum)
# Out:
# 250500

# %% [markdown]
# **Lab 3**
#
# * Write a program that read a text file and prints the top 100 most used words
# * Hints
#   * To read a file:
#     * f = open(‘abc.txt’)
#     * text = f.read()
#   * To split text into words:
#     * words = text.split()
#   * To sort a list:
#     * sorted(list, key=func, reverse=True)

# %%
f=open('abc.txt','r')
text=f.read()
print(len(text))
words=text.split()
freq_chart={}
for word in words:
  curr_count= freq_chart.setdefault(word,0)
  freq_chart[word]=curr_count+1
aa=sorted(freq_chart.items(),key=lambda x: x[1],reverse=True)
print(aa[:100])
# Out:
# 132327
# [('the', 601), ('I', 571), ('and', 477), ('to', 452), ('a', 396), ('of', 371), ('my', 310), ('is', 303), ('in', 283), ('that', 265), ('you', 254), ('not', 238), ('me', 236), ('thou', 234), ('And', 229), ('with', 227), ('be', 196), ('it', 177), ('this', 171), ('for', 163), ('Rom', 163), ('O', 147), ('thy', 145), ('her', 137), ('will', 132), ('his', 129), ('thee', 128), ('as', 120), ('Jul', 117), ('have', 115), ('Nurse', 110), ('so', 110), ('love', 109), ('Romeo', 103), ('but', 100), ('What', 98), ('he', 97), ('shall', 94), ('your', 88), ('him', 87), ('she', 87), ('all', 84), ('But', 83), ('To', 81), ('from', 80), ('by', 79), ('Enter', 79), ('That', 77), ('Friar', 75), ('The', 73), ('do', 71), ("I'll", 71), ('no', 71), ('on', 66), ('A', 64), ('Ben', 64), ('an', 63), ('at', 62), ('are', 62), ('what', 62), ('Mer', 62), ('good', 60), ('For', 60), ('night', 58), ('am', 57), ('our', 56), ('more', 56), ('if', 54), ('come', 54), ('man', 53), ('Cap', 53), ('hath', 53), ('would', 53), ('here', 51), ('then', 50), ('Juliet', 49), ('now', 49), ('art', 49), ('one', 49), ('My', 49), ('up', 48), ('Tybalt', 47), ('we', 47), ('death', 47), ('their', 46), ('should', 46), ('out', 46), ('too', 46), ('say', 45), ('there', 44), ('they', 43), ('go', 43), ('was', 43), ('some', 43), ('fair', 42), ('or', 42), ('may', 42), ('them', 41), ('Thou', 41), ('This', 41)]

# %% [markdown]
# **Lab 4**
#
# * Implement accelerate and deaccelerate methods for the car class assume of fix rate of acceleration and deaccelerate make sure car doesn’t move backward when it deaccelerating.
# * Simulate a race of 10 cars. All car starts at the same position and accelerates at a random rate between 1 and 5 m/$s^2$ for a period of between 5 to 10 seconds.

# %%
class Car:
    def __init__(self, yearModel, make, speed):
        self.yearModel = yearModel
        self.make = make
        self.speed = speed
        
# Model accelerate and brake behaviors
    def accelerate(self,x):
        self.speed = self.speed + x
        if(self.speed > 25):
            self.speed = 25
 
    def brake(self,x):
        self.speed = self.speed - x
        if(self.speed < 0):
            self.speed = 0

# Access Data
    def get_type(self):
        print("Car")
        
# Define report status
    def status(self):
        print("The speed of the car is currently {} mph.".format(self.speed, end = ""))

# Have user enter model year and make
yearModel=input("What is the car's model year?\n")
make=input("What is the make of the car?\n")
speed=0
print('The car being tested is a {} from model year {}.'.format(make,yearModel))
myCar=Car(yearModel, make, 0)
myCar.status()
myCar.accelerate(5)
myCar.status()
myCar.accelerate(5)
myCar.status()
myCar.accelerate(5)
myCar.status()
myCar.accelerate(5)
myCar.status()
myCar.accelerate(5)
myCar.status()
myCar.brake(5)
myCar.status()
myCar.brake(5)
myCar.status()
myCar.brake(5)
myCar.status()
myCar.brake(5)
myCar.status()
myCar.brake(5)
myCar.status()
# Out:
# What is the car's model year?
# 2010
# What is the make of the car?
# abc
# The car being tested is a abc from model year 2010.
# The speed of the car is currently 0 mph.
# The speed of the car is currently 5 mph.
# The speed of the car is currently 10 mph.
# The speed of the car is currently 15 mph.
# The speed of the car is currently 20 mph.
# The speed of the car is currently 25 mph.
# The speed of the car is currently 20 mph.
# The speed of the car is currently 15 mph.
# The speed of the car is currently 10 mph.
# The speed of the car is currently 5 mph.
# The speed of the car is currently 0 mph.

# %%
    class Car:
      def __init__(self,year,make,color,speed):
        self.year = year
        self.make = make
        self.color = color
        self.speed = 0
        self.status = "stopped"
    
      def accelerate(self):
        self.speed +=5
        if (self.speed == 0) :
          self.status = "stopped"
        else:
          self.status = "Running"

      def deaccelerate(self):
        self.speed -=5
        if (self.speed == 0) :
          self.status = "stopped"
        else:
          self.status = "Running"
        
      def get_speed(self):
        return self.speed
   
    mycar = Car(2009,"Maruti","White",0 )
    print('The current status & speed is: ', mycar.status , mycar.get_speed())
    mycar.accelerate()
    print('The current status & speed is: ', mycar.status ,mycar.get_speed())
    mycar.accelerate()
    print('The current status & speed is: ', mycar.status ,mycar.get_speed())
    mycar.accelerate()
    print('The current status & speed is: ', mycar.status ,mycar.get_speed())
   
    mycar.deaccelerate()
    print('The current status & speed after deaccelerate is: ',mycar.status , mycar.get_speed())
    mycar.deaccelerate()
    print('The current status & speed after deaccelerate is: ',mycar.status , mycar.get_speed())
    mycar.deaccelerate()
    print('The current status & speed after deaccelerate is: ',mycar.status , mycar.get_speed())
# Out:
# The current status & speed is:  stopped 0
# The current status & speed is:  Running 5
# The current status & speed is:  Running 10
# The current status & speed is:  Running 15
# The current status & speed after deaccelerate is:  Running 10
# The current status & speed after deaccelerate is:  Running 5
# The current status & speed after deaccelerate is:  stopped 0

# %% [markdown]
# **Lab 5**
#
# Do object modeling for an application that manages a users personal library

# %%
class music_differentiator:
  def _init_(self, *music_file):
    self.music_file = music_file

  class music_differentiator:
    def _init_(self, *music_file):
     self.music_file = music_file

  def mp(self):
    mp3 = []
    mp4 = []
    for x in self.music_file:
       if x._contains_('.mp3') is True: 
          mp3.append(x)
       else:
          mp4.append(x)
    print('Mp3 music file', mp3)
    print('MP4 music file', mp4)

  ins = music_differentiator('mainepyaarkiya.mp3','kalikaliankhee.mp3','mainehoondon.mp4','hathighorapalki.mp3',True)
  ins.mp()
