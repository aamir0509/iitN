# %% [markdown]
# #**Day 1**

# %%
import requests
r = requests.get('http://www.iitk.ac.in/'')
print(r.header)
# Out:
#   File "<ipython-input-8-4620e55982a7>", line 2
#     r = requests.get('http://www.iitk.ac.in/'')
#                                                ^
# SyntaxError: EOL while scanning string literal

# %% [markdown]
# **Lab 1**
#
# Ask user for his name and say hello. Also tell him how long his name is.
#
#
# *   Few functions needed:
#   *   print() - prints on screen
#   *   input() - reads one line of input
#   *   len(), str(), float(), int()
# *   Create a program in a file named hello.py

# %%
import requests
import pprint
headers={'authorization':'token f2f5fbdcd1522e7ce63341dba7bf9115f08d53ca'}
json={}
r = requests.get('http://api.github.com/user/repos',headers=headers)
pprint.pprint(r.json())
# Out:
# [{'archive_url': 'https://api.github.com/repos/jayprakash24/IITK/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/jayprakash24/IITK/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/jayprakash24/IITK/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/jayprakash24/IITK/branches{/branch}',
#   'clone_url': 'https://github.com/jayprakash24/IITK.git',
#   'collaborators_url': 'https://api.github.com/repos/jayprakash24/IITK/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/jayprakash24/IITK/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/jayprakash24/IITK/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/jayprakash24/IITK/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/jayprakash24/IITK/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/jayprakash24/IITK/contributors',
#   'created_at': '2019-11-10T06:45:24Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/jayprakash24/IITK/deployments',
#   'description': None,
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/jayprakash24/IITK/downloads',
#   'events_url': 'https://api.github.com/repos/jayprakash24/IITK/events',
#   'fork': True,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/jayprakash24/IITK/forks',
#   'full_name': 'jayprakash24/IITK',
#   'git_commits_url': 'https://api.github.com/repos/jayprakash24/IITK/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/jayprakash24/IITK/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/jayprakash24/IITK/git/tags{/sha}',
#   'git_url': 'git://github.com/jayprakash24/IITK.git',
#   'has_downloads': True,
#   'has_issues': False,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/jayprakash24/IITK/hooks',
#   'html_url': 'https://github.com/jayprakash24/IITK',
#   'id': 220752398,
#   'issue_comment_url': 'https://api.github.com/repos/jayprakash24/IITK/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/jayprakash24/IITK/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/jayprakash24/IITK/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/jayprakash24/IITK/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/jayprakash24/IITK/labels{/name}',
#   'language': None,
#   'languages_url': 'https://api.github.com/repos/jayprakash24/IITK/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/jayprakash24/IITK/merges',
#   'milestones_url': 'https://api.github.com/repos/jayprakash24/IITK/milestones{/number}',
#   'mirror_url': None,
#   'name': 'IITK',
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyMjA3NTIzOTg=',
#   'notifications_url': 'https://api.github.com/repos/jayprakash24/IITK/notifications{?since,all,participating}',
#   'open_issues': 0,
#   'open_issues_count': 0,
#   'owner': {'avatar_url': 'https://avatars3.githubusercontent.com/u/57561920?v=4',
#             'events_url': 'https://api.github.com/users/jayprakash24/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/jayprakash24/followers',
#             'following_url': 'https://api.github.com/users/jayprakash24/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/jayprakash24/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/jayprakash24',
#             'id': 57561920,
#             'login': 'jayprakash24',
#             'node_id': 'MDQ6VXNlcjU3NTYxOTIw',
#             'organizations_url': 'https://api.github.com/users/jayprakash24/orgs',
#             'received_events_url': 'https://api.github.com/users/jayprakash24/received_events',
#             'repos_url': 'https://api.github.com/users/jayprakash24/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/jayprakash24/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/jayprakash24/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/jayprakash24'},
#   'permissions': {'admin': True, 'pull': True, 'push': True},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/jayprakash24/IITK/pulls{/number}',
#   'pushed_at': '2019-11-10T06:46:03Z',
#   'releases_url': 'https://api.github.com/repos/jayprakash24/IITK/releases{/id}',
#   'size': 0,
#   'ssh_url': 'git@github.com:jayprakash24/IITK.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/jayprakash24/IITK/stargazers',
#   'statuses_url': 'https://api.github.com/repos/jayprakash24/IITK/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/jayprakash24/IITK/subscribers',
#   'subscription_url': 'https://api.github.com/repos/jayprakash24/IITK/subscription',
#   'svn_url': 'https://github.com/jayprakash24/IITK',
#   'tags_url': 'https://api.github.com/repos/jayprakash24/IITK/tags',
#   'teams_url': 'https://api.github.com/repos/jayprakash24/IITK/teams',
#   'trees_url': 'https://api.github.com/repos/jayprakash24/IITK/git/trees{/sha}',
#   'updated_at': '2019-11-10T06:45:26Z',
#   'url': 'https://api.github.com/repos/jayprakash24/IITK',
#   'watchers': 0,
#   'watchers_count': 0},
#  {'archive_url': 'https://api.github.com/repos/jayprakash24/jayprakash24/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/jayprakash24/jayprakash24/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/jayprakash24/jayprakash24/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/jayprakash24/jayprakash24/branches{/branch}',
#   'clone_url': 'https://github.com/jayprakash24/jayprakash24.git',
#   'collaborators_url': 'https://api.github.com/repos/jayprakash24/jayprakash24/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/jayprakash24/jayprakash24/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/jayprakash24/jayprakash24/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/jayprakash24/jayprakash24/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/jayprakash24/jayprakash24/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/jayprakash24/jayprakash24/contributors',
#   'created_at': '2019-11-09T12:06:48Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/jayprakash24/jayprakash24/deployments',
#   'description': None,
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/jayprakash24/jayprakash24/downloads',
#   'events_url': 'https://api.github.com/repos/jayprakash24/jayprakash24/events',
#   'fork': False,
#   'forks': 1,
#   'forks_count': 1,
#   'forks_url': 'https://api.github.com/repos/jayprakash24/jayprakash24/forks',
#   'full_name': 'jayprakash24/jayprakash24',
#   'git_commits_url': 'https://api.github.com/repos/jayprakash24/jayprakash24/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/jayprakash24/jayprakash24/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/jayprakash24/jayprakash24/git/tags{/sha}',
#   'git_url': 'git://github.com/jayprakash24/jayprakash24.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/jayprakash24/jayprakash24/hooks',
#   'html_url': 'https://github.com/jayprakash24/jayprakash24',
#   'id': 220636536,
#   'issue_comment_url': 'https://api.github.com/repos/jayprakash24/jayprakash24/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/jayprakash24/jayprakash24/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/jayprakash24/jayprakash24/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/jayprakash24/jayprakash24/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/jayprakash24/jayprakash24/labels{/name}',
#   'language': 'HTML',
#   'languages_url': 'https://api.github.com/repos/jayprakash24/jayprakash24/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/jayprakash24/jayprakash24/merges',
#   'milestones_url': 'https://api.github.com/repos/jayprakash24/jayprakash24/milestones{/number}',
#   'mirror_url': None,
#   'name': 'jayprakash24',
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyMjA2MzY1MzY=',
#   'notifications_url': 'https://api.github.com/repos/jayprakash24/jayprakash24/notifications{?since,all,participating}',
#   'open_issues': 0,
#   'open_issues_count': 0,
#   'owner': {'avatar_url': 'https://avatars3.githubusercontent.com/u/57561920?v=4',
#             'events_url': 'https://api.github.com/users/jayprakash24/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/jayprakash24/followers',
#             'following_url': 'https://api.github.com/users/jayprakash24/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/jayprakash24/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/jayprakash24',
#             'id': 57561920,
#             'login': 'jayprakash24',
#             'node_id': 'MDQ6VXNlcjU3NTYxOTIw',
#             'organizations_url': 'https://api.github.com/users/jayprakash24/orgs',
#             'received_events_url': 'https://api.github.com/users/jayprakash24/received_events',
#             'repos_url': 'https://api.github.com/users/jayprakash24/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/jayprakash24/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/jayprakash24/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/jayprakash24'},
#   'permissions': {'admin': True, 'pull': True, 'push': True},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/jayprakash24/jayprakash24/pulls{/number}',
#   'pushed_at': '2019-11-10T06:13:40Z',
#   'releases_url': 'https://api.github.com/repos/jayprakash24/jayprakash24/releases{/id}',
#   'size': 0,
#   'ssh_url': 'git@github.com:jayprakash24/jayprakash24.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/jayprakash24/jayprakash24/stargazers',
#   'statuses_url': 'https://api.github.com/repos/jayprakash24/jayprakash24/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/jayprakash24/jayprakash24/subscribers',
#   'subscription_url': 'https://api.github.com/repos/jayprakash24/jayprakash24/subscription',
#   'svn_url': 'https://github.com/jayprakash24/jayprakash24',
#   'tags_url': 'https://api.github.com/repos/jayprakash24/jayprakash24/tags',
#   'teams_url': 'https://api.github.com/repos/jayprakash24/jayprakash24/teams',
#   'trees_url': 'https://api.github.com/repos/jayprakash24/jayprakash24/git/trees{/sha}',
#   'updated_at': '2019-11-10T06:13:41Z',
#   'url': 'https://api.github.com/repos/jayprakash24/jayprakash24',
#   'watchers': 0,
#   'watchers_count': 0}]

# %%
print("Hello world")

# %% [markdown]
# **Lab 2**
#
# * Write a program that asks user to enter ten words, one at a time and then it prints those words in sorted order
# * Write a program that prints the sum of all even numbers between 1 and 1000

# %% [markdown]
# **Lab 3**
#
# * Write a program that read a text file and prints the top 100 most used words
# * Hints
#   * To read a file:
#     * f = open(‘abc.txt’)
#     * text = f.read()
#   * To split text into words:
#     * words = text.split()
#   * To sort a list:
#     * sorted(list, key=func, reverse=True)

# %%
count = 0;  
word = "";  
maxCount = 0;  
words = [];  
   
#Opens a file in read mode  
file = open("abc.txt", "r")  
      
#Gets each line till end of file is reached  
for line in file:  
    #Splits each line into words  
    string = line.lower().replace(',','').replace('.','').split(" ");  
    #Adding all words generated in previous step into words  
    for s in string:  
        words.append(s);  
   
#Determine the most repeated word in a file  
for i in range(0, len(words)):  
    count = 1;  
    #Count each word in the file and store it in variable count  
    for j in range(i+1, len(words)):  
        if(words[i] == words[j]):  
            count = count + 1;  
              
    #If maxCount is less than count then store value of count in maxCount  
    #and corresponding word to variable word  
    if(count > maxCount):  
        maxCount = count;  
        word = words[i];  
          
print("Most repeated word: " + word);  
file.close();

# %%
count = 0;  
word = "";  
maxCount = 0;  
words = [];  
   
#Opens a file in read mode  
file = open("abc.txt", "r")  
      
#Gets each line till end of file is reached  
for line in file:  
    #Splits each line into words  
    string = line.lower().replace(',','').replace('.','').split(" ");  
    #Adding all words generated in previous step into words  
    for s in string:  
        words.append(s);  
   
#Determine the most repeated word in a file  
for i in range(0, len(words)):  
    count = 1;  
    #Count each word in the file and store it in variable count  
    for j in range(i+1, len(words)):  
        if(words[i] == words[j]):  
            count = count + 1;  
              
    #If maxCount is less than count then store value of count in maxCount  
    #and corresponding word to variable word  
    if(count > maxCount):  
        maxCount = count;  
        word = words[i];  
          
print("Most repeated word: " + word);  
file.close();

# %%
f=open('abc.txt')
text=f.read()

# %%
f.open()'abc.txt,r
txt=f.read()
words=txt.split()
freq_chart={}
for words in words 
curr_count=freq_chart.setdefault(word,0)
freq_chart[word]=curr_count+1
sorted(freq_chart)

# %% [markdown]
# **Lab 4**
#
# * Implement accelerate and deaccelerate methods for the car class assume of fix rate of acceleration and deaccelerate make sure car doesn’t move backward when it deaccelerating.
# * Simulate a race of 10 cars. All car starts at the same position and accelerates at a random rate between 1 and 5 m/$s^2$ for a period of between 5 to 10 seconds.

# %% [markdown]
# **Lab 5**
#
# Do object modeling for an application that manages a users personal library
