# %% [markdown]
# #**Day 1**

# %% [markdown]
# **Lab 1**
#
# Ask user for his name and say hello. Also tell him how long his name is.
#
#
# *   Few functions needed:
#   *   print() - prints on screen
#   *   input() - reads one line of input
#   *   len(), str(), float(), int()
# *   Create a program in a file named hello.py

# %%
x = input(" Enter your name ")
print("Hello "+x)
print("length of your name is " + str(len(x)))
# Out:
#  Enter your name Kamlesh Deshmukh
# Hello Kamlesh Deshmukh
# length of your name is 16

# %% [markdown]
# Lab 1.5

# %%
x = int(input("Enter any number"))
i=1
while i<=10:
  j=x*i 
  print(x , " * " , i , " = " , j)
  i=i+1
# Out:
# Enter any number5
# 5  *  1  =  5
# 5  *  2  =  10
# 5  *  3  =  15
# 5  *  4  =  20
# 5  *  5  =  25
# 5  *  6  =  30
# 5  *  7  =  35
# 5  *  8  =  40
# 5  *  9  =  45
# 5  *  10  =  50

# %% [markdown]
# ### **Lab 2**
#
# * Write a program that asks user to enter ten words, one at a time and then it prints those words in sorted order
# * Write a program that prints the sum of all even numbers between 1 and 1000

# %%
words = []
print("Enter 10 words")
for x in range(0,10) :
  str = input("Enter your word ")
  words.append(str)
  x=x+1
print(words)
words.sort()
print("List after sorting")
print(words)
# Out:
# Enter 10 words
# Enter your word ramesh
# Enter your word rahul
# Enter your word alpana
# Enter your word kamlesh
# Enter your word santosh
# Enter your word manisha
# Enter your word chaman
# Enter your word tarun
# Enter your word komal
# Enter your word paridhi
# ['ramesh', 'rahul', 'alpana', 'kamlesh', 'santosh', 'manisha', 'chaman', 'tarun', 'komal', 'paridhi']
# List after sorting
# ['alpana', 'chaman', 'kamlesh', 'komal', 'manisha', 'paridhi', 'rahul', 'ramesh', 'santosh', 'tarun']

# %%
i=1
sum=0
for i in range(1,1001):
  if i%2==0:
    sum = sum+i
print(sum)
# Out:
# 250500

# %% [markdown]
# **Lab 3**
#
# * Write a program that read a text file and prints the top 100 most used words
# * Hints
#   * To read a file:
#     * f = open(‘abc.txt’)
#     * text = f.read()
#   * To split text into words:
#     * words = text.split()
#   * To sort a list:
#     * sorted(list, key=func, reverse=True)

# %%
f=open('abc.txt','r')
text=f.read()
words=text.split()
freq_chart = { }
for word in words:
  curr_count=freq_chart.setdefault(word,0)
  freq_chart[word]=curr_count+1
most_used=sorted(freq_chart.items(),key=lambda x:x[1],reverse=True)
print(most_used[:100])
# Out:
# [('the', 601), ('I', 571), ('and', 477), ('to', 452), ('a', 396), ('of', 371), ('my', 310), ('is', 303), ('in', 283), ('that', 265), ('you', 254), ('not', 238), ('me', 236), ('thou', 234), ('And', 229), ('with', 227), ('be', 196), ('it', 177), ('this', 171), ('for', 163), ('Rom', 163), ('O', 147), ('thy', 145), ('her', 137), ('will', 132), ('his', 129), ('thee', 128), ('as', 120), ('Jul', 117), ('have', 115), ('Nurse', 110), ('so', 110), ('love', 109), ('Romeo', 103), ('but', 100), ('What', 98), ('he', 97), ('shall', 94), ('your', 88), ('him', 87), ('she', 87), ('all', 84), ('But', 83), ('To', 81), ('from', 80), ('by', 79), ('Enter', 79), ('That', 77), ('Friar', 75), ('The', 73), ('do', 71), ("I'll", 71), ('no', 71), ('on', 66), ('A', 64), ('Ben', 64), ('an', 63), ('at', 62), ('are', 62), ('what', 62), ('Mer', 62), ('good', 60), ('For', 60), ('night', 58), ('am', 57), ('our', 56), ('more', 56), ('if', 54), ('come', 54), ('man', 53), ('Cap', 53), ('hath', 53), ('would', 53), ('here', 51), ('then', 50), ('Juliet', 49), ('now', 49), ('art', 49), ('one', 49), ('My', 49), ('up', 48), ('Tybalt', 47), ('we', 47), ('death', 47), ('their', 46), ('should', 46), ('out', 46), ('too', 46), ('say', 45), ('there', 44), ('they', 43), ('go', 43), ('was', 43), ('some', 43), ('fair', 42), ('or', 42), ('may', 42), ('them', 41), ('Thou', 41), ('This', 41)]

# %% [markdown]
# **Lab 4**
#
# * Implement accelerate and deaccelerate methods for the car class assume of fix rate of acceleration and deaccelerate make sure car doesn’t move backward when it deaccelerating.
# * Simulate a race of 10 cars. All car starts at the same position and accelerates at a random rate between 1 and 5 m/$s^2$ for a period of between 5 to 10 seconds.

# %%
    class Car:
      def __init__(self,year,make,color,speed):
        self.year = year
        self.make = make
        self.color = color
        self.speed = 0
        self.status = "stopped"
    
      def accelerate(self):
        self.speed +=5
        if (self.speed == 0) :
          self.status = "stopped"
        else:
          self.status = "Running"

      def deaccelerate(self):
        self.speed -=5
        if (self.speed == 0) :
          self.status = "stopped"
        else:
          self.status = "Running"
        
      def get_speed(self):
        return self.speed
   
    mycar = Car(2009,"Maruti","White",0 )
    
    print('The current status & speed is: ', mycar.status , mycar.get_speed())
    mycar.accelerate()
    print('The current status & speed is: ', mycar.status ,mycar.get_speed())
    mycar.accelerate()
    print('The current status & speed is: ', mycar.status ,mycar.get_speed())
    mycar.accelerate()
    print('The current status & speed is: ', mycar.status ,mycar.get_speed())
   
    mycar.deaccelerate()
    print('The current status & speed after deaccelerate is: ',mycar.status , mycar.get_speed())
    mycar.deaccelerate()
    print('The current status & speed after deaccelerate is: ',mycar.status , mycar.get_speed())
    mycar.deaccelerate()
    print('The current status & speed after deaccelerate is: ',mycar.status , mycar.get_speed())
# Out:
# The current status & speed is:  stopped 0
# The current status & speed is:  Running 5
# The current status & speed is:  Running 10
# The current status & speed is:  Running 15
# The current status & speed after deaccelerate is:  Running 10
# The current status & speed after deaccelerate is:  Running 5
# The current status & speed after deaccelerate is:  stopped 0

# %%
import random
class Car:
  def __init__(self,make,model,year,color):
    self.make=make
    self.model=model
    self.year=year
    self.color=color
    self.position=0
    self.speed=0
    self.fuellevel=100
    self.state="stopped"
  def start(self):
    self.state="started"
  def accelerate(self,rate,time):
    if self.state in ["started","running"]:
      self.speed=self.speed+rate*time
      self.position=self.position+(rate*time*time/2.0)
    else:
      pass
  def deacelerate(self,rate,time):
    self.speed=self.speed-rate*time
    self.position=self.position+(self.speed*time - (rate*time*time/2.0))
carmake=["Maruti","Tata","Hyundai","Compass","BMW","Nissan","Kia","Mahindra","Toytota","Ford"]
carmodel=["Swift","Nexon","Creta","Verna","Jeep","370","Micra","X11","KUV 500","Camry","Mustang"]
caryear=[1996,1997,1998,1999,2000,2001,2002,2003,2004,2005]
carcolor=["White","Silver","Blue","Black","Grey","Green","Yellow","Red","White","Brown"]
carlist = []  
  
# appending instances to list  
carlist.append(Car(carmake[0],carmodel[0],caryear[0],carcolor[0]))
carlist.append(Car(carmake[1],carmodel[1],caryear[1],carcolor[1]) ) 
carlist.append( Car(carmake[2],carmodel[2],caryear[2],carcolor[2]))
carlist.append(Car(carmake[3],carmodel[3],caryear[3],carcolor[3]))
carlist.append(Car(carmake[4],carmodel[4],caryear[4],carcolor[4]) ) 
carlist.append( Car(carmake[5],carmodel[5],caryear[5],carcolor[5]))
carlist.append(Car(carmake[6],carmodel[6],caryear[6],carcolor[6]))
carlist.append(Car(carmake[7],carmodel[7],caryear[7],carcolor[7]) ) 
carlist.append( Car(carmake[8],carmodel[8],caryear[8],carcolor[8]))
carlist.append(Car(carmake[9],carmodel[9],caryear[9],carcolor[9]) ) 
print("Let the Race begin....")
counter=0  
a=[] #list() #random acceleration
for i in range(10):
    a.append(1+random.random()*4)
ta=[] #list() #random time for acceleration
for i in range(10):
    ta.append(5+random.random()*5)
for obj in carlist: 
    carlist[counter].start() #( obj.name, obj.roll, sep =' ' )
    carlist[counter].accelerate(a[counter],ta[counter])
    counter=counter+1
counter=0
i=0
maxposition=carlist[0].position
for obj in carlist:
    if carlist[counter].position > maxposition:
        i=counter
        maxposition=carlist[counter].position
    counter=counter+1
print("The car that wins is %s %s" %(carlist[i].make,carlist[i].model))
# Out:
# Let the Race begin....
# The car that wins is Toytota KUV 500

# %% [markdown]
# **Lab 5**
#
# Do object modeling for an application that manages a users personal library

# %%
class music_differentiator:
  def _init_(self, *music_file):
    self.music_file = music_file

  def mp(self):
    mp3 = []
    mp4 = []
    for x in self.music_file:
       if x._contains_('.mp3') is True: 
          mp3.append(x)
       else:
          mp4.append(x)
    print('Mp3 music file', mp3)
    print('MP4 music file', mp4)

ins = music_differentiator('mainepyaarkiya.mp3','kalikaliankhee.mp3','mainehoondon.mp4','hathighorapalki.mp3')
ins.mp()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-80ce78903ded> in <module>()
#      14     print('MP4 music file', mp4)
#      15
# ---> 16 ins = music_differentiator('mainepyaarkiya.mp3','kalikaliankhee.mp3','mainehoondon.mp4','hathighorapalki.mp3')
#      17 ins.mp()
#
# TypeError: object() takes no parameters
