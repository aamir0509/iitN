# %% [markdown]
# #**Day 1**

# %%
'Alice' + 'Bob'
# Out:
# 'AliceBob'

# %%
fileread = open('abc.txt','r')
text = fileread.read()
words = text.split()
lst1=[]
for i in words:
      if (words.count(i),i) not in lst1:
         lst1.append((words.count(i),i))
lst1.sort()
for i in range(100):
    print(lst1[i])
# Out:
# (1, '"Where')
# (1, "'An")
# (1, "'Ay")
# (1, "'Ay';")
# (1, "'By")
# (1, "'For")
# (1, "'God")
# (1, "'Hold")
# (1, "'I'll")
# (1, "'It")
# (1, "'My")
# (1, "'Paris';")
# (1, "'Proud'-")
# (1, "'Romeo'")
# (1, "'Signior")
# (1, "'Then")
# (1, "'To")
# (1, "'Twas")
# (1, "'Twixt")
# (1, "'Twould")
# (1, "'Tybalt")
# (1, "'Tybalt's")
# (1, "'When")
# (1, "'Wilt")
# (1, "'Your")
# (1, "'a?")
# (1, "'better'")
# (1, "'broad'")
# (1, "'death';")
# (1, "'dost")
# (1, "'dove';")
# (1, "'fall'st")
# (1, "'gainst")
# (1, "'gallops")
# (1, "'love'")
# (1, "'marry'")
# (1, "'no'")
# (1, "'not")
# (1, "'promis'd")
# (1, "'the")
# (1, "'twere")
# (1, "'twill")
# (1, "'twixt")
# (1, "'villain'")
# (1, '(Being')
# (1, '(I')
# (1, '(O')
# (1, '(Strange')
# (1, '(exquisite)')
# (1, '(mark')
# (1, '(marry')
# (1, '(rises)')
# (1, '(so')
# (1, '(with')
# (1, '-the')
# (1, 'AND')
# (1, 'Abate')
# (1, 'Above')
# (1, 'Abram')
# (1, "Accurs'd")
# (1, 'Acquaint')
# (1, 'Adam')
# (1, 'Adding')
# (1, 'Adieu')
# (1, "Adversity's")
# (1, 'Affection')
# (1, 'Affliction')
# (1, 'Afore')
# (1, 'After')
# (1, 'Against')
# (1, 'Alike')
# (1, 'Alive')
# (1, 'Alla')
# (1, 'Although')
# (1, 'Amen')
# (1, 'Amen!')
# (1, 'Ancient')
# (1, 'Angelica;')
# (1, 'Anselmo')
# (1, 'Anthony')
# (1, 'Any')
# (1, 'Appear')
# (1, 'April')
# (1, 'Arise')
# (1, 'Arise;')
# (1, 'Arms')
# (1, 'Ascend')
# (1, 'Ask')
# (1, 'Athwart')
# (1, 'Attendants')
# (1, 'Attendants]')
# (1, "Aurora's")
# (1, 'Back')
# (1, 'Balthasar?')
# (1, 'Balthasar]')
# (1, "Banish'd")
# (1, 'Bear')
# (1, 'Bearing')
# (1, 'Beautiful')
# (1, 'Beauty')

# %%
x= input("whats your name")
print(x)
lenofname = len(x)
print (lenofname)
# Out:
# whats your namemahish
# mahish
# 6

# %%
x =input("whats your name")
print(x)
lenOfName = len(x)
print("length of the name is ",lenOfName)
y =len(x)
print(y)
# Out:
# whats your nameerrte
# errte
# length of the name is  5
# 5

# %%
x= 25
if x > 0:
  print("no is positive")
  y = 9;
  if y%5 ==0:
    print("number is divisible by 5")
  else 
    print("not divvisble")
# Out:
#   File "<ipython-input-29-fddcfbc5b987>", line 8
#     else
#          ^
# SyntaxError: invalid syntax

# %%
2+3*5 -8 /4
# Out:
# 15.0

# %% [markdown]
# **Lab 1**
#
# Ask user for his name and say hello. Also tell him how long his name is.
#
#
# *   Few functions needed:
#   *   print() - prints on screen
#   *   input() - reads one line of input
#   *   len(), str(), float(), int()
# *   Create a program in a file named hello.py

# %% [markdown]
# Lab 1.5
#
# Write program for printing table of  a given number

# %%
i=1;
number = int(input("enter table number to be generated"))
while (i<=10):
      print (number,"X",i,"=",(number*i))
      i=i+1;
# Out:
# enter table number to be generated2
# 2 X 1 = 2
# 2 X 2 = 4
# 2 X 3 = 6
# 2 X 4 = 8
# 2 X 5 = 10
# 2 X 6 = 12
# 2 X 7 = 14
# 2 X 8 = 16
# 2 X 9 = 18
# 2 X 10 = 20

# %%
i = 0
sum =0
while(i <=1000):
  if (i%2 == 0):
    sum = sum + i
  i = i + 1
print (sum)
# Out:
# 250500

# %%
maximum = int(input(" Please Enter the Maximum Value : "))
total = 0

for number in range(1, maximum+1):
    if(number % 2 == 0):
        print("{0}".format(number))
        total = total + number

print("The Sum of Even Numbers from 1 to {0} = {1}".format(number, total))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     729             try:
# --> 730                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     731             except Exception:
#
# /usr/local/lib/python3.6/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.6/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     465         """
# --> 466         parts = [self.recv(flags, copy=copy, track=track)]
#     467         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.6/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-79-d7dd44c2959b> in <module>()
# ----> 1 maximum = int(input(" Please Enter the Maximum Value : "))
#       2 total = 0
#       3
#       4 for number in range(1, maximum+1):
#       5     if(number % 2 == 0):
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     703             self._parent_ident,
#     704             self._parent_header,
# --> 705             password=False,
#     706         )
#     707
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     733             except KeyboardInterrupt:
#     734                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 735                 raise KeyboardInterrupt
#     736             else:
#     737                 break
#
# KeyboardInterrupt:

# %%
x

# %%
l=[]
for i in range(30):
    l.append(input("enter word"))
l.sort()
gg

print(l)
# Out:
# enter wordqqqq
# enter wordrrr
# enter wordwww
# enter worduuu
# enter wordtt
# enter wordrrr
# enter wordpp
# enter wordoo
# enter wordss
# enter wordaa
# enter wordbb
# enter wordc
# enter wordc
# enter worde
# enter wordm
# enter wordj
# enter wordl
# enter word
# enter worddd
# enter wordhh
# enter wordgg
# enter wordnn
# enter wordcc
# enter wordff
# enter wordww
# enter wordvv
# enter wordx
# enter wordzz
# enter wordtt
# enter wordnn
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-92-723c30587c01> in <module>()
#       3 for i in range(30):
#       4     l.append(input("enter word"))
# ----> 5 l.sort(reverse = true)
#       6 print(l)
#
# NameError: name 'true' is not defined

# %%
x =[1,2,3,4]
x = x+[5]

5 in x
x.append(6)
print (x)
x.sort
print(x)

# %%
car = {'maek':'maruti','model':'swift', 'yearr':2009}
for k,v in car.items():
  print(k,":",v)
# Out:
# maek : maruti
# model : swift
# yearr : 2009

# %%
for k incar:
  print()

# %% [markdown]
# **Lab 2**
#
# * Write a program that asks user to enter ten words, one at a time and then it prints those words in sorted order
# * Write a program that prints the sum of all even numbers between 1 and 1000

# %%
def mysum(a,b,c):
  return a+b+c
  z=[1,2,3]
  print(mysum(*z))
  y={'a':1,'b':2,'c':3}
  print(mysum(**y))

# %% [markdown]
# **Lab 3**
#
# * Write a program that read a text file and prints the top 100 most used words
# * Hints
#   * To read a file:
#     * f = open(‘abc.txt’)
#     * text = f.read()
#   * To split text into words:
#     * words = text.split()
#   * To sort a list:
#     * sorted(list, key=func, reverse=True)

# %%
f = open('abc.txt')
text = f.read()
words =text.split()
length = len(words)
print(length)
# Out:
# 25788

# %%
f = open('abc.txt')
text = f.read()
words =text.split()
length = len(words)
print(length)
# Out:
# 25788

# %%
def mysum(a, *args, **kwargs):
  print(kwargs)
  sum = 0
  for x in args:
    sum = sum + x
  return sum
  print(mysum(1,2,a=3))
#print(mysum(a=1,2,3,4,5,6))

# %%
def spam():
  eggs = 31337
spam()
print(eggs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-120-e32925274696> in <module>()
#       2   eggs =31337
#       3 spam()
# ----> 4 print(eggs)
#
# NameError: name 'eggs' is not defined

# %%
def spam():
    print(eggs)
  eggs = 42
spam()
print(eggs)
# Out:
#   File "<ipython-input-121-ca90ac8a66d0>", line 3
#     eggs = 42
#              ^
# IndentationError: unindent does not match any outer indentation level

# %%
def spam():
    global eggs
    eggs = 'spam'
eggs = 'global'
spam()
print(eggs)
# Out:
# spam

# %%
f = open('abc.txt')
text = f.read()
words =text.split()
length = len(words)
print(length)
# Out:
# 25788

# %% [markdown]
# **Lab 4**
#
# * Implement accelerate and deaccelerate methods for the car class assume of fix rate of acceleration and deaccelerate make sure car doesn’t move backward when it deaccelerating.
# * Simulate a race of 10 cars. All car starts at the same position and accelerates at a random rate between 1 and 5 m/$s^2$ for a period of between 5 to 10 seconds.

# %% [markdown]
# **Lab 5**
#
# Do object modeling for an application that manages a users personal library
