# %% [markdown]
# #**Day 1**

# %% [markdown]
# **Lab 1**
#
# Ask user for his name and say hello. Also tell him how long his name is.
#
#
# *   Few functions needed:
#   *   print() - prints on screen
#   *   input() - reads one line of input
#   *   len(), str(), float(), int()
# *   Create a program in a file named hello.py

# %%
print("Hello World")
# Out:
# Hello World

# %%
a = 10
b = 20
c = a + b
print(c)
# Out:
# 30

# %%
5%3
# This will give the remainder valaue.
# Out:
# 2

# %%
2 + 3 * 5 - 8 / 4
# Following same mathematical principles.
# Out:
# 15.0

# %%
'Alice' + 'Bob'
# "Check 'Alice' + 5".
# Out:
# 'AliceBob'

# %%
a = 5>3 and 4>5
print(a)
# Out:
# False

# %%
x = input("What is your name ")
print("Hello! " + x + ", Length of your name is " + str(len(x)))
# Out:
# What is your name Rishendra
# Hello! Rishendra, Length of your name is 9

# %%
name = input("Waht is your name ")
if len(name)> 8:
  print("Your name is " + name)
else:
  print("Hello! Shorty")
# Out:
# Waht is your name Rishendra
# Your name is Rishendra

# %%
while True:
  print('Who are you?')
  name = raw_input()
  if name != 'Radha':
    continue

# %%
num = int(input("What is your number "))
i = 1
while i<=10:
  print(num, "x", i, '=', (num*i))
  i = i + 1
# Out:
# What is your number 5
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %%
# Program the same function using for loop.
for i in range(1,11):

# %% [markdown]
# **Lab 2**
#
# * Write a program that asks user to enter ten words, one at a time and then it prints those words in sorted order
# * Write a program that prints the sum of all even numbers between 1 and 1000

# %%
l=[]
for i in range(10):
  l.append(input("word"))
l.sort()
print(l)

# %%
i = int(input("What is your number "))
sum=0
for i in range(1,1001):
  if i%2 == 0:
    sum = sum + i
print(sum)
# Out:
# What is your number 1000
# 250500

# %% [markdown]
# **Lab 3**
#
# * Write a program that read a text file and prints the top 100 most used words
# * Hints
#   * To read a file:
#     * f = open(‘abc.txt’)
#     * text = f.read()
#   * To split text into words:
#     * words = text.split()
#   * To sort a list:
#     * sorted(list, key=func, reverse=True)

# %%
f =open('abc.txt', 'r')
txt=f.read()
print(len(txt))
words=txt.split()
freq_chart={}
for word in words:
  curr_count= freq_chart.setdefault(word,0)
  freq_chart[word]= curr_count+1
  aa=sorted(freq_chart.items(), key=lambda x:x[1] ,reverse=True)
  print(aa[:100])

# %%
f = open('abc.txt', 'r')
txt = f.read()
words = txt.split()
freq_chart = {}
for word in words:
  curr_count = freq_chart.setdefault(word,0)
  freq_chart[word] = curr_count + 1
sorted(freq_chart.item() ,key=lambda x:x [1] , reverse =True)

# %% [markdown]
# **Lab 4**
#
# * Implement accelerate and deaccelerate methods for the car class assume of fix rate of acceleration and deaccelerate make sure car doesn’t move backward when it deaccelerating.
# * Simulate a race of 10 cars. All car starts at the same position and accelerates at a random rate between 1 and 5 m/$s^2$ for a period of between 5 to 10 seconds.

# %%
class Car:
  def __init__(self,name,pos=0,speed=0):
    self.name=name
    self.pos=pos
    self.speed=speed
  def accelerate(self,a,t):
    self.pos=self.pos+self.speed*t+(0.5*a*t*t)
    self.spped=self.speed+a*t
  def deaccelerate(self,d,t):
    tzero=self.speed/d
    if t<tzero:
      self.pos=self.pos-self.speed*t-(0.5*a*t*t)
    else:
      self.pos=self.pos+self.speed*tzero-(0.5*d*tzero*tzero)
c1=Car('akki')
c2=Car('kaju')
c1.accelerate(5,10)
print(c1.pos)
c1.deaccelerate(5,10)
print(c1.pos)
# Out:
# 250.0
# 250.0

# %%
def main():
  # Create a car object
  car = Car("1970", "Mustang")
  # Calls the accelerate method
  print('Accelerating')

  for i in range(5):
    car.accelerate()
    print (car.get_speed())

  # Calls the brake method five times.
  print("Decelerating")

  for i in range(8):
    car.brake()
    print(car.get_speed())
    if car.get_speed()==0:
      break

# %% [markdown]
# **Lab 5**
#
# Do object modeling for an application that manages a users personal library

# %%
class car:
  def __init__(self, yearModel, make, speed):
    self.yearModel = yearModel
    self.make = make
    self.speed = speed

  # Model accelerate and brake behaviours
  def accelerate(self,x):
    self.speed = self.speed + x
    if(self.speed> 25):
      self.speed = 25

  def brake(self,x):
    self.speed = self.speed - x
    if(self.speed < 0):
      self.speed = 0

  # Define report status
  def status(self):
    print("The speed of the car is currently {} mph.".format(self.speed, end =""))

# Have user enter model year and make
yearModel=input ("Waht is the car's model year?\n")
make=input("what is the make of the car?\n")
speed=0
print('The car being tested is a {} from model year {}.'.format(make,yearModel))

# Speed report:
myCar=Car(yearModel, make, 0)
my.Car.status()
myCar.accelerate(5)
myCar.status()
myCar.accelerate(5)
myCar.status()
myCar.accelerate(5)
myCar.status()
myCar.accelerate(5)
myCar.status()
myCar.accelerate(5)
myCar.status()
myCar.brake(5)
myCar.status()
myCar.brake(5)
myCar.status()
myCar.brake(5)
myCar.status()
myCar.brake(5)
myCar.status()
myCar.brake(5)
myCar.status()
