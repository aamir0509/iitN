# %% [markdown]
# #**Day 1**

# %% [markdown]
# **Lab 1**
#
# Ask user for his name and say hello. Also tell him how long his name is.
#
#
# *   Few functions needed:
#   *   print() - prints on screen
#   *   input() - reads one line of input
#   *   len(), str(), float(), int()
# *   Create a program in a file named hello.py

# %%
names=input("Enter your name")
print("hello mr " + names + "your name length is :" + str(len(names)))
# Out:
# enter your name:trilok
# 6

# %% [markdown]
# Lab 1.5

# %%
i=1
while i<=10:
  print("5x",i,"=",(str(5*i)))
  i=i+1
# Out:
# 5x 1 = 5
# 5x 2 = 10
# 5x 3 = 15
# 5x 4 = 20
# 5x 5 = 25
# 5x 6 = 30
# 5x 7 = 35
# 5x 8 = 40
# 5x 9 = 45
# 5x 10 = 50

# %% [markdown]
# Lab 2

# %%
l=[]
for i in range(10):
  l.append(input("input words0"))
l.sort()
print(l)
# Out:
# input words0a
# input words0f
# input words0
# input words0v
# input words0g
# input words0t
# input words0y
# input words0
# input words0i
# input words0h
# ['', '', 'a', 'f', 'g', 'h', 'i', 't', 'v', 'y']

# %% [markdown]
# lab 2.5

# %%
i=2
sum=10000
while i<=:
  sum=sum+i
  i=i+2
print("sum of all even numbers between 1 and 1000 is: "+str(sum))
# Out:
# sum of all even numbers between 1 and 1000 is: 250500

# %% [markdown]
# **Lab 2**
#
# * Write a program that asks user to enter ten words, one at a time and then it prints those words in sorted order
# * Write a program that prints the sum of all even numbers between 1 and 1000

# %%
l=[]
for i in range(10):
  l.append(input("input words0"))
l.sort()
print(l)



i=2
sum=10000
while i<=:
  sum=sum+i
  i=i+2
print("sum of all even numbers between 1 and 1000 is: "+str(sum))
# Out:
# input words0a
# input words0f
# input words0
# input words0v
# input words0g
# input words0t
# input words0y
# input words0
# input words0i
# input words0h
# ['', '', 'a', 'f', 'g', 'h', 'i', 't', 'v', 'y']

# %% [markdown]
# **Lab 3**
#
# * Write a program that read a text file and prints the top 100 most used words
# * Hints
#   * To read a file:
#     * f = open(‘abc.txt’)
#     * text = f.read()
#   * To split text into words:
#     * words = text.split()
#   * To sort a list:
#     * sorted(list, key=func, reverse=True)

# %%
f=open('abc.txt','r')
text=f.read()
words=text.split()
l1=[]
for i in words:
  if(words.count(i),i) not in l1:
    l1.append((words.count(i),i))
l1.sort(reverse=True)
i=0
while i<=100:       
  print(l1[i])
  i=i+1
# Out:
# (601, 'the')
# (571, 'I')
# (477, 'and')
# (452, 'to')
# (396, 'a')
# (371, 'of')
# (310, 'my')
# (303, 'is')
# (283, 'in')
# (265, 'that')
# (254, 'you')
# (238, 'not')
# (236, 'me')
# (234, 'thou')
# (229, 'And')
# (227, 'with')
# (196, 'be')
# (177, 'it')
# (171, 'this')
# (163, 'for')
# (163, 'Rom')
# (147, 'O')
# (145, 'thy')
# (137, 'her')
# (132, 'will')
# (129, 'his')
# (128, 'thee')
# (120, 'as')
# (117, 'Jul')
# (115, 'have')
# (110, 'so')
# (110, 'Nurse')
# (109, 'love')
# (103, 'Romeo')
# (100, 'but')
# (98, 'What')
# (97, 'he')
# (94, 'shall')
# (88, 'your')
# (87, 'she')
# (87, 'him')
# (84, 'all')
# (83, 'But')
# (81, 'To')
# (80, 'from')
# (79, 'by')
# (79, 'Enter')
# (77, 'That')
# (75, 'Friar')
# (73, 'The')
# (71, 'no')
# (71, 'do')
# (71, "I'll")
# (66, 'on')
# (64, 'Ben')
# (64, 'A')
# (63, 'an')
# (62, 'what')
# (62, 'at')
# (62, 'are')
# (62, 'Mer')
# (60, 'good')
# (60, 'For')
# (58, 'night')
# (57, 'am')
# (56, 'our')
# (56, 'more')
# (54, 'if')
# (54, 'come')
# (53, 'would')
# (53, 'man')
# (53, 'hath')
# (53, 'Cap')
# (51, 'here')
# (50, 'then')
# (49, 'one')
# (49, 'now')
# (49, 'art')
# (49, 'My')
# (49, 'Juliet')
# (48, 'up')
# (47, 'we')
# (47, 'death')
# (47, 'Tybalt')
# (46, 'too')
# (46, 'their')
# (46, 'should')
# (46, 'out')
# (45, 'say')
# (44, 'there')
# (43, 'was')
# (43, 'they')
# (43, 'some')
# (43, 'go')
# (42, 'or')
# (42, 'may')
# (42, 'fair')
# (41, 'them')
# (41, 'such')
# (41, 'Thou')
# (41, 'This')

# %%
f=open('abc.txt','r')
text=f.read();
print(len(text))
# Out:
# 132327

# %% [markdown]
# **Lab 4**
#
# * Implement accelerate and deaccelerate methods for the car class assume of fix rate of acceleration and deaccelerate make sure car doesn’t move backward when it deaccelerating.
# * Simulate a race of 10 cars. All car starts at the same position and accelerates at a random rate between 1 and 5 m/$s^2$ for a period of between 5 to 10 seconds.

# %%
import random
class Car:
  def __init__(self,v=0):
    self.make=make
    self.model=model
    self.year=year
    self.color=color
    self.position=0
    self.speed=0
    self.fuelLevel=100
    self.state="stopped"
    self.speed=v

  def start(self):
    self.state="started"

  def accelerate(self,rate,time):
    if self.state in ["started","running"]:
      self.speed=self.speed+rate*time
      self.position=self.position+(rate*time*time/2.0)
      print("current speed of car after aacceleration is:",self.speed)
      else:

  def deaccelerate(self,rate,dt):
    self.speed=self-rate*dt
    print("current speed of car after deacceleration is:",self.speed)

c1=Car()
C1.aacceleration(random.randrange(1,6),random.randrange(5,11))

C2=Car()
C2.aacceleration(random.randrange(1,6),random.randrange(5,11))
# Out:
#   File "<ipython-input-20-c3710b3b7155>", line 22
#     else:
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# **Lab 5**
#
# Do object modeling for an application that manages a users personal library
