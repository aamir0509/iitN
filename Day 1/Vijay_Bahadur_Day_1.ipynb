# %% [markdown]
# #**Day 1**

# %%
class car:
   def_init_(self, name, pos=0, speed=0):
      self.name= name
      self.pos=pos
      self.speed=speed

      def accelerate(self, a, t):
         self.pos

# %% [markdown]
# **Lab 1**
#
# Ask user for his name and say hello. Also tell him how long his name is.
#
#
# *   Few functions needed:
#   *   print() - prints on screen
#   *   input() - reads one line of input
#   *   len(), str(), float(), int()
# *   Create a program in a file named hello.py

# %% [markdown]
# lab 1.5
# print table

# %%
z=int(input('Enter the number'))
i=1
while i<=10:
    print(str(z)+"x"+ str(i) + "=" + str(z*i))
    i = i+1
# Out:
# Enter the number9
# 9x1=9
# 9x2=18
# 9x3=27
# 9x4=36
# 9x5=45
# 9x6=54
# 9x7=63
# 9x8=72
# 9x9=81
# 9x10=90

# %%
z=int(input('Enter the number'))
i=1
for  i in range(1,11):
    print(str(z)+"x"+ str(i) + "=" + str(z*i))
    i = i+1
# Out:
# Enter the number5
# 5x1=5
# 5x2=10
# 5x3=15
# 5x4=20
# 5x5=25
# 5x6=30
# 5x7=35
# 5x8=40
# 5x9=45
# 5x10=50

# %%
z=int(input('Enter the number'))

for  i in range(1,11):
    print(str(z),"x", str(i),"=" ,str(z*i/2))
    i = i+1
# Out:
# Enter the number6
# 6 x 1 = 3.0
# 6 x 2 = 6.0
# 6 x 3 = 9.0
# 6 x 4 = 12.0
# 6 x 5 = 15.0
# 6 x 6 = 18.0
# 6 x 7 = 21.0
# 6 x 8 = 24.0
# 6 x 9 = 27.0
# 6 x 10 = 30.0

# %%
a=[1,2,3]
b=[4,5,6]
z=list(map(sum,zip(a,b)))
print(z)
# Out:
# [5, 7, 9]

# %% [markdown]
# # New Section

# %%
def mysum(*args,**kwargs):
  print(kwargs)
  sum=0
  for x in ars:
    sum=sum+x
    return sum
print(mysum(1,2,3))
print(mysum(1,2,3,4,5,6))
# Out:
# {}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-33097edcf8a4> in <module>()
#       5     sum=sum+x
#       6     return sum
# ----> 7 print(mysum(1,2,3))
#       8 print(mysum(1,2,3,4,5,6))
#
# <ipython-input-31-33097edcf8a4> in mysum(*args, **kwargs)
#       2   print(kwargs)
#       3   sum=0
# ----> 4   for x in ars:
#       5     sum=sum+x
#       6     return sum
#
# NameError: name 'ars' is not defined

# %% [markdown]
# **Lab 2**
#
# * Write a program that asks user to enter ten words, one at a time and then it prints those words in sorted order
# * Write a program that prints the sum of all even numbers between 1 and 1000

# %% [markdown]
# **Lab 3**
#
# * Write a program that read a text file and prints the top 100 most used words
# * Hints
#   * To read a file:
#     * f = open(‘abc.txt’)
#     * text = f.read()
#   * To split text into words:
#     * words = text.split()
#   * To sort a list:
#     * sorted(list, key=func, reverse=True)

# %%
f=open('abc.txt','r')
txt=f.read()
print(len(txt))
# Out:
# 132327

# %%
f=open('abc.txt','r')
txt=f.read()
words=txt.split()
freq_chart={}
for word in word:
  curr_count=freq_chart.setdefault(word,{})
  freq_chart[word]=curr_count+1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-912d80d936bf> in <module>()
#       5 for word in word:
#       6   curr_count=freq_chart.setdefault(word,{})
# ----> 7   freq_chart[word]=curr_count+1
#       8
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'int'

# %% [markdown]
# **Lab 4**
#
# * Implement accelerate and deaccelerate methods for the car class assume of fix rate of acceleration and deaccelerate make sure car doesn’t move backward when it deaccelerating.
# * Simulate a race of 10 cars. All car starts at the same position and accelerates at a random rate between 1 and 5 m/$s^2$ for a period of between 5 to 10 seconds.

# %% [markdown]
# **Lab 5**
#
# Do object modeling for an application that manages a users personal library
