# %% [markdown]
# **Lab 1**
# 1. Use git init to create an empty repo
# 2. Add a file to local repo and push to github
# 3. Make additional changes to same file, again push to github
# 4. Add a collaborator to your repo
# 5. Ask you collaborator to make change to the file and push to repo
# 6. You try to make a diff change at the same place in the file and push to repo
# 7. Step6 will fail, Fix merge conflicts and push again
# 8. Verify all the commits in github
# 9. Revert code to previous version

# %% [markdown]
# **Lab 2**
# 1. Remove push access to master branch from your collabortator
# 2. Ask your collaborator to create a new branch
# 3. Push new code changes to that branch
# 4. Create a pull request from that branch to master branch
# 5. Approve and merge the pull request
# 6. Do a git pull and veirfy that you can see the new changes in master branch

# %% [markdown]
# **Lab 3**
# 1. Use python requests to post a comment on your commit
# 2. Use python requests to find top 10 commiters on django repo

# %%
import requests
import pprint
headers ={"Authorization" : "token 58f1df067e9fec82c9dc0e7eedced3c0570f370c"}
json = {"body": "comment from api call", "path": "ïndex.html"}
r = requests.post("https://api.github.com/user/repos/Aish1606/iitk_project/commits/ee883f8287fa5c2404f31dfafdab5504878b9b18",headers=headers, json=json)
r = requests.get("https://api.github.com/user/repos",headers=headers)
print(r.json())
pprint.pprint(r.json())
# Out:
# [{'id': 220749421, 'node_id': 'MDEwOlJlcG9zaXRvcnkyMjA3NDk0MjE=', 'name': 'iitk_project', 'full_name': 'Aish1606/iitk_project', 'private': False, 'owner': {'login': 'Aish1606', 'id': 45567893, 'node_id': 'MDQ6VXNlcjQ1NTY3ODkz', 'avatar_url': 'https://avatars1.githubusercontent.com/u/45567893?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/Aish1606', 'html_url': 'https://github.com/Aish1606', 'followers_url': 'https://api.github.com/users/Aish1606/followers', 'following_url': 'https://api.github.com/users/Aish1606/following{/other_user}', 'gists_url': 'https://api.github.com/users/Aish1606/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/Aish1606/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/Aish1606/subscriptions', 'organizations_url': 'https://api.github.com/users/Aish1606/orgs', 'repos_url': 'https://api.github.com/users/Aish1606/repos', 'events_url': 'https://api.github.com/users/Aish1606/events{/privacy}', 'received_events_url': 'https://api.github.com/users/Aish1606/received_events', 'type': 'User', 'site_admin': False}, 'html_url': 'https://github.com/Aish1606/iitk_project', 'description': None, 'fork': False, 'url': 'https://api.github.com/repos/Aish1606/iitk_project', 'forks_url': 'https://api.github.com/repos/Aish1606/iitk_project/forks', 'keys_url': 'https://api.github.com/repos/Aish1606/iitk_project/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/Aish1606/iitk_project/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/Aish1606/iitk_project/teams', 'hooks_url': 'https://api.github.com/repos/Aish1606/iitk_project/hooks', 'issue_events_url': 'https://api.github.com/repos/Aish1606/iitk_project/issues/events{/number}', 'events_url': 'https://api.github.com/repos/Aish1606/iitk_project/events', 'assignees_url': 'https://api.github.com/repos/Aish1606/iitk_project/assignees{/user}', 'branches_url': 'https://api.github.com/repos/Aish1606/iitk_project/branches{/branch}', 'tags_url': 'https://api.github.com/repos/Aish1606/iitk_project/tags', 'blobs_url': 'https://api.github.com/repos/Aish1606/iitk_project/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/Aish1606/iitk_project/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/Aish1606/iitk_project/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/Aish1606/iitk_project/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/Aish1606/iitk_project/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/Aish1606/iitk_project/languages', 'stargazers_url': 'https://api.github.com/repos/Aish1606/iitk_project/stargazers', 'contributors_url': 'https://api.github.com/repos/Aish1606/iitk_project/contributors', 'subscribers_url': 'https://api.github.com/repos/Aish1606/iitk_project/subscribers', 'subscription_url': 'https://api.github.com/repos/Aish1606/iitk_project/subscription', 'commits_url': 'https://api.github.com/repos/Aish1606/iitk_project/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/Aish1606/iitk_project/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/Aish1606/iitk_project/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/Aish1606/iitk_project/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/Aish1606/iitk_project/contents/{+path}', 'compare_url': 'https://api.github.com/repos/Aish1606/iitk_project/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/Aish1606/iitk_project/merges', 'archive_url': 'https://api.github.com/repos/Aish1606/iitk_project/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/Aish1606/iitk_project/downloads', 'issues_url': 'https://api.github.com/repos/Aish1606/iitk_project/issues{/number}', 'pulls_url': 'https://api.github.com/repos/Aish1606/iitk_project/pulls{/number}', 'milestones_url': 'https://api.github.com/repos/Aish1606/iitk_project/milestones{/number}', 'notifications_url': 'https://api ...
# [{'archive_url': 'https://api.github.com/repos/Aish1606/iitk_project/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/Aish1606/iitk_project/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/Aish1606/iitk_project/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/Aish1606/iitk_project/branches{/branch}',
#   'clone_url': 'https://github.com/Aish1606/iitk_project.git',
#   'collaborators_url': 'https://api.github.com/repos/Aish1606/iitk_project/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/Aish1606/iitk_project/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/Aish1606/iitk_project/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/Aish1606/iitk_project/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/Aish1606/iitk_project/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/Aish1606/iitk_project/contributors',
#   'created_at': '2019-11-10T06:12:12Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/Aish1606/iitk_project/deployments',
#   'description': None,
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/Aish1606/iitk_project/downloads',
#   'events_url': 'https://api.github.com/repos/Aish1606/iitk_project/events',
#   'fork': False,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/Aish1606/iitk_project/forks',
#   'full_name': 'Aish1606/iitk_project',
#   'git_commits_url': 'https://api.github.com/repos/Aish1606/iitk_project/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Aish1606/iitk_project/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Aish1606/iitk_project/git/tags{/sha}',
#   'git_url': 'git://github.com/Aish1606/iitk_project.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/Aish1606/iitk_project/hooks',
#   'html_url': 'https://github.com/Aish1606/iitk_project',
#   'id': 220749421,
#   'issue_comment_url': 'https://api.github.com/repos/Aish1606/iitk_project/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/Aish1606/iitk_project/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/Aish1606/iitk_project/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/Aish1606/iitk_project/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/Aish1606/iitk_project/labels{/name}',
#   'language': 'HTML',
#   'languages_url': 'https://api.github.com/repos/Aish1606/iitk_project/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/Aish1606/iitk_project/merges',
#   'milestones_url': 'https://api.github.com/repos/Aish1606/iitk_project/milestones{/number}',
#   'mirror_url': None,
#   'name': 'iitk_project',
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyMjA3NDk0MjE=',
#   'notifications_url': 'https://api.github.com/repos/Aish1606/iitk_project/notifications{?since,all,participating}',
#   'open_issues': 0,
#   'open_issues_count': 0,
#   'owner': {'avatar_url': 'https://avatars1.githubusercontent.com/u/45567893?v=4',
#             'events_url': 'https://api.github.com/users/Aish1606/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/Aish1606/followers',
#             'following_url': 'https://api.github.com/users/Aish1606/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/Aish1606/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/Aish1606',
#             'id': 45567893,
#             'login': 'Aish1606',
#             'node_id': 'MDQ6VXNlcjQ1NTY3ODkz',
#             'organizations_url': 'https://api.github.com/users/Aish1606/orgs',
#             'received_events_url': 'https://api.github.com/users/Aish1606/received_events',
#             'repos_url': 'https://api.github.com/users/Aish1606/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/Aish1606/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/Aish1606/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/Aish1606'},
#   'permissions': {'admin': True, 'pull': True, 'push': True},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/Aish1606/iitk_project/pulls{/number}',
#   'pushed_at': '2019-11-10T07:03:00Z',
#   'releases_url': 'https://api.github.com/repos/Aish1606/iitk_project/releases{/id}',
#   'size': 2,
#   'ssh_url': 'git@github.com:Aish1606/iitk_project.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/Aish1606/iitk_project/stargazers',
#   'statuses_url': 'https://api.github.com/repos/Aish1606/iitk_project/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/Aish1606/iitk_project/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Aish1606/iitk_project/subscription',
#   'svn_url': 'https://github.com/Aish1606/iitk_project',
#   'tags_url': 'https://api.github.com/repos/Aish1606/iitk_project/tags',
#   'teams_url': 'https://api.github.com/repos/Aish1606/iitk_project/teams',
#   'trees_url': 'https://api.github.com/repos/Aish1606/iitk_project/git/trees{/sha}',
#   'updated_at': '2019-11-10T07:03:02Z',
#   'url': 'https://api.github.com/repos/Aish1606/iitk_project',
#   'watchers': 0,
#   'watchers_count': 0},
#  {'archive_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/branches{/branch}',
#   'clone_url': 'https://github.com/renuka019/iitkproj_nov.git',
#   'collaborators_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/contributors',
#   'created_at': '2019-11-10T06:10:05Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/deployments',
#   'description': None,
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/downloads',
#   'events_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/events',
#   'fork': False,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/forks',
#   'full_name': 'renuka019/iitkproj_nov',
#   'git_commits_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/git/tags{/sha}',
#   'git_url': 'git://github.com/renuka019/iitkproj_nov.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/hooks',
#   'html_url': 'https://github.com/renuka019/iitkproj_nov',
#   'id': 220749228,
#   'issue_comment_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/labels{/name}',
#   'language': 'HTML',
#   'languages_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/merges',
#   'milestones_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/milestones{/number}',
#   'mirror_url': None,
#   'name': 'iitkproj_nov',
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyMjA3NDkyMjg=',
#   'notifications_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/notifications{?since,all,participating}',
#   'open_issues': 0,
#   'open_issues_count': 0,
#   'owner': {'avatar_url': 'https://avatars1.githubusercontent.com/u/57562111?v=4',
#             'events_url': 'https://api.github.com/users/renuka019/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/renuka019/followers',
#             'following_url': 'https://api.github.com/users/renuka019/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/renuka019/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/renuka019',
#             'id': 57562111,
#             'login': 'renuka019',
#             'node_id': 'MDQ6VXNlcjU3NTYyMTEx',
#             'organizations_url': 'https://api.github.com/users/renuka019/orgs',
#             'received_events_url': 'https://api.github.com/users/renuka019/received_events',
#             'repos_url': 'https://api.github.com/users/renuka019/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/renuka019/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/renuka019/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/renuka019'},
#   'permissions': {'admin': False, 'pull': True, 'push': True},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/pulls{/number}',
#   'pushed_at': '2019-11-10T06:45:51Z',
#   'releases_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/releases{/id}',
#   'size': 0,
#   'ssh_url': 'git@github.com:renuka019/iitkproj_nov.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/stargazers',
#   'statuses_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/subscribers',
#   'subscription_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/subscription',
#   'svn_url': 'https://github.com/renuka019/iitkproj_nov',
#   'tags_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/tags',
#   'teams_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/teams',
#   'trees_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/git/trees{/sha}',
#   'updated_at': '2019-11-10T06:45:53Z',
#   'url': 'https://api.github.com/repos/renuka019/iitkproj_nov',
#   'watchers': 0,
#   'watchers_count': 0}]

# %% [markdown]
# **Lab 4**
# 1. Create a 8x8x8 array with random values
# 2. From the matrix in (1) Negate all elements
# whose values are between 3 to 8
# 3. Multiply a 8x3 matrix by 3x2 matrix and
# prints the columns as 1 D array

# %%
import numpy as np
x = [1,2,3,4]
z = np.array(x)

# %%
z = np.random.randint(10, 20,(4,4))
z
# Out:
# array([[11, 10, 14, 15],
#        [14, 17, 16, 14],
#        [13, 13, 16, 12],
#        [14, 17, 19, 12]])

# %%
import numpy as np
z = np.random.randint(10,50,(8,8,8))
z
# Out:
# array([[[20, 47, 47, 17, 29, 20, 28, 34],
#         [39, 47, 30, 13, 39, 25, 34, 18],
#         [21, 25, 39, 39, 15, 33, 22, 47],
#         [41, 29, 44, 29, 12, 49, 25, 22],
#         [11, 22, 44, 18, 30, 21, 11, 45],
#         [42, 43, 42, 41, 32, 29, 11, 17],
#         [35, 40, 31, 27, 20, 38, 35, 42],
#         [27, 21, 35, 42, 22, 19, 35, 15]],
#
#        [[32, 33, 12, 10, 45, 30, 25, 23],
#         [45, 39, 39, 43, 29, 19, 22, 25],
#         [39, 19, 33, 22, 37, 38, 48, 20],
#         [41, 23, 43, 19, 46, 46, 13, 10],
#         [45, 26, 40, 39, 38, 11, 46, 45],
#         [11, 44, 44, 46, 12, 44, 14, 45],
#         [31, 24, 35, 44, 27, 37, 26, 35],
#         [32, 43, 33, 29, 36, 25, 41, 39]],
#
#        [[38, 13, 44, 41, 32, 32, 30, 39],
#         [44, 19, 10, 27, 34, 21, 14, 49],
#         [21, 35, 42, 28, 48, 16, 13, 28],
#         [13, 46, 19, 24, 25, 39, 28, 20],
#         [28, 46, 47, 21, 19, 14, 40, 24],
#         [46, 37, 14, 42, 21, 41, 27, 42],
#         [46, 16, 35, 23, 12, 23, 36, 26],
#         [31, 38, 31, 18, 48, 46, 26, 36]],
#
#        [[44, 30, 34, 45, 25, 24, 30, 44],
#         [22, 28, 33, 25, 35, 48, 31, 32],
#         [45, 11, 41, 38, 48, 42, 45, 44],
#         [45, 30, 41, 38, 46, 42, 29, 39],
#         [45, 27, 16, 28, 15, 44, 15, 33],
#         [40, 45, 19, 11, 39, 15, 24, 13],
#         [16, 39, 30, 39, 18, 28, 48, 28],
#         [35, 45, 46, 38, 15, 10, 49, 35]],
#
#        [[31, 23, 27, 27, 40, 46, 34, 39],
#         [37, 24, 32, 31, 26, 10, 44, 37],
#         [16, 30, 43, 37, 30, 23, 28, 34],
#         [10, 10, 44, 12, 23, 36, 31, 23],
#         [37, 20, 25, 49, 13, 46, 32, 35],
#         [11, 38, 42, 16, 24, 23, 16, 32],
#         [22, 21, 40, 22, 32, 42, 16, 48],
#         [11, 14, 12, 14, 33, 11, 39, 40]],
#
#        [[15, 20, 26, 30, 15, 33, 22, 40],
#         [47, 40, 27, 28, 42, 19, 12, 32],
#         [47, 18, 39, 22, 43, 47, 38, 34],
#         [43, 30, 31, 36, 43, 35, 19, 37],
#         [25, 20, 17, 19, 46, 11, 30, 17],
#         [21, 38, 23, 35, 18, 31, 38, 37],
#         [16, 21, 37, 36, 18, 23, 13, 44],
#         [42, 36, 41, 39, 25, 33, 41, 44]],
#
#        [[42, 20, 35, 47, 31, 25, 16, 29],
#         [42, 40, 13, 14, 13, 46, 10, 42],
#         [31, 17, 46, 15, 12, 18, 24, 20],
#         [31, 11, 44, 19, 19, 11, 13, 39],
#         [19, 15, 41, 48, 20, 22, 42, 20],
#         [34, 18, 14, 34, 33, 46, 11, 23],
#         [32, 21, 41, 21, 41, 13, 35, 43],
#         [29, 48, 31, 47, 49, 15, 48, 37]],
#
#        [[28, 12, 18, 36, 45, 22, 42, 40],
#         [44, 33, 34, 21, 16, 25, 39, 33],
#         [10, 11, 43, 29, 19, 27, 11, 45],
#         [48, 18, 48, 13, 31, 15, 39, 19],
#         [41, 30, 12, 19, 11, 22, 20, 24],
#         [17, 44, 35, 37, 19, 48, 25, 22],
#         [32, 44, 30, 26, 42, 19, 17, 22],
#         [32, 29, 39, 14, 48, 49, 46, 44]]])

# %%
import numpy as np
z = np.random.randint(1,10,(8,8,8))
mask =(z>3)&(z<8)
z[mask]=-1*z[mask]
z
# Out:
# array([[[-5,  8,  8, -4, -4, -5, -4,  9],
#         [ 3, -6, -5, -4,  1,  1,  3,  8],
#         [ 1,  2, -7,  1, -6,  9,  1, -5],
#         [-6, -5,  8,  3,  9,  8,  3, -6],
#         [-4,  8, -7, -7, -6,  2,  3,  8],
#         [ 3,  9, -7, -7,  3, -4,  2, -5],
#         [-4,  9, -6,  1,  8,  8,  1,  2],
#         [ 2,  2, -5,  3,  3,  2,  8,  3]],
#
#        [[-7, -7,  2,  8, -6,  3, -5, -4],
#         [ 9, -7,  2,  2, -6,  1,  1, -5],
#         [ 8, -6,  2,  1,  9,  8, -7, -7],
#         [-5,  1, -6,  2,  8, -4, -4, -5],
#         [-5,  8, -4, -5, -4, -7, -4,  3],
#         [ 9, -5, -4,  1, -5,  8, -5, -4],
#         [-4,  2, -6, -6,  3,  1,  8, -6],
#         [-6, -6,  2, -5, -4,  9,  3, -4]],
#
#        [[-7,  3,  1,  1, -7,  1, -5,  8],
#         [ 8,  1,  8,  8,  8,  8,  3, -5],
#         [-5, -6,  9,  1,  2,  8, -5,  3],
#         [ 2,  9,  8,  3,  1,  9,  2,  8],
#         [-4, -6,  9, -4, -6,  9, -4, -4],
#         [ 2, -6, -7,  3, -7, -4,  8,  3],
#         [-7, -7, -4, -6,  1,  1,  8, -5],
#         [-6,  9, -6, -5, -6, -5,  8, -4]],
#
#        [[ 8, -7,  1,  2, -6,  1, -6,  2],
#         [-6,  8, -7, -5, -6,  9,  1, -5],
#         [-7, -5,  2,  1, -6,  2,  1, -4],
#         [-4, -5,  3, -6, -6,  2,  9,  3],
#         [ 8,  8,  9,  1, -4,  9,  9,  9],
#         [-5, -5,  9,  1,  9, -7,  8,  8],
#         [ 3,  9, -7,  3, -6,  1, -5, -7],
#         [ 3,  8, -6,  2,  2,  8, -4,  2]],
#
#        [[-5, -5,  8,  2, -4, -6,  2, -6],
#         [-7,  9,  2,  2, -6, -6, -5,  2],
#         [-7, -7,  9,  9,  8,  2,  2,  2],
#         [ 2, -5, -7, -6,  2, -6, -4,  2],
#         [ 9,  2,  3, -7,  1,  9, -4, -6],
#         [-7, -4,  9,  8, -4, -6,  1,  8],
#         [ 8,  2,  9,  1, -7,  3,  1, -4],
#         [-7, -7,  2,  8,  9,  3,  2,  8]],
#
#        [[ 1,  2, -5,  3, -6, -6, -5,  8],
#         [-6, -4, -7, -7, -6,  2, -5,  1],
#         [-6,  9,  8,  8, -4, -4,  3, -7],
#         [ 9,  9, -6,  2, -5,  1, -4,  3],
#         [-6, -7,  8,  1,  2,  3, -7, -6],
#         [ 1, -7, -6,  8, -6, -4,  9, -4],
#         [-7,  2,  9,  1,  3, -6,  1, -5],
#         [-5,  9,  3, -7,  1, -6,  9,  3]],
#
#        [[-4, -6,  2, -4,  3,  3, -7, -6],
#         [ 2,  2, -6,  9,  1, -5,  3,  9],
#         [ 2,  8,  2, -4,  3,  8, -5, -5],
#         [ 8,  8, -6,  1,  9,  1,  1,  1],
#         [-5, -6,  2,  2,  9,  2,  8,  9],
#         [-4, -7, -6,  9,  2, -4, -4,  3],
#         [-7,  8,  3,  9,  8,  2,  1, -4],
#         [-5, -7,  1,  3,  1, -6,  2, -7]],
#
#        [[ 3,  1,  9, -4, -7,  9, -7,  1],
#         [ 8, -6,  9,  9,  2,  8, -4,  8],
#         [-5,  3,  2, -6,  3, -5,  1, -5],
#         [ 2, -5,  3, -7, -6, -4,  9, -4],
#         [-7,  9,  3, -4,  1, -5, -4, -4],
#         [-6,  9,  9,  1,  3,  3, -5, -5],
#         [ 3,  9,  9, -6,  3,  1,  3,  1],
#         [-4, -5, -4, -6,  8,  3,  1, -4]]])

# %%
import numpy as np
a=np.random.randint(1,10,(8,3))
b=np.random.randint(1,10,(3,2))
c=np.dot(a,b)
print(c)
d=c.reshape(1,2)
print(d)
# Out:
# [[ 63  63]
#  [ 60  25]
#  [ 37  38]
#  [ 87  48]
#  [114  55]
#  [ 64  43]
#  [129  85]
#  [ 68  30]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-776cddb13658> in <module>()
#       4 c=np.dot(a,b)
#       5 print(c)
# ----> 6 d=c.reshape(1,2)
#       7 print(d)
#
# ValueError: cannot reshape array of size 16 into shape (1,2)

# %% [markdown]
# **Lab 5**
#
# 1. Create a 8x8x8 matrix with random values ranging from 5 to 9
# 2. Find the diagonal of product of two random 5x5 matrices
# 3. Negate a boolean, or to change the the sign of the float inplace

# %%
n=np.random.randint(5,9,(8,8))
m=np.random.randint(5,9,(8,8))
c=np.dot(n,m)
c
# Out:
# array([[322, 322, 274, 307, 338, 340, 289, 336],
#        [363, 370, 316, 355, 381, 394, 337, 382],
#        [381, 396, 333, 376, 404, 403, 356, 399],
#        [333, 336, 284, 327, 354, 352, 305, 346],
#        [335, 337, 285, 329, 354, 350, 307, 347],
#        [310, 317, 269, 308, 334, 325, 287, 320],
#        [293, 299, 252, 288, 312, 304, 269, 303],
#        [332, 340, 286, 325, 353, 345, 305, 342]])

# %%
Z = np.random.randint(0,2,100)
np.logical_not(Z, out=Z)

Z = np.random.uniform(-1.0,1.0,100)
np.negative(Z, out=Z)
# Out:
# array([ 0.45126423, -0.23684717, -0.67951151,  0.35375621, -0.26818958,
#         0.2614231 ,  0.86866154,  0.52367222,  0.84600548, -0.60826164,
#        -0.23438999,  0.68897401,  0.74469909,  0.26301192,  0.28434479,
#        -0.77501939, -0.26887269, -0.5487373 ,  0.3795634 , -0.22250188,
#        -0.85590362, -0.55570216, -0.92461136, -0.22906566, -0.79469351,
#        -0.2737114 ,  0.3224918 ,  0.98163609,  0.53264763, -0.85382948,
#         0.6054169 , -0.63046132, -0.08333838, -0.09285329, -0.0877291 ,
#        -0.75079506, -0.31884217,  0.58789338,  0.99389401, -0.6646962 ,
#         0.4215244 , -0.95706355, -0.02914892, -0.74710335, -0.41130396,
#         0.72139534,  0.48287415,  0.56220673,  0.17873272,  0.24539733,
#         0.20357818,  0.8764834 , -0.14811734, -0.45061356, -0.42365058,
#        -0.52777093, -0.13348829, -0.26782807, -0.17996407,  0.69398822,
#         0.12056388,  0.60782403, -0.0424441 , -0.78916364,  0.75069395,
#        -0.42532397, -0.63613206,  0.64991759,  0.21365647, -0.95042815,
#        -0.79244193, -0.58986139,  0.17543902,  0.12241736, -0.90594433,
#         0.22241344, -0.51243059, -0.9582184 ,  0.93206925,  0.72207444,
#        -0.85913801,  0.0426793 ,  0.00564883,  0.11802966,  0.73227108,
#        -0.62155625, -0.6603493 ,  0.90124157, -0.0919574 ,  0.93782919,
#         0.50624403, -0.55278559, -0.67437018, -0.15068878, -0.06022527,
#         0.33276141, -0.26490773, -0.68956949, -0.82260943,  0.58519669])

# %%
np.diag(c)
# Out:
# array([ 86, 113,  64,  41, 138, 102,  95,  89])

# %% [markdown]
# **Lab 6**
#
# Given 100 random points in 2D space and find the top 10 closest points to the origin.

# %%
z = np.random.randn(100,2)

# %%
import numpy as np
z=np.random.randn(100,2)
np.flip(z[np.argsort(np.sqrt(np.sum(z*z,axis=1)))],axis=0)[0:10]
# Out:
# array([[-2.69928485, -0.19901355],
#        [-2.56036304,  0.84008558],
#        [-0.91674692,  2.49973208],
#        [-1.85465662, -1.88457044],
#        [ 0.19426084,  2.45601228],
#        [ 0.14287552,  2.42824905],
#        [-2.41697216,  0.20569808],
#        [ 2.37041913, -0.41976893],
#        [ 0.65093885,  2.18260011],
#        [-1.38374396,  1.65737477]])

# %%
import numpy as np
z=np.random.randn(100,2)
a1 = z[np.argsort(np.sqrt(np.sum(z*z,axis=1)))]
np.savez('temp.npz',xyz=z,abc<=1)
# Out:
# array([[-1.41962987e-02,  4.22897219e-02],
#        [-1.78838737e-02, -8.93551284e-02],
#        [-1.59526767e-02,  1.35839918e-01],
#        [-1.54943583e-03,  2.11197483e-01],
#        [-2.32383844e-01, -4.02036339e-02],
#        [-2.81804005e-01,  9.71829528e-02],
#        [-1.61735763e-01,  2.53681209e-01],
#        [-1.23189174e-01, -3.25289774e-01],
#        [ 3.65966241e-01,  1.83803363e-01],
#        [-4.24300418e-01, -8.65031264e-02],
#        [ 1.76410977e-01,  4.47191524e-01],
#        [-4.90075553e-01, -8.45927605e-04],
#        [-2.81641537e-01,  4.59618126e-01],
#        [-1.84146739e-01,  5.17548197e-01],
#        [ 4.69685882e-01,  2.87952277e-01],
#        [ 2.68788926e-01, -4.92637414e-01],
#        [-1.50638603e-01, -5.98194179e-01],
#        [-4.55991966e-01, -4.34220394e-01],
#        [ 4.35652930e-01,  4.82163716e-01],
#        [-3.85910577e-01,  5.41735275e-01],
#        [ 2.20948486e-01,  7.08940475e-01],
#        [ 7.43165025e-01, -6.76680042e-02],
#        [ 5.56538770e-01, -5.27009475e-01],
#        [ 7.66458536e-01, -3.07383788e-01],
#        [-3.68074466e-02,  8.43371397e-01],
#        [ 4.08285088e-01, -7.39116049e-01],
#        [ 6.42203156e-01, -5.91023659e-01],
#        [ 6.89881475e-01,  5.42992081e-01],
#        [-6.83947265e-01, -5.52963000e-01],
#        [ 7.06183852e-01,  6.03829051e-01],
#        [-5.51523217e-01, -7.52314993e-01],
#        [ 2.58043467e-01, -9.14022278e-01],
#        [ 3.60559780e-01, -8.86330391e-01],
#        [-9.63350688e-01, -2.85535822e-03],
#        [ 9.08730501e-01, -3.96066385e-01],
#        [ 9.45766285e-01, -3.09737649e-01],
#        [-6.50153973e-01, -7.63708663e-01],
#        [-7.30327144e-01, -6.99082116e-01],
#        [-2.31479334e-01, -1.00530878e+00],
#        [ 7.29742575e-01, -7.37878066e-01],
#        [ 9.45438000e-01, -5.48267171e-01],
#        [ 7.37657318e-01, -8.34708157e-01],
#        [-5.09836758e-01, -9.99642700e-01],
#        [-1.11560622e+00,  1.50003254e-01],
#        [-9.11521552e-01, -6.84684713e-01],
#        [ 4.09256809e-02, -1.19068485e+00],
#        [ 2.22315650e-01,  1.17970210e+00],
#        [ 6.08455207e-01,  1.05267430e+00],
#        [ 7.22322039e-01,  1.03028615e+00],
#        [ 7.21942264e-01,  1.05789621e+00],
#        [-7.51482021e-01, -1.07211800e+00],
#        [ 1.31168986e+00,  2.26289463e-01],
#        [-1.26131453e-01, -1.33033161e+00],
#        [ 5.18671090e-01, -1.24367268e+00],
#        [-1.35668800e+00,  2.85763352e-01],
#        [ 1.22482746e+00,  6.68104045e-01],
#        [-7.58729972e-01, -1.25276898e+00],
#        [-8.80414694e-01, -1.17063669e+00],
#        [ 1.18890256e+00, -9.08838360e-01],
#        [ 1.40024695e+00,  5.28212891e-01],
#        [-5.15066531e-01,  1.41166793e+00],
#        [ 4.04017148e-01,  1.47754884e+00],
#        [-9.55141404e-01, -1.21159834e+00],
#        [ 1.39466992e+00, -7.44265820e-01],
#        [ 7.83207429e-01, -1.40260953e+00],
#        [-8.11210906e-01, -1.39028281e+00],
#        [ 1.94993097e-01,  1.60525499e+00],
#        [-3.66085317e-01,  1.57773701e+00],
#        [-8.44942980e-01,  1.53772380e+00],
#        [-7.23887147e-01,  1.61405659e+00],
#        [-1.36184096e+00, -1.21901558e+00],
#        [-1.63279669e+00,  8.61521376e-01],
#        [-1.45293591e+00, -1.17167574e+00],
#        [-1.86072020e+00, -2.08046575e-01],
#        [-3.70351764e-01, -1.84349938e+00],
#        [ 3.60817988e-01,  1.84592095e+00],
#        [ 1.50350066e+00, -1.13645961e+00],
#        [ 1.89791546e+00,  3.48561222e-01],
#        [ 1.77955568e+00, -7.76612082e-01],
#        [ 7.74304777e-01, -1.79091790e+00],
#        [ 1.44981905e+00, -1.30679730e+00],
#        [-3.15995446e-01,  1.92992141e+00],
#        [ 5.75349534e-01,  1.88342698e+00],
#        [-1.97820108e+00,  9.36181056e-02],
#        [ 1.98964770e+00, -7.62942995e-02],
#        [ 1.15634472e+00,  1.62736534e+00],
#        [-1.97470969e+00, -7.50785085e-01],
#        [ 1.19548109e+00, -1.80670788e+00],
#        [-1.92169976e+00, -1.00286393e+00],
#        [-2.06932875e+00,  7.18727938e-01],
#        [ 2.20911484e+00,  1.95645486e-01],
#        [ 6.98448802e-01,  2.12200408e+00],
#        [-1.90202974e+00, -1.24128298e+00],
#        [ 9.23548405e-01,  2.12420415e+00],
#        [-1.68840982e+00, -1.62668105e+00],
#        [-1.58931365e+00,  1.78592460e+00],
#        [ 2.27529427e+00, -7.71311572e-01],
#        [-4.53928517e-01, -2.58586206e+00],
#        [ 2.48377407e-01,  2.62062230e+00],
#        [-2.70043012e+00,  1.04951525e+00]])

# %%
a=np.random.randint(1,100(100,2))
print(a)
x=a[:,0]
y=a[:,1]
print(x,y)
p1=np.array(np)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-981bb7c25141> in <module>()
# ----> 1 a=np.random.randint(1,100(100,2))
#       2 print(a)
#       3 x=a[:,0]
#       4 y=a[:,1]
#       5 print(x,y)
#
# TypeError: 'int' object is not callable

# %% [markdown]
# **Lab 7**
#
# Find the value of pi using Monte Carlo simulation.
#
# **Hint:-**
#
# Consider a unit circle which is enclosed in a square. randomly genrate uniformily distributed points inside the square. The fraction of points falling inside the circle is pi/4.

# %%
coordinates = np.random.randn(100,2)
dist=np.sqrt(coordinates[:,0]**2+coordinates[:,1]**2)
top_10=np.argsort(dist)[:10]
print(coordinates[top_10])
# Out:
# [[ 0.00100319 -0.01849744]
#  [-0.00284443  0.0757368 ]
#  [-0.19841142  0.00996533]
#  [-0.19552771 -0.04777026]
#  [ 0.19046364 -0.08513409]
#  [ 0.20326582  0.05187894]
#  [-0.03497909 -0.22719607]
#  [-0.25686005  0.00392779]
#  [-0.18266662 -0.23237514]
#  [-0.29858314 -0.06240169]]

# %%
from random import *
from math import sqrt
inside=0
n=10**6
for i in range(0,n):
    x=random()
    y=random()
    if sqrt(x*x+y*y)<=1:
        inside+=1
pi=4*inside/n
print (pi)
# Out:
# 3.145424

# %%
from numpy import random,sqrt,pi
n=100000
p=random.rand(n,2)
idx = sqrt(p[:,0]**2+p[:,1]**2)<1
print(sum(idx)/n*4,"result")
print(pi,"real pi")
# Out:
# 3.14568 result
# 3.141592653589793 real pi

# %% [markdown]
# **Home Work**
#
# 1. wap the first two rows of a random 5x5
# array
# 2. How to get the block-sum of a 16x16 matrix
# (block size is 4x4)?
# 3. Sort an array by the nth column
# 4. Subtract the mean of each row of a matrix
# from each element

# %%
import numpy as np
x = np.random.random((5,5))
print("Original Array:")
print(x)
# Out:
# Original Array:
# [[0.81878287 0.70352538 0.78276478 0.66500265 0.52281257]
#  [0.13708465 0.54756421 0.13685819 0.69964625 0.74541263]
#  [0.55446351 0.02887095 0.99856594 0.31956136 0.27246306]
#  [0.80547593 0.38271265 0.77702247 0.58136805 0.06260012]
#  [0.68615916 0.37442578 0.76164371 0.04212548 0.43646939]]

# %%
Z = np.ones((16,16))
k = 4
S = np.add.reduceat(np.add.reduceat(Z, np.arange(0, Z.shape[0], k), axis=0),
                                       np.arange(0, Z.shape[1], k), axis=1)
print(S)
# Out:
# [[16. 16. 16. 16.]
#  [16. 16. 16. 16.]
#  [16. 16. 16. 16.]
#  [16. 16. 16. 16.]]

# %%
Z = np.random.randint(0,10,(3,3))
print(Z)
print(Z[Z[:,1].argsort()])
# Out:
# [[2 9 8]
#  [5 1 0]
#  [9 0 1]]
# [[9 0 1]
#  [5 1 0]
#  [2 9 8]]

# %%
X = np.random.rand(5, 10)

# Recent versions of numpy
Y = X - X.mean(axis=1, keepdims=True)

# Older versions of numpy
Y = X - X.mean(axis=1).reshape(-1, 1)

print(Y)
# Out:
# [[ 0.04971902 -0.00601491  0.24785613 -0.31619407 -0.39564837  0.30328289
#   -0.16494815  0.24403685  0.23894765 -0.20103705]
#  [ 0.00175159  0.56033257  0.35094635 -0.38613211 -0.42032836 -0.06447932
#   -0.37321938  0.20188404  0.52962878 -0.40038416]
#  [-0.0804075   0.28731971 -0.29906619  0.22570362  0.29185376 -0.26038373
#   -0.54311787  0.09249617  0.07410786  0.21149419]
#  [-0.05595568 -0.28683396  0.20061763 -0.20765581  0.31535417  0.12759641
#   -0.15283137  0.30911243  0.21166767 -0.46107149]
#  [-0.36770699 -0.36649875  0.20357999  0.09013176  0.34858386 -0.37335248
#   -0.21142783 -0.14301848  0.35292787  0.46678105]]
