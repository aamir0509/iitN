# %% [markdown]
# **Lab 1**
# 1. Use git init to create an empty repo
# 2. Add a file to local repo and push to github
# 3. Make additional changes to same file, again push to github
# 4. Add a collaborator to your repo
# 5. Ask you collaborator to make change to the file and push to repo
# 6. You try to make a diff change at the same place in the file and push to repo
# 7. Step6 will fail, Fix merge conflicts and push again
# 8. Verify all the commits in github
# 9. Revert code to previous version

# %% [markdown]
# https://github.com/k-saxena/demo

# %% [markdown]
# **Lab 2**
# 1. Remove push access to master branch from your collabortator
# 2. Ask your collaborator to create a new branch
# 3. Push new code changes to that branch
# 4. Create a pull request from that branch to master branch
# 5. Approve and merge the pull request
# 6. Do a git pull and veirfy that you can see the new changes in master branch

# %% [markdown]
# https://github.com/Aakansha1507/AKS

# %% [markdown]
# **Lab 3**
# 1. Use python requests to post a comment on your commit
# 2. Use python requests to find top 10 commiters on django repo

# %%
import requests

# %% [markdown]
# **Lab 4**
# 1. Create a 8x8x8 array with random values
# 2. From the matrix in (1) Negate all elements
# whose values are between 3 to 8
# 3. Multiply a 8x3 matrix by 3x2 matrix and
# prints the columns as 1 D array

# %%
import numpy as np
import random
np_arr=np.random.randint(1,10,(8,8,8))
print(np_arr) #Ans 1
np_arr[(np_arr<=3) | (np_arr>=8)] #Ans 2
np_arr1=np.random.randint(1,10,(8,3))
np_arr2=np.random.randint(1,10,(3,2))
np_arr3=np_arr1.dot(np_arr2)
print('Result of Multiplication')
print(np_arr3)
print('Flattening ..')
print(np_arr3.reshape(-1))
# Out:
# [[[2 8 3 5 2 2 7 9]
#   [6 6 2 7 5 5 9 2]
#   [7 6 6 1 8 1 6 6]
#   [5 8 6 7 6 7 8 5]
#   [9 5 6 1 2 8 8 7]
#   [7 2 3 6 6 8 2 8]
#   [7 3 4 5 3 2 9 5]
#   [9 6 1 5 5 2 3 5]]
#
#  [[1 6 7 5 3 2 3 9]
#   [7 4 3 6 1 7 3 4]
#   [3 1 9 2 4 5 4 8]
#   [6 8 7 2 3 7 3 7]
#   [8 6 3 4 7 7 8 8]
#   [7 2 5 7 6 9 5 3]
#   [9 6 9 2 6 1 9 3]
#   [8 5 6 6 7 4 5 4]]
#
#  [[5 8 7 6 6 6 9 7]
#   [7 1 3 1 6 1 1 2]
#   [6 5 9 9 3 2 9 9]
#   [3 6 9 1 3 3 1 3]
#   [1 8 9 8 4 9 6 3]
#   [4 3 6 4 1 2 4 9]
#   [5 5 6 5 1 2 8 1]
#   [9 9 9 7 9 2 3 3]]
#
#  [[3 7 2 1 4 6 6 5]
#   [5 9 7 5 9 4 1 7]
#   [9 6 7 2 2 9 9 6]
#   [1 1 6 2 4 1 3 1]
#   [1 6 1 4 5 4 8 7]
#   [6 9 6 4 2 7 7 4]
#   [9 3 9 2 9 5 2 5]
#   [1 3 2 9 3 5 6 3]]
#
#  [[7 3 6 7 6 4 9 1]
#   [7 8 8 9 9 5 4 9]
#   [6 4 3 7 1 9 7 5]
#   [3 9 1 8 7 9 1 6]
#   [9 1 5 7 8 9 7 7]
#   [4 3 4 6 6 6 9 7]
#   [6 9 5 1 4 6 1 3]
#   [6 9 8 9 5 6 2 8]]
#
#  [[3 5 1 9 2 3 3 3]
#   [4 8 7 1 1 4 1 3]
#   [2 9 9 4 2 5 1 8]
#   [4 2 2 8 5 3 6 5]
#   [7 2 9 3 3 6 4 8]
#   [6 6 8 5 7 9 6 6]
#   [3 5 3 2 3 3 9 3]
#   [5 7 5 6 5 6 9 2]]
#
#  [[1 7 7 6 1 1 2 6]
#   [1 4 9 6 4 8 1 5]
#   [9 2 3 7 2 2 4 1]
#   [8 4 1 7 9 6 2 9]
#   [7 6 8 7 6 9 8 5]
#   [8 7 8 4 9 6 3 3]
#   [6 4 7 8 8 3 9 9]
#   [3 6 7 9 2 7 1 5]]
#
#  [[4 8 2 3 6 6 8 7]
#   [6 3 3 6 5 9 5 2]
#   [2 2 4 1 6 2 2 1]
#   [9 9 1 2 2 4 2 7]
#   [1 7 6 8 2 1 8 6]
#   [5 8 5 1 5 6 9 3]
#   [3 1 6 3 9 2 5 2]
#   [4 8 9 8 8 5 7 8]]]
# Result of Multiplication
# [[ 38  91]
#  [ 55  86]
#  [ 44  83]
#  [ 57 112]
#  [ 33  85]
#  [ 75  79]
#  [ 30  53]
#  [ 72  66]]
# Flattening ..
# [ 38  91  55  86  44  83  57 112  33  85  75  79  30  53  72  66]

# %% [markdown]
# **Lab 5**
#
# 1. Create a 8x8x8 matrix with random values ranging from 5 to 9
# 2. Find the diagonal of product of two random 5x5 matrices
# 3. Negate a boolean, or to change the the sign of the float inplace

# %%
import numpy as np
import random
np_arr=np.random.randint(5,9,(8,8,8))
print(np_arr) #Answer 1
#np_arr.T
np_1=np.random.randint(1,10,(5,5))
print ('Matrix 1')
print (np_1)
np_2=np.random.randint(1,10,(5,5))
print('Matrix 2')
print(np_2)
print('Result of Multiplication')
np_3=np_1*np_2 #Answer 2
print(np_3)
b=np.asarray(np_3)
print (('%d is the Sum') %(np.trace(b)))
print('The diagonal elements are ')
print (np.diagonal(b))
# Out:
# [[[8 8 7 8 7 8 6 8]
#   [8 5 8 8 5 5 7 5]
#   [6 8 7 8 6 8 5 7]
#   [7 6 8 5 8 5 7 7]
#   [6 5 7 7 5 7 5 6]
#   [6 8 6 7 7 7 6 6]
#   [8 5 8 5 6 5 7 6]
#   [7 8 7 6 7 8 8 6]]
#
#  [[5 7 7 5 5 8 5 5]
#   [7 5 6 5 6 5 6 7]
#   [7 6 7 7 8 5 8 5]
#   [8 7 5 5 7 8 7 8]
#   [5 8 6 8 7 7 5 8]
#   [7 7 8 8 6 8 5 7]
#   [7 8 6 7 6 7 6 7]
#   [7 7 8 7 7 8 8 7]]
#
#  [[7 5 5 6 5 7 6 5]
#   [8 8 6 5 6 8 5 6]
#   [5 6 6 6 5 8 5 5]
#   [7 8 6 6 5 6 5 6]
#   [6 7 7 6 7 6 6 5]
#   [6 7 7 8 8 5 7 6]
#   [5 6 5 7 7 5 5 8]
#   [7 6 6 8 5 8 8 6]]
#
#  [[8 6 8 7 5 8 5 6]
#   [6 5 8 6 6 6 7 5]
#   [8 5 5 5 8 8 8 7]
#   [6 5 7 5 7 6 7 6]
#   [5 6 7 5 8 6 5 7]
#   [7 6 5 8 8 5 7 8]
#   [6 6 7 6 5 6 7 5]
#   [8 7 8 7 8 5 8 5]]
#
#  [[8 7 6 6 8 5 7 5]
#   [6 5 8 5 6 5 6 7]
#   [5 7 8 8 5 8 6 8]
#   [6 8 5 5 6 5 5 7]
#   [7 8 5 8 6 5 8 7]
#   [7 7 7 5 7 5 6 6]
#   [7 5 8 8 7 5 6 8]
#   [7 5 8 7 6 8 8 6]]
#
#  [[5 5 8 8 6 5 5 5]
#   [8 5 7 7 5 6 8 8]
#   [8 7 6 7 6 5 8 5]
#   [5 5 8 8 5 6 7 5]
#   [6 8 7 8 7 5 7 8]
#   [6 8 7 7 7 6 7 5]
#   [6 5 7 7 5 6 5 5]
#   [7 5 6 6 6 8 6 5]]
#
#  [[5 7 7 5 6 7 5 8]
#   [8 6 5 7 5 6 5 6]
#   [5 5 5 8 5 8 6 8]
#   [6 5 6 7 5 6 6 5]
#   [6 8 8 5 8 5 6 6]
#   [7 6 6 7 6 7 5 8]
#   [7 8 7 6 8 8 6 8]
#   [6 8 6 8 6 7 5 8]]
#
#  [[6 5 5 5 7 5 7 5]
#   [5 6 7 6 6 5 5 6]
#   [6 7 7 7 7 6 5 7]
#   [6 5 8 5 7 6 7 5]
#   [8 7 7 6 8 8 6 6]
#   [8 5 6 6 8 5 6 5]
#   [8 5 5 5 6 8 5 8]
#   [8 6 5 8 7 8 5 6]]]
# Matrix 1
# [[2 1 5 2 2]
#  [1 2 5 2 3]
#  [5 6 3 8 2]
#  [2 3 3 9 3]
#  [7 1 1 5 4]]
# Matrix 2
# [[9 9 9 5 5]
#  [3 6 8 2 3]
#  [1 4 9 8 9]
#  [4 1 8 1 7]
#  [9 9 4 6 1]]
# Result of Multiplication
# [[18  9 45 10 10]
#  [ 3 12 40  4  9]
#  [ 5 24 27 64 18]
#  [ 8  3 24  9 21]
#  [63  9  4 30  4]]
# 70 is the Sum
# The diagonal elements are
# [18 12 27  9  4]

# %% [markdown]
# **Lab 6**
#
# Given 100 random points in 2D space and find the top 10 closest points to the origin.

# %%
import numpy as np
import random
np_arr=np.random.randint(-10,10,(100,2))
print(np_arr)
np.flip(np_arr[np.argsort(np.sqrt(np.sum(np_arr*np_arr,axis=1)))],axis=0)[0:10]
# Out:
# [[-10   0]
#  [ -9   2]
#  [  3   5]
#  [  2  -9]
#  [  7   2]
#  [  8  -7]
#  [  2   7]
#  [  9   5]
#  [  6  -7]
#  [ -9   6]
#  [  0   0]
#  [ -9   2]
#  [-10  -9]
#  [-10  -6]
#  [  1   6]
#  [  7   7]
#  [  2   6]
#  [ -9   3]
#  [  6  -7]
#  [  3   2]
#  [ -5   7]
#  [  4  -8]
#  [  1 -10]
#  [ -5   2]
#  [  0   4]
#  [  2   2]
#  [  6  -4]
#  [ -9  -8]
#  [  1  -7]
#  [ -7   2]
#  [  8   7]
#  [  6  -3]
#  [ -1  -1]
#  [ -6  -6]
#  [ -2  -6]
#  [ -5  -2]
#  [ -3   5]
#  [  6  -8]
#  [ -7  -6]
#  [  4 -10]
#  [  0   9]
#  [  5   1]
#  [  8  -5]
#  [ -1   3]
#  [  1  -6]
#  [ -1 -10]
#  [  2   6]
#  [ -4   2]
#  [  6   3]
#  [  1  -5]
#  [ -9   8]
#  [ -9   8]
#  [ -8  -7]
#  [ -2   1]
#  [  7   9]
#  [ -3   5]
#  [  4  -8]
#  [ -9  -7]
#  [ -9   6]
#  [ -7   5]
#  [ -4  -9]
#  [  6   0]
#  [ -4  -9]
#  [  5  -2]
#  [  6 -10]
#  [  9  -1]
#  [ -3   9]
#  [  8  -5]
#  [ -6  -9]
#  [  3  -9]
#  [ -2   3]
#  [  2  -8]
#  [ -5  -7]
#  [ -2  -3]
#  [ -9   5]
#  [ -3  -4]
#  [ -9   4]
#  [ -3  -4]
#  [  4  -5]
#  [  1   7]
#  [  8  -6]
#  [  6  -4]
#  [  9   7]
#  [  4   3]
#  [ -5  -5]
#  [  5   0]
#  [  2  -2]
#  [ -3   0]
#  [ -3  -9]
#  [ -3  -3]
#  [ -3  -9]
#  [ -3   4]
#  [  7  -5]
#  [ -2  -3]
#  [  1   5]
#  [ -1  -2]
#  [ -7  -7]
#  [ -9  -2]
#  [  8   3]
#  [  5   2]]
# array([[-10,  -9],
#        [ -9,   8],
#        [ -9,  -8],
#        [ -9,   8],
#        [  6, -10],
#        [-10,  -6],
#        [ -9,  -7],
#        [  7,   9],
#        [  9,   7],
#        [ -9,   6]])

# %% [markdown]
# **Lab 7**
#
# Find the value of pi using Monte Carlo simulation.
#
# **Hint:-**
#
# Consider a unit circle which is enclosed in a square. randomly genrate uniformily distributed points inside the square. The fraction of points falling inside the circle is pi/4.

# %%
import numpy as np
import random
np_arr=np.random.randn(100,2)
dist=np.sqrt(np_arr[:,0]**2+np_arr[:,1]**2)
top_10=np.argsort(dist)[:10]

print(np_arr[top_10])
# Out:
# [[ 0.0946664   0.0032542 ]
#  [-0.15607392 -0.08934347]
#  [ 0.05588485  0.2014911 ]
#  [ 0.18901694  0.0898914 ]
#  [ 0.21308974  0.14154959]
#  [ 0.17550582  0.30163914]
#  [-0.40352395  0.0903807 ]
#  [ 0.07251965  0.44607816]
#  [-0.03559049 -0.48706525]
#  [ 0.22433115  0.43486076]]

# %%
import numpy as np
import random
np_arr=np.random.randn(100,2)
print(np_arr)
dist=np.sqrt(np_arr[:,0]**2+np_arr[:,1]**2)
top_10=np.argsort(dist)[:10]

print(np_arr[top_10])
# Out:
# [[-1.92612974 -0.09328773]
#  [-0.52901166 -0.97828576]
#  [-1.78482678  0.42925334]
#  [-0.12020505 -0.20110095]
#  [ 0.32936547 -0.3757049 ]
#  [-0.4230558   0.41441886]
#  [-0.53114321 -0.20679812]
#  [ 0.09613596 -0.61357904]
#  [ 2.01459762  0.93877376]
#  [-0.36471475  0.85668031]
#  [-1.05233885  1.36430964]
#  [ 0.32387442  0.07711322]
#  [-0.00365121 -0.04283876]
#  [-1.17116549 -0.51588349]
#  [-1.51700948  0.32066635]
#  [ 1.07816942 -0.38617258]
#  [-1.24049222 -0.19684017]
#  [ 1.13286034 -1.26661474]
#  [-1.30896619  1.21634221]
#  [ 1.2124246  -0.32030484]
#  [ 0.70970568 -0.07161996]
#  [ 0.67076235  0.38058283]
#  [-1.22580533  1.14623384]
#  [-0.15813279 -0.03582049]
#  [ 1.02856312 -0.17013998]
#  [-0.73949618  2.18843722]
#  [-0.34888752  0.56363229]
#  [-0.96425456  2.23561712]
#  [-0.49290671 -0.93280557]
#  [-0.76498342  0.00801046]
#  [ 0.8958461  -0.6415405 ]
#  [-0.95282384  0.34861762]
#  [ 0.57719051 -0.74852572]
#  [ 1.33844382 -1.66914181]
#  [-0.36268885  1.21239276]
#  [-0.41424712 -0.78678215]
#  [-0.14061244  0.0610066 ]
#  [ 0.29570688  2.50053476]
#  [ 1.14318821 -0.03486477]
#  [ 0.19769981 -1.68549635]
#  [ 0.1174307   1.14770904]
#  [-1.04756764  0.8942507 ]
#  [ 2.12554611  0.12999687]
#  [-0.22268982 -0.47703926]
#  [-0.55020259  0.12719969]
#  [-0.78355696  0.34248161]
#  [ 0.20583297  1.30279516]
#  [ 0.44168339  0.6776204 ]
#  [-1.28700279 -1.76056668]
#  [-0.26593812 -0.07257481]
#  [ 0.69403018  0.86856515]
#  [-1.2737647   0.0744326 ]
#  [ 0.434726   -1.34344749]
#  [ 1.96543991  0.31697887]
#  [-0.34756711  1.37372594]
#  [-1.94181073 -0.64916977]
#  [-0.0494816   0.66954395]
#  [-0.61210437 -0.1973008 ]
#  [ 0.15887442 -2.19517575]
#  [ 1.30777988  0.33581415]
#  [ 0.10262919  0.54412535]
#  [-1.65433139  2.12784806]
#  [-0.7635895   0.2390539 ]
#  [-0.08078777 -1.48534951]
#  [ 0.10697891  0.64412809]
#  [-0.03535809 -0.44070661]
#  [-2.85213954  0.32601449]
#  [-0.78008355 -0.6303393 ]
#  [ 0.38079193  1.03730605]
#  [ 1.29717102  0.44966519]
#  [-0.26226933  1.74406708]
#  [-0.58595562 -0.52212898]
#  [ 0.32720085 -2.07238631]
#  [-0.47280284  0.7095388 ]
#  [-1.53438841  1.24149857]
#  [-0.60918669  0.9669439 ]
#  [-1.37565357 -0.02817351]
#  [-0.35186548  0.29416513]
#  [ 0.30232109 -1.18393071]
#  [-0.60382592  0.10724127]
#  [ 0.53132509 -0.63124205]
#  [-1.3248352   0.64845087]
#  [ 0.39146444  0.63676923]
#  [-0.56996004 -0.01643587]
#  [ 0.34209676 -1.46459056]
#  [-0.43431273  1.40712936]
#  [ 0.38971999  0.4603889 ]
#  [-1.97425349 -1.5289021 ]
#  [-0.31414203  2.57726733]
#  [-0.5130978   0.76773725]
#  [ 0.05420289  0.06300736]
#  [ 0.93001831  0.89482416]
#  [ 0.17041478 -0.39281301]
#  [ 0.59732683  1.47136689]
#  [ 0.37167028 -0.81292679]
#  [ 1.03942404 -0.92898128]
#  [-0.14681141  0.80006898]
#  [-0.32182062 -0.6450661 ]
#  [ 0.07379584  0.11763395]
#  [-1.01453545 -0.86304502]]
# [[-0.00365121 -0.04283876]
#  [ 0.05420289  0.06300736]
#  [ 0.07379584  0.11763395]
#  [-0.14061244  0.0610066 ]
#  [-0.15813279 -0.03582049]
#  [-0.12020505 -0.20110095]
#  [-0.26593812 -0.07257481]
#  [ 0.32387442  0.07711322]
#  [ 0.17041478 -0.39281301]
#  [-0.03535809 -0.44070661]]

# %% [markdown]
# **Home Work**
#
# 1. Swap the first two rows of a random 5x5
# array
# 2. How to get the block-sum of a 16x16 matrix
# (block size is 4x4)?
# 3. Sort an array by the nth column
# 4. Subtract the mean of each row of a matrix
# from each element

# %%
import numpy as np
import random
np_arr=np.random.randint(5,9,(5,5))
print(np_arr)
print('Swapping first two rows')
temp=np_arr[[0]]
np_arr[[0]]=np_arr[[1]]
np_arr[[1]]=temp
print(np_arr) #Answer 1
# Out:
# [[8 8 8 8 6]
#  [8 8 7 7 7]
#  [6 7 8 6 6]
#  [7 5 8 5 8]
#  [6 5 5 5 6]]
# Swapping first two rows
# [[8 8 7 7 7]
#  [8 8 8 8 6]
#  [6 7 8 6 6]
#  [7 5 8 5 8]
#  [6 5 5 5 6]]
