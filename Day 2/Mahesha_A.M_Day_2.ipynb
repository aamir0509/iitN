# %%
import numpy as np
x = np.random.random(5)
print(x)
# Out:
# [0.35865736 0.44460494 0.66643898 0.83822883 0.75540468]

# %%
import numpy as np
z = np.random.randn(100,2)
al = z[np.argsort(np.sqrt(np.sum(z*z,axis=1)))]
np.savez('tmp.npz',xyz=z,c=1)
print(a1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-446bcd58985c> in <module>()
#       3 al = z[np.argsort(np.sqrt(np.sum(z*z,axis=1)))]
#       4 np.savez('tmp.npz',xyz=z,c=1)
# ----> 5 print(a1)
#
# NameError: name 'a1' is not defined

# %%
a = np.load('tmp.npz')

# %%
a['abc']

# %%
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode

def take_photo(filename='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)
  data = eval_js('takePhoto({})'.format(quality))
  binary = b64decode(data.split(',')[1])
  with open(filename, 'wb') as f:
    f.write(binary)
  return filename

# %%
from IPython.display import Image
try:
  filename = take_photo()
  print('Saved to {}'.format(filename))
  
  # Show the image which was just taken.
  display(Image(filename))
except Exception as err:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))

# %% [markdown]
# **Lab 2**
# 1. Remove push access to master branch from your collabortator
# 2. Ask your collaborator to create a new branch
# 3. Push new code changes to that branch
# 4. Create a pull request from that branch to master branch
# 5. Approve and merge the pull request
# 6. Do a git pull and veirfy that you can see the new changes in master branch

# %%
import requests
import pprint
headers = {'Authorization': 'token  b0ed6f9ae2a52284d366d5630d95981f35e69814'}
json ={'body': 'comment from api call', 'path':'index.html'}
r = requests.post('https://api.github.com/repos/mahishgithub/RepoiitkNovMaheshaam/commits/c88fd59732b865e1a34420e15bad8ece8bfc0473',headers = headers,json = json)
r = requests.get('https://api.github.com/user/repos',headers = headers)
pprint.pprint(r.json())
#print(r.text)
#print(r.headers)
#print (r.status_code)
# Out:
# [{'archive_url': 'https://api.github.com/repos/mahishgithub/RepoiitkNovMaheshaam/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/mahishgithub/RepoiitkNovMaheshaam/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/mahishgithub/RepoiitkNovMaheshaam/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/mahishgithub/RepoiitkNovMaheshaam/branches{/branch}',
#   'clone_url': 'https://github.com/mahishgithub/RepoiitkNovMaheshaam.git',
#   'collaborators_url': 'https://api.github.com/repos/mahishgithub/RepoiitkNovMaheshaam/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/mahishgithub/RepoiitkNovMaheshaam/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/mahishgithub/RepoiitkNovMaheshaam/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/mahishgithub/RepoiitkNovMaheshaam/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/mahishgithub/RepoiitkNovMaheshaam/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/mahishgithub/RepoiitkNovMaheshaam/contributors',
#   'created_at': '2019-11-10T06:10:08Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/mahishgithub/RepoiitkNovMaheshaam/deployments',
#   'description': None,
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/mahishgithub/RepoiitkNovMaheshaam/downloads',
#   'events_url': 'https://api.github.com/repos/mahishgithub/RepoiitkNovMaheshaam/events',
#   'fork': False,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/mahishgithub/RepoiitkNovMaheshaam/forks',
#   'full_name': 'mahishgithub/RepoiitkNovMaheshaam',
#   'git_commits_url': 'https://api.github.com/repos/mahishgithub/RepoiitkNovMaheshaam/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/mahishgithub/RepoiitkNovMaheshaam/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/mahishgithub/RepoiitkNovMaheshaam/git/tags{/sha}',
#   'git_url': 'git://github.com/mahishgithub/RepoiitkNovMaheshaam.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/mahishgithub/RepoiitkNovMaheshaam/hooks',
#   'html_url': 'https://github.com/mahishgithub/RepoiitkNovMaheshaam',
#   'id': 220749231,
#   'issue_comment_url': 'https://api.github.com/repos/mahishgithub/RepoiitkNovMaheshaam/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/mahishgithub/RepoiitkNovMaheshaam/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/mahishgithub/RepoiitkNovMaheshaam/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/mahishgithub/RepoiitkNovMaheshaam/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/mahishgithub/RepoiitkNovMaheshaam/labels{/name}',
#   'language': 'HTML',
#   'languages_url': 'https://api.github.com/repos/mahishgithub/RepoiitkNovMaheshaam/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/mahishgithub/RepoiitkNovMaheshaam/merges',
#   'milestones_url': 'https://api.github.com/repos/mahishgithub/RepoiitkNovMaheshaam/milestones{/number}',
#   'mirror_url': None,
#   'name': 'RepoiitkNovMaheshaam',
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyMjA3NDkyMzE=',
#   'notifications_url': 'https://api.github.com/repos/mahishgithub/RepoiitkNovMaheshaam/notifications{?since,all,participating}',
#   'open_issues': 0,
#   'open_issues_count': 0,
#   'owner': {'avatar_url': 'https://avatars1.githubusercontent.com/u/57562064?v=4',
#             'events_url': 'https://api.github.com/users/mahishgithub/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/mahishgithub/followers',
#             'following_url': 'https://api.github.com/users/mahishgithub/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/mahishgithub/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/mahishgithub',
#             'id': 57562064,
#             'login': 'mahishgithub',
#             'node_id': 'MDQ6VXNlcjU3NTYyMDY0',
#             'organizations_url': 'https://api.github.com/users/mahishgithub/orgs',
#             'received_events_url': 'https://api.github.com/users/mahishgithub/received_events',
#             'repos_url': 'https://api.github.com/users/mahishgithub/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/mahishgithub/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/mahishgithub/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/mahishgithub'},
#   'permissions': {'admin': True, 'pull': True, 'push': True},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/mahishgithub/RepoiitkNovMaheshaam/pulls{/number}',
#   'pushed_at': '2019-11-10T06:41:24Z',
#   'releases_url': 'https://api.github.com/repos/mahishgithub/RepoiitkNovMaheshaam/releases{/id}',
#   'size': 1,
#   'ssh_url': 'git@github.com:mahishgithub/RepoiitkNovMaheshaam.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/mahishgithub/RepoiitkNovMaheshaam/stargazers',
#   'statuses_url': 'https://api.github.com/repos/mahishgithub/RepoiitkNovMaheshaam/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/mahishgithub/RepoiitkNovMaheshaam/subscribers',
#   'subscription_url': 'https://api.github.com/repos/mahishgithub/RepoiitkNovMaheshaam/subscription',
#   'svn_url': 'https://github.com/mahishgithub/RepoiitkNovMaheshaam',
#   'tags_url': 'https://api.github.com/repos/mahishgithub/RepoiitkNovMaheshaam/tags',
#   'teams_url': 'https://api.github.com/repos/mahishgithub/RepoiitkNovMaheshaam/teams',
#   'trees_url': 'https://api.github.com/repos/mahishgithub/RepoiitkNovMaheshaam/git/trees{/sha}',
#   'updated_at': '2019-11-10T06:41:25Z',
#   'url': 'https://api.github.com/repos/mahishgithub/RepoiitkNovMaheshaam',
#   'watchers': 0,
#   'watchers_count': 0},
#  {'archive_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/branches{/branch}',
#   'clone_url': 'https://github.com/renuka019/iitkproj_nov.git',
#   'collaborators_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/contributors',
#   'created_at': '2019-11-10T06:10:05Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/deployments',
#   'description': None,
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/downloads',
#   'events_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/events',
#   'fork': False,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/forks',
#   'full_name': 'renuka019/iitkproj_nov',
#   'git_commits_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/git/tags{/sha}',
#   'git_url': 'git://github.com/renuka019/iitkproj_nov.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/hooks',
#   'html_url': 'https://github.com/renuka019/iitkproj_nov',
#   'id': 220749228,
#   'issue_comment_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/labels{/name}',
#   'language': 'HTML',
#   'languages_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/merges',
#   'milestones_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/milestones{/number}',
#   'mirror_url': None,
#   'name': 'iitkproj_nov',
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyMjA3NDkyMjg=',
#   'notifications_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/notifications{?since,all,participating}',
#   'open_issues': 0,
#   'open_issues_count': 0,
#   'owner': {'avatar_url': 'https://avatars1.githubusercontent.com/u/57562111?v=4',
#             'events_url': 'https://api.github.com/users/renuka019/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/renuka019/followers',
#             'following_url': 'https://api.github.com/users/renuka019/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/renuka019/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/renuka019',
#             'id': 57562111,
#             'login': 'renuka019',
#             'node_id': 'MDQ6VXNlcjU3NTYyMTEx',
#             'organizations_url': 'https://api.github.com/users/renuka019/orgs',
#             'received_events_url': 'https://api.github.com/users/renuka019/received_events',
#             'repos_url': 'https://api.github.com/users/renuka019/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/renuka019/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/renuka019/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/renuka019'},
#   'permissions': {'admin': False, 'pull': True, 'push': True},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/pulls{/number}',
#   'pushed_at': '2019-11-10T06:45:51Z',
#   'releases_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/releases{/id}',
#   'size': 0,
#   'ssh_url': 'git@github.com:renuka019/iitkproj_nov.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/stargazers',
#   'statuses_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/subscribers',
#   'subscription_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/subscription',
#   'svn_url': 'https://github.com/renuka019/iitkproj_nov',
#   'tags_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/tags',
#   'teams_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/teams',
#   'trees_url': 'https://api.github.com/repos/renuka019/iitkproj_nov/git/trees{/sha}',
#   'updated_at': '2019-11-10T06:45:53Z',
#   'url': 'https://api.github.com/repos/renuka019/iitkproj_nov',
#   'watchers': 0,
#   'watchers_count': 0}]

# %%
import numpy as np
x= [1,2,3,4]
y = np.array(x)
print (y)
# Out:
# [1 2 3 4]

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# **Lab 3**
# 1. Use python requests to post a comment on your commit
# 2. Use python requests to find top 10 commiters on django repo

# %% [markdown]
# **Lab 4**
# 1. Create a 8x8x8 array with random values
# 2. From the matrix in (1) Negate all elements
# whose values are between 3 to 8
# 3. Multiply a 8x3 matrix by 3x2 matrix and
# prints the columns as 1 D array

# %%
coordin = np.random.randn(100,2)
dist = np.sqrt(coordin[:,0]**2+coordin[:,1]**2)
top10 = np.argsort(dist)[:,10]
print(coordin[top10])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-85e83850511a> in <module>()
#       1 coordin = np.random.randn(100,2)
#       2 dist = np.sqrt(coordin[:,0]**2+coordin[:,1]**2)
# ----> 3 top10 = np.argsort(dist)[:,10]
#       4 print(coordin[top10])
#
# IndexError: too many indices for array

# %% [markdown]
# **Lab 5**
#
# 1. Create a 8x8x8 matrix with random values ranging from 5 to 9
# 2. Find the diagonal of product of two random 5x5 matrices
# 3. Negate a boolean, or to change the the sign of the float inplace

# %% [markdown]
# **Lab 6**
#
# Given 100 random points in 2D space and find the top 10 closest points to the origin.

# %% [markdown]
# **Lab 7**
#
# Find the value of pi using Monte Carlo simulation.
#
# **Hint:-**
#
# Consider a unit circle which is enclosed in a square. randomly genrate uniformily distributed points inside the square. The fraction of points falling inside the circle is pi/4.

# %% [markdown]
# **Home Work**
#
# 1. wap the first two rows of a random 5x5
# array
# 2. How to get the block-sum of a 16x16 matrix
# (block size is 4x4)?
# 3. Sort an array by the nth column
# 4. Subtract the mean of each row of a matrix
# from each element
