# %% [markdown]
# **Lab 1**
# 1. Use git init to create an empty repo
# 2. Add a file to local repo and push to github
# 3. Make additional changes to same file, again push to github
# 4. Add a collaborator to your repo
# 5. Ask you collaborator to make change to the file and push to repo
# 6. You try to make a diff change at the same place in the file and push to repo
# 7. Step6 will fail, Fix merge conflicts and push again
# 8. Verify all the commits in github
# 9. Revert code to previous version

# %% [markdown]
# **Lab 2**
# 1. Remove push access to master branch from your collabortator
# 2. Ask your collaborator to create a new branch
# 3. Push new code changes to that branch
# 4. Create a pull request from that branch to master branch
# 5. Approve and merge the pull request
# 6. Do a git pull and veirfy that you can see the new changes in master branch

# %% [markdown]
# **Lab 3**
# 1. Use python requests to post a comment on your commit
# 2. Use python requests to find top 10 commiters on django repo

# %% [markdown]
# **Lab 4**
# 1. Create a 8x8x8 array with random values
# 2. From the matrix in (1) Negate all elements
# whose values are between 3 to 8
# 3. Multiply a 8x3 matrix by 3x2 matrix and
# prints the columns as 1 D array

# %% [markdown]
# **Lab 5**
#
# 1. Create a 8x8x8 matrix with random values ranging from 5 to 9
# 2. Find the diagonal of product of two random 5x5 matrices
# 3. Negate a boolean, or to change the the sign of the float inplace

# %% [markdown]
# **Lab 6**
#
# Given 100 random points in 2D space and find the top 10 closest points to the origin.

# %% [markdown]
# **Lab 7**
#
# Find the value of pi using Monte Carlo simulation.
#
# **Hint:-**
#
# Consider a unit circle which is enclosed in a square. randomly genrate uniformily distributed points inside the square. The fraction of points falling inside the circle is pi/4.

# %%
from __future__ import division
import numpy

n = 1000000

data = numpy.random.uniform(0, 1, size=(n, 2))


inside = len(
    numpy.argwhere(
        numpy.linalg.norm(data, axis=1) < 1
    )
)

print(inside / n * 4)
# Out:
# 3.141436

# %% [markdown]
# **Home Work**
#
# 1. wap the first two rows of a random 5x5
# array
# 2. How to get the block-sum of a 16x16 matrix
# (block size is 4x4)?
# 3. Sort an array by the nth column
# 4. Subtract the mean of each row of a matrix
# from each element

# %%
import numpy as np
z=np.random.randn(100,2)
a1=z[np.argsort(np.sqrt(np.sum(z*z,axis=1)))]
np.savez('tmp.npz',xyz=z,abc=a1)
a=np.load('tmp.npz')
a['abc']
# Out:
# array([[-6.62965292e-03,  6.07226585e-02],
#        [-1.04939203e-01, -3.32643036e-02],
#        [-8.75075856e-02,  8.12031537e-02],
#        [-4.09683942e-02, -1.73785401e-01],
#        [-1.82955784e-01,  5.58937616e-02],
#        [-5.36304464e-02,  2.37323773e-01],
#        [ 1.74810195e-01, -1.95605544e-01],
#        [-8.39803368e-02, -2.49010174e-01],
#        [ 2.92708635e-01, -1.65683627e-02],
#        [ 2.73603160e-01,  1.40239719e-01],
#        [ 2.58373886e-01,  2.44431899e-01],
#        [ 2.06634074e-01, -3.18432564e-01],
#        [ 3.70721391e-01,  1.40738906e-01],
#        [-4.31509380e-01, -1.11264288e-01],
#        [-1.13227184e-01, -4.46210606e-01],
#        [ 4.89308236e-01, -2.53113495e-02],
#        [-4.38687367e-01, -2.26077329e-01],
#        [ 3.61597056e-01, -3.61641973e-01],
#        [ 4.87656932e-01,  2.23704349e-01],
#        [ 4.57607117e-01,  3.11234907e-01],
#        [ 6.93760500e-02,  5.74656602e-01],
#        [ 5.56963538e-01,  1.70326326e-01],
#        [ 2.04616815e-01,  5.52523760e-01],
#        [-6.67191452e-02, -5.92160805e-01],
#        [-6.10077491e-01,  6.89103275e-02],
#        [-6.25959572e-01,  3.67708235e-02],
#        [ 4.21988832e-01, -4.66906910e-01],
#        [-3.79888997e-01,  5.07709781e-01],
#        [-2.27530754e-01, -6.05165920e-01],
#        [-3.39367899e-01,  5.65528252e-01],
#        [ 3.54806161e-01,  6.05661989e-01],
#        [-2.66026991e-01, -6.70020480e-01],
#        [-7.11622504e-01, -1.64089952e-01],
#        [ 7.35607710e-01, -2.55755684e-02],
#        [-1.26594409e-01,  7.28385434e-01],
#        [ 1.58915041e-01,  7.31921464e-01],
#        [-4.30748125e-01,  6.36164913e-01],
#        [ 6.00464533e-01,  5.07145600e-01],
#        [-1.53900931e-01,  7.80822253e-01],
#        [-7.17326986e-01, -4.11284743e-01],
#        [-5.52459454e-02, -8.25931495e-01],
#        [ 4.89585936e-01,  6.75129618e-01],
#        [-4.45023365e-01,  7.18830752e-01],
#        [ 8.38391751e-01,  1.87928290e-01],
#        [-8.68167899e-01,  7.96032630e-02],
#        [ 8.32653593e-01, -3.69901061e-01],
#        [ 9.44358929e-01,  2.20791616e-03],
#        [-7.80166251e-01, -7.19828510e-01],
#        [-5.41523373e-01,  9.45674403e-01],
#        [-1.32840656e-01, -1.10217640e+00],
#        [ 3.31543728e-01,  1.12260211e+00],
#        [-1.13031846e+00, -3.85019561e-01],
#        [-1.18910355e+00, -1.69114602e-01],
#        [ 9.01339405e-01, -7.96950791e-01],
#        [-9.39918429e-01,  7.54710931e-01],
#        [-1.21074905e+00,  1.39506724e-01],
#        [-1.10316161e+00,  5.36054259e-01],
#        [-7.38278763e-01, -9.94636168e-01],
#        [-6.18543779e-01,  1.08372704e+00],
#        [ 3.61104672e-01, -1.22289088e+00],
#        [ 1.22842380e+00,  3.66874122e-01],
#        [-3.04061423e-01,  1.24602689e+00],
#        [-8.02909253e-01, -1.04563953e+00],
#        [-1.07845221e+00,  8.68816052e-01],
#        [-2.71131109e-01, -1.38098057e+00],
#        [-1.37402152e+00, -5.06606384e-01],
#        [ 8.78359521e-01, -1.20382428e+00],
#        [ 1.04129334e+00,  1.08685533e+00],
#        [-6.35294224e-01, -1.36786508e+00],
#        [ 5.57757078e-04, -1.52953650e+00],
#        [ 1.60356547e-01,  1.53102095e+00],
#        [ 1.16473859e+00, -1.02455789e+00],
#        [ 9.38156683e-02, -1.56841429e+00],
#        [ 1.22342849e+00, -9.98132417e-01],
#        [-1.13167585e+00,  1.14862519e+00],
#        [-1.60586978e+00, -2.70454842e-01],
#        [-1.20120939e+00, -1.18104438e+00],
#        [-1.37214305e-01, -1.68101414e+00],
#        [-1.25446408e+00,  1.18204457e+00],
#        [-7.12403394e-02,  1.72922998e+00],
#        [ 4.26457972e-01, -1.73822392e+00],
#        [-6.68138346e-01, -1.67337490e+00],
#        [-1.61656624e-01,  1.80131925e+00],
#        [-8.25614023e-01, -1.61998298e+00],
#        [ 9.86828157e-01, -1.60798799e+00],
#        [ 1.83403456e+00, -4.43949412e-01],
#        [-3.46201346e-01,  1.91326540e+00],
#        [ 1.72966103e+00,  1.02403740e+00],
#        [ 1.78399343e+00, -9.29105104e-01],
#        [-1.60422442e+00, -1.22099748e+00],
#        [-1.47075551e+00,  1.38893302e+00],
#        [ 1.01955040e+00,  1.77700484e+00],
#        [-1.82493307e+00, -9.53648000e-01],
#        [-9.99608213e-01, -1.84400542e+00],
#        [-1.92072200e+00,  1.24103312e+00],
#        [-9.04643255e-01,  2.13571203e+00],
#        [-5.42592562e-02,  2.32654622e+00],
#        [ 1.67949814e+00, -1.72574115e+00],
#        [-7.13173747e-01,  2.51675666e+00],
#        [-1.45893171e+00, -3.02229429e+00]])
