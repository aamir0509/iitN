# %% [markdown]
# **Lab 1**
# 1. Use git init to create an empty repo
# 2. Add a file to local repo and push to github
# 3. Make additional changes to same file, again push to github
# 4. Add a collaborator to your repo
# 5. Ask you collaborator to make change to the file and push to repo
# 6. You try to make a diff change at the same place in the file and push to repo
# 7. Step6 will fail, Fix merge conflicts and push again
# 8. Verify all the commits in github
# 9. Revert code to previous version

# %% [markdown]
# **Lab 2**
# 1. Remove push access to master branch from your collabortator
# 2. Ask your collaborator to create a new branch
# 3. Push new code changes to that branch
# 4. Create a pull request from that branch to master branch
# 5. Approve and merge the pull request
# 6. Do a git pull and veirfy that you can see the new changes in master branch

# %% [markdown]
# **Lab 3**
# 1. Use python requests to post a comment on your commit
# 2. Use python requests to find top 10 commiters on django repo

# %% [markdown]
# **Lab 4**
# 1. Create a 8x8x8 array with random values
# 2. From the matrix in (1) Negate all elements
# whose values are between 3 to 8
# 3. Multiply a 8x3 matrix by 3x2 matrix and
# prints the columns as 1 D array

# %%
import numpy as np
z= np.random.randint(10,20,(8,8,8))
print (z)
# Out:
# array([[[17, 19, 19, 10, 18, 16, 11, 14],
#         [11, 15, 12, 19, 15, 10, 14, 17],
#         [16, 15, 15, 10, 11, 14, 19, 14],
#         [19, 13, 19, 14, 17, 16, 16, 19],
#         [14, 19, 13, 10, 16, 18, 17, 12],
#         [18, 18, 15, 17, 15, 18, 19, 14],
#         [13, 15, 17, 11, 17, 16, 15, 16],
#         [16, 18, 15, 12, 14, 12, 19, 11]],
#
#        [[12, 16, 19, 16, 10, 14, 15, 19],
#         [19, 12, 13, 17, 17, 10, 12, 19],
#         [15, 19, 19, 17, 12, 18, 15, 14],
#         [11, 17, 11, 13, 11, 11, 19, 19],
#         [10, 12, 10, 11, 13, 18, 11, 11],
#         [10, 10, 13, 16, 13, 18, 10, 11],
#         [16, 12, 17, 12, 11, 19, 12, 14],
#         [16, 17, 16, 14, 13, 16, 13, 13]],
#
#        [[19, 14, 10, 18, 14, 18, 18, 13],
#         [19, 16, 11, 18, 16, 18, 18, 11],
#         [16, 11, 18, 12, 10, 17, 17, 13],
#         [19, 12, 10, 15, 18, 18, 15, 18],
#         [15, 18, 15, 13, 17, 10, 11, 16],
#         [16, 12, 17, 10, 16, 15, 16, 12],
#         [18, 13, 12, 17, 15, 11, 13, 14],
#         [16, 11, 16, 16, 14, 18, 19, 17]],
#
#        [[14, 16, 16, 12, 11, 19, 13, 17],
#         [10, 15, 13, 16, 16, 19, 19, 16],
#         [18, 19, 13, 18, 18, 19, 19, 18],
#         [14, 10, 16, 13, 19, 18, 15, 18],
#         [19, 19, 15, 14, 11, 11, 17, 13],
#         [13, 10, 10, 19, 16, 18, 13, 13],
#         [11, 14, 14, 17, 11, 12, 10, 15],
#         [14, 15, 18, 17, 11, 12, 14, 11]],
#
#        [[11, 16, 12, 12, 19, 13, 16, 18],
#         [14, 11, 18, 12, 19, 16, 18, 19],
#         [16, 19, 12, 11, 19, 19, 14, 11],
#         [10, 12, 14, 11, 12, 17, 12, 14],
#         [13, 11, 10, 18, 14, 16, 12, 12],
#         [11, 16, 19, 15, 14, 15, 10, 12],
#         [11, 12, 16, 19, 17, 18, 14, 13],
#         [18, 12, 14, 15, 14, 10, 17, 16]],
#
#        [[15, 17, 19, 11, 10, 19, 10, 17],
#         [19, 13, 13, 12, 17, 10, 12, 14],
#         [19, 10, 10, 12, 18, 14, 14, 11],
#         [15, 16, 12, 10, 10, 14, 18, 11],
#         [17, 14, 18, 14, 10, 15, 17, 17],
#         [13, 17, 18, 19, 14, 12, 13, 13],
#         [13, 10, 15, 10, 11, 12, 11, 16],
#         [18, 12, 14, 12, 13, 14, 16, 15]],
#
#        [[18, 13, 11, 14, 17, 17, 13, 13],
#         [18, 17, 16, 10, 18, 15, 14, 17],
#         [10, 17, 12, 11, 15, 12, 17, 17],
#         [16, 11, 16, 18, 17, 14, 15, 11],
#         [15, 19, 18, 10, 11, 10, 16, 13],
#         [16, 10, 10, 13, 13, 17, 12, 18],
#         [14, 16, 11, 16, 15, 12, 15, 14],
#         [13, 19, 16, 10, 18, 17, 16, 18]],
#
#        [[18, 11, 16, 17, 11, 13, 13, 17],
#         [14, 13, 18, 15, 11, 12, 17, 10],
#         [13, 10, 10, 10, 16, 18, 16, 12],
#         [14, 17, 16, 12, 14, 12, 10, 12],
#         [16, 18, 14, 19, 17, 13, 19, 19],
#         [17, 10, 11, 11, 13, 19, 16, 14],
#         [16, 14, 12, 10, 19, 18, 19, 19],
#         [19, 17, 17, 18, 19, 19, 16, 17]]])

# %%
import numpy as np
a=np.random.randint(1,10,(5,5,5))
#print(a)
mask=(a>3)&(a<9)
a[mask]=-1*a[mask]
print(a)
# Out:
# [[[-7 -4 -7 -5 -5]
#   [-5  3 -6 -5  9]
#   [ 2  9 -8 -7 -8]
#   [-8  2  9 -5  2]
#   [ 1 -7 -7  1 -5]]
#
#  [[-6 -6 -5  3 -6]
#   [ 3  3 -7  2  2]
#   [ 3 -8 -8 -5 -4]
#   [ 1  9 -6  1  3]
#   [-4  3 -4  3  1]]
#
#  [[-7  9  1 -6  2]
#   [ 2  3 -4 -6 -7]
#   [ 2  9  3 -7  9]
#   [-5  3 -5 -4 -8]
#   [-4 -5 -5 -5  1]]
#
#  [[ 2 -6  9 -7  1]
#   [-6 -4 -4  9  1]
#   [ 9 -7 -8  2 -5]
#   [-4  1  2  1 -8]
#   [-7 -5 -5  3  2]]
#
#  [[-4 -8 -8 -5 -4]
#   [ 2  9  2 -4 -5]
#   [ 3  2 -4  2  1]
#   [ 1 -8  3 -7  3]
#   [-8 -6  3  1  9]]]

# %%
import numpy as np
a=np.random.randint(1,10,(8,3))
b=np.random.randint(1,10,(3,2))
np.dot(a,b)
# Out:
# array([[ 31,  26],
#        [109,  64],
#        [109,  64],
#        [ 71,  46],
#        [ 66,  36],
#        [ 67,  47],
#        [109,  64],
#        [106,  71]])

# %% [markdown]
# **Lab 5**
#
# 1. Create a 8x8x8 matrix with random values ranging from 5 to 9
# 2. Find the diagonal of product of two random 5x5 matrices
# 3. Negate a boolean, or to change the the sign of the float inplace

# %%
import numpy as np
z=np.random.randint(5,10,(8,8))
print (z)
# Out:
# [[5 7 5 6 5 8 5 9]
#  [5 9 6 7 5 7 8 6]
#  [5 9 7 6 7 8 8 5]
#  [6 7 7 8 8 5 5 5]
#  [6 9 8 5 6 9 7 7]
#  [8 7 7 8 6 8 6 9]
#  [5 9 9 7 5 9 5 5]
#  [9 8 8 5 9 9 6 6]]

# %% [markdown]
# from the matirx in i negate all elements whose values are between 3 to 8

# %% [markdown]
# **Lab 6**
#
# Given 100 random points in 2D space and find the top 10 closest points to the origin.

# %%
z = np.random.randn(100,2)
z.shape
z[np.argsort(np.sqrt(np.sum(z*z,axis=1)
#        [ 1.10125148e-01, -1.37976254e+00],
#        [-3.31049921e-01,  1.42870504e+00],
#        [ 1.47715296e+00, -1.28885617e-01],
#        [ 1.14979148e+00,  9.44006219e-01],
#        [-1.26351106e-01, -1.48614165e+00],
#        [-1.05897362e+00,  1.05214020e+00],
#        [ 1.19555262e-03, -1.52999385e+00],
#        [-1.31229060e+00,  8.36473402e-01],
#        [-1.57506314e+00, -4.71113445e-02],
#        [-3.62272673e-01,  1.55077934e+00],
#        [-1.57510942e+00, -3.38313979e-01],
#        [ 1.00094405e+00, -1.30092666e+00],
#        [-1.67566847e+00,  1.69368916e-01],
#        [-1.63104759e+00, -5.85528351e-01],
#        [ 1.67346946e+00, -5.93560547e-01],
#        [ 1.80606435e+00,  1.20455662e-01],
#        [ 8.69736450e-01, -1.60382594e+00],
#        [ 1.29308431e+00,  1.28728032e+00],
#        [ 3.09114100e-01,  1.81338647e+00],
#        [ 1.01331577e+00,  1.56074715e+00],
#        [-1.65636534e+00, -8.59939230e-01],
#        [ 7.28572457e-01,  1.83764663e+00],
#        [ 1.64201784e+00,  1.16897590e+00],
#        [-5.63110897e-01, -1.97880489e+00],
#        [-1.20432080e+00, -1.73275187e+00],
#        [-2.04758471e+00, -6.16902090e-01],
#        [-1.73556912e+00,  1.28503980e+00],
#        [-1.02751393e+00, -1.90392601e+00],
#        [ 1.97489020e-01, -2.15774609e+00],
#        [-1.55870988e+00, -1.66337924e+00],
#        [-1.43171224e+00,  1.78914673e+00],
#        [ 1.90471537e+00,  1.35250091e+00],
#        [ 6.50928791e-01, -2.25845799e+00],
#        [ 2.16903778e+00,  9.50850107e-01],
#        [-9.83996682e-01, -2.18534592e+00],
#        [-2.12658069e+00, -1.13411401e+00],
#        [-2.00871336e+00, -1.60490959e+00],
#        [ 8.61619952e-02,  2.57006370e+00],
#        [-1.68411824e+00,  1.97674030e+00],
#        [-1.31437303e+00, -2.58510175e+00]])

# %%
coordinates=np.random.randn(100,2)
dist=np.sqrt(coordinates[:,0]**2+coordinates[:,1]**2)
top_10=np.argsort(dist)[:10]
print(coordinates[top_10])
# Out:
# [[-0.15345311  0.07860903]
#  [-0.1329245  -0.20228713]
#  [ 0.26704888 -0.11482799]
#  [-0.18224342 -0.30833749]
#  [ 0.37188739  0.1681012 ]
#  [-0.08556723 -0.43969702]
#  [-0.46159866  0.1114483 ]
#  [ 0.05711587 -0.47530331]
#  [ 0.472643   -0.10924007]
#  [-0.50319152  0.04753937]]

# %% [markdown]
# **Lab 7**
#
# Find the value of pi using Monte Carlo simulation.
#
# **Hint:-**
#
# Consider a unit circle which is enclosed in a square. randomly genrate uniformily distributed points inside the square. The fraction of points falling inside the circle is pi/4.

# %%
from numpy import random, sqrt, pi
n=int(input("number of iterations"))
p=random.rand(n,2)
idx=sqrt((p[:,0]**2)+(p[:,1]**2))
print(sum(idx)/n*4,"result")
print (pi,"real value")
# Out:
# number of iterations1000
# 3.0937140030166277 result
# 3.141592653589793 real value

# %% [markdown]
# **Home Work**
#
# 1. wap the first two rows of a random 5x5
# array
# 2. How to get the block-sum of a 16x16 matrix
# (block size is 4x4)?
# 3. Sort an array by the nth column
# 4. Subtract the mean of each row of a matrix
# from each element
