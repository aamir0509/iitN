# %% [markdown]
# **Lab 2**
# 1. Remove push access to master branch from your collabortator
# 2. Ask your collaborator to create a new branch
# 3. Push new code changes to that branch
# 4. Create a pull request from that branch to master branch
# 5. Approve and merge the pull request
# 6. Do a git pull and veirfy that you can see the new changes in master branch

# %%
import requests
import pprint
headers = {'Authorization': 'token 3358494ea76c4a2125edd52ff3a1544631c9896a'}
json = {'body': 'comment from api call','path':'index.html'}
r = requests.post('https://api.github.com/repos/pythonwithda/iitknov/commits/5968f469ac7faf5d5046b827369aaa1da3a8dfee/comments', headers=headers, json=json)
pprint.pprint(r.json())
# Out:
# {'author_association': 'OWNER',
#  'body': 'comment from api call',
#  'commit_id': '5968f469ac7faf5d5046b827369aaa1da3a8dfee',
#  'created_at': '2019-11-10T09:33:59Z',
#  'html_url': 'https://github.com/pythonwithda/iitknov/commit/5968f469ac7faf5d5046b827369aaa1da3a8dfee#commitcomment-35883066',
#  'id': 35883066,
#  'line': None,
#  'node_id': 'MDEzOkNvbW1pdENvbW1lbnQzNTg4MzA2Ng==',
#  'path': 'index.html',
#  'position': None,
#  'updated_at': '2019-11-10T09:33:59Z',
#  'url': 'https://api.github.com/repos/pythonwithda/iitknov/comments/35883066',
#  'user': {'avatar_url': 'https://avatars0.githubusercontent.com/u/57561906?v=4',
#           'events_url': 'https://api.github.com/users/pythonwithda/events{/privacy}',
#           'followers_url': 'https://api.github.com/users/pythonwithda/followers',
#           'following_url': 'https://api.github.com/users/pythonwithda/following{/other_user}',
#           'gists_url': 'https://api.github.com/users/pythonwithda/gists{/gist_id}',
#           'gravatar_id': '',
#           'html_url': 'https://github.com/pythonwithda',
#           'id': 57561906,
#           'login': 'pythonwithda',
#           'node_id': 'MDQ6VXNlcjU3NTYxOTA2',
#           'organizations_url': 'https://api.github.com/users/pythonwithda/orgs',
#           'received_events_url': 'https://api.github.com/users/pythonwithda/received_events',
#           'repos_url': 'https://api.github.com/users/pythonwithda/repos',
#           'site_admin': False,
#           'starred_url': 'https://api.github.com/users/pythonwithda/starred{/owner}{/repo}',
#           'subscriptions_url': 'https://api.github.com/users/pythonwithda/subscriptions',
#           'type': 'User',
#           'url': 'https://api.github.com/users/pythonwithda'}}

# %% [markdown]
# **Lab 1**
# 1. Use git init to create an empty repo
# 2. Add a file to local repo and push to github
# 3. Make additional changes to same file, again push to github
# 4. Add a collaborator to your repo
# 5. Ask you collaborator to make change to the file and push to repo
# 6. You try to make a diff change at the same place in the file and push to repo
# 7. Step6 will fail, Fix merge conflicts and push again
# 8. Verify all the commits in github
# 9. Revert code to previous version

# %% [markdown]
# **Lab 3**
# 1. Use python requests to post a comment on your commit
# 2. Use python requests to find top 10 commiters on django repo

# %% [markdown]
# **Lab 4**
# 1. Create a 8x8x8 array with random values
# 2. From the matrix in (1) Negate all elements
# whose values are between 3 to 8
# 3. Multiply a 8x3 matrix by 3x2 matrix and
# prints the columns as 1 D array

# %%
import numpy as np  
arr = np.random.randint(1,10,(8,8,8))
print(arr)
# Out:
# [[[4 4 9 1 1 1 9 4]
#   [9 4 8 2 3 8 1 3]
#   [1 7 1 5 5 5 6 3]
#   [2 9 7 4 8 2 2 2]
#   [1 3 4 7 2 2 3 2]
#   [1 6 9 1 5 2 6 3]
#   [5 6 9 7 8 1 1 2]
#   [9 4 2 2 1 3 1 3]]
#
#  [[3 3 2 3 4 4 6 3]
#   [6 9 6 5 8 8 8 7]
#   [8 5 4 4 1 7 9 1]
#   [6 5 5 9 8 5 4 8]
#   [4 3 7 2 2 4 5 6]
#   [4 4 7 8 1 9 9 7]
#   [4 8 2 4 5 3 2 8]
#   [2 7 1 6 5 1 1 4]]
#
#  [[8 7 6 2 9 8 8 5]
#   [3 5 8 8 6 4 6 1]
#   [1 5 3 8 3 5 3 4]
#   [5 9 1 6 1 1 1 4]
#   [8 3 2 9 4 9 4 8]
#   [8 9 4 6 9 5 8 2]
#   [7 8 5 9 4 4 4 2]
#   [8 3 6 1 6 8 8 6]]
#
#  [[7 3 4 4 1 2 2 7]
#   [2 9 7 6 1 7 6 1]
#   [2 3 9 2 1 6 7 9]
#   [1 3 2 8 2 3 5 8]
#   [2 3 2 7 5 3 2 1]
#   [4 1 8 6 1 7 7 3]
#   [9 9 2 3 9 6 8 9]
#   [1 2 3 7 5 1 7 8]]
#
#  [[3 4 3 9 3 2 6 7]
#   [2 4 9 1 5 4 8 5]
#   [7 5 7 7 6 7 8 3]
#   [9 8 6 9 4 6 8 5]
#   [5 5 5 9 5 2 8 3]
#   [6 9 9 2 9 8 8 7]
#   [4 7 6 2 6 2 9 9]
#   [5 8 9 6 5 6 1 2]]
#
#  [[9 7 2 5 9 3 8 1]
#   [5 7 5 5 1 5 1 4]
#   [7 1 1 8 2 2 8 2]
#   [9 9 8 4 3 4 1 3]
#   [9 7 6 4 3 9 5 7]
#   [3 5 1 4 2 4 9 5]
#   [8 4 3 4 9 5 9 8]
#   [3 4 1 6 4 7 7 9]]
#
#  [[6 7 8 5 1 9 9 8]
#   [1 6 7 4 2 4 8 6]
#   [1 4 5 7 8 3 5 9]
#   [7 7 4 3 6 5 2 8]
#   [2 7 1 6 5 4 3 9]
#   [7 7 2 9 7 7 8 4]
#   [5 5 1 9 2 9 9 6]
#   [1 6 3 3 4 1 3 5]]
#
#  [[4 8 4 7 8 2 9 4]
#   [5 6 6 9 7 1 3 7]
#   [9 8 3 2 5 3 7 3]
#   [7 1 6 3 5 6 3 2]
#   [5 6 2 2 3 8 5 3]
#   [2 3 4 3 4 9 9 9]
#   [8 3 5 4 8 3 7 2]
#   [9 9 3 9 8 8 9 7]]]

# %%
import numpy as np
a = np.random.randint(1,10,(8,8,8))
print(a)
mask=(a>3)&(a<8)
a[mask]=-1*a[mask]
print(a)
# Out:
# [[[7 6 7 3 1 1 9 5]
#   [1 6 5 2 4 7 1 2]
#   [4 2 6 7 5 6 9 1]
#   [4 7 7 6 1 3 1 9]
#   [2 6 8 8 3 6 8 9]
#   [8 7 8 4 7 5 4 5]
#   [6 9 8 2 4 3 6 5]
#   [4 8 9 3 1 6 5 7]]
#
#  [[6 6 8 5 3 5 6 9]
#   [7 6 6 1 7 1 7 7]
#   [8 9 6 5 8 4 7 7]
#   [4 9 1 8 3 5 6 7]
#   [3 9 4 8 6 6 7 9]
#   [6 1 5 5 4 6 8 1]
#   [1 3 5 6 2 4 8 7]
#   [8 5 3 4 2 3 7 5]]
#
#  [[2 9 9 5 7 9 5 1]
#   [9 7 2 3 6 4 1 8]
#   [1 1 4 5 9 2 4 6]
#   [2 8 6 2 1 6 4 3]
#   [5 3 2 1 2 7 3 2]
#   [2 4 1 1 6 8 7 8]
#   [6 1 7 1 3 3 5 8]
#   [8 9 6 7 7 9 1 9]]
#
#  [[4 5 6 1 3 8 9 5]
#   [6 5 1 3 5 6 7 1]
#   [4 9 7 3 1 9 9 1]
#   [2 9 4 7 3 7 9 8]
#   [4 7 4 4 8 1 3 4]
#   [1 4 3 8 3 2 4 3]
#   [5 1 2 2 8 8 7 4]
#   [3 5 3 2 5 3 3 8]]
#
#  [[7 4 9 9 4 5 2 2]
#   [1 5 9 2 8 9 9 3]
#   [5 5 7 2 6 5 4 2]
#   [8 2 2 1 7 1 9 3]
#   [2 9 8 1 3 7 6 9]
#   [1 6 3 6 3 7 7 2]
#   [8 6 9 1 3 3 4 2]
#   [6 6 6 8 6 1 6 9]]
#
#  [[1 2 2 2 7 4 5 5]
#   [9 6 4 6 9 4 5 2]
#   [6 6 3 7 9 4 4 2]
#   [4 5 7 1 4 4 3 4]
#   [2 1 1 1 4 3 7 5]
#   [5 2 7 6 3 8 3 3]
#   [9 1 2 9 8 4 4 3]
#   [9 1 8 8 1 5 1 2]]
#
#  [[2 1 2 6 4 3 5 3]
#   [8 2 3 9 9 5 9 7]
#   [9 5 2 7 7 6 8 7]
#   [5 5 5 2 2 6 1 1]
#   [2 4 6 6 5 7 1 1]
#   [2 6 3 8 7 2 9 8]
#   [1 8 8 4 4 2 7 5]
#   [4 9 4 4 4 7 9 7]]
#
#  [[8 7 8 3 1 4 9 7]
#   [8 3 6 9 4 4 5 3]
#   [4 5 9 6 8 8 1 3]
#   [9 3 9 3 8 3 7 3]
#   [6 9 2 9 6 4 2 8]
#   [9 4 5 3 4 5 8 6]
#   [8 9 2 1 4 9 9 3]
#   [3 7 7 2 1 7 6 4]]]
# [[[-7 -6 -7  3  1  1  9 -5]
#   [ 1 -6 -5  2 -4 -7  1  2]
#   [-4  2 -6 -7 -5 -6  9  1]
#   [-4 -7 -7 -6  1  3  1  9]
#   [ 2 -6  8  8  3 -6  8  9]
#   [ 8 -7  8 -4 -7 -5 -4 -5]
#   [-6  9  8  2 -4  3 -6 -5]
#   [-4  8  9  3  1 -6 -5 -7]]
#
#  [[-6 -6  8 -5  3 -5 -6  9]
#   [-7 -6 -6  1 -7  1 -7 -7]
#   [ 8  9 -6 -5  8 -4 -7 -7]
#   [-4  9  1  8  3 -5 -6 -7]
#   [ 3  9 -4  8 -6 -6 -7  9]
#   [-6  1 -5 -5 -4 -6  8  1]
#   [ 1  3 -5 -6  2 -4  8 -7]
#   [ 8 -5  3 -4  2  3 -7 -5]]
#
#  [[ 2  9  9 -5 -7  9 -5  1]
#   [ 9 -7  2  3 -6 -4  1  8]
#   [ 1  1 -4 -5  9  2 -4 -6]
#   [ 2  8 -6  2  1 -6 -4  3]
#   [-5  3  2  1  2 -7  3  2]
#   [ 2 -4  1  1 -6  8 -7  8]
#   [-6  1 -7  1  3  3 -5  8]
#   [ 8  9 -6 -7 -7  9  1  9]]
#
#  [[-4 -5 -6  1  3  8  9 -5]
#   [-6 -5  1  3 -5 -6 -7  1]
#   [-4  9 -7  3  1  9  9  1]
#   [ 2  9 -4 -7  3 -7  9  8]
#   [-4 -7 -4 -4  8  1  3 -4]
#   [ 1 -4  3  8  3  2 -4  3]
#   [-5  1  2  2  8  8 -7 -4]
#   [ 3 -5  3  2 -5  3  3  8]]
#
#  [[-7 -4  9  9 -4 -5  2  2]
#   [ 1 -5  9  2  8  9  9  3]
#   [-5 -5 -7  2 -6 -5 -4  2]
#   [ 8  2  2  1 -7  1  9  3]
#   [ 2  9  8  1  3 -7 -6  9]
#   [ 1 -6  3 -6  3 -7 -7  2]
#   [ 8 -6  9  1  3  3 -4  2]
#   [-6 -6 -6  8 -6  1 -6  9]]
#
#  [[ 1  2  2  2 -7 -4 -5 -5]
#   [ 9 -6 -4 -6  9 -4 -5  2]
#   [-6 -6  3 -7  9 -4 -4  2]
#   [-4 -5 -7  1 -4 -4  3 -4]
#   [ 2  1  1  1 -4  3 -7 -5]
#   [-5  2 -7 -6  3  8  3  3]
#   [ 9  1  2  9  8 -4 -4  3]
#   [ 9  1  8  8  1 -5  1  2]]
#
#  [[ 2  1  2 -6 -4  3 -5  3]
#   [ 8  2  3  9  9 -5  9 -7]
#   [ 9 -5  2 -7 -7 -6  8 -7]
#   [-5 -5 -5  2  2 -6  1  1]
#   [ 2 -4 -6 -6 -5 -7  1  1]
#   [ 2 -6  3  8 -7  2  9  8]
#   [ 1  8  8 -4 -4  2 -7 -5]
#   [-4  9 -4 -4 -4 -7  9 -7]]
#
#  [[ 8 -7  8  3  1 -4  9 -7]
#   [ 8  3 -6  9 -4 -4 -5  3]
#   [-4 -5  9 -6  8  8  1  3]
#   [ 9  3  9  3  8  3 -7  3]
#   [-6  9  2  9 -6 -4  2  8]
#   [ 9 -4 -5  3 -4 -5  8 -6]
#   [ 8  9  2  1 -4  9  9  3]
#   [ 3 -7 -7  2  1 -7 -6 -4]]]

# %%
a=np.random.randint(1,10,(8,3))
b=np.random.randint(1,10,(3,2))
c=np.dot(a,b)
print(c)
d=c.reshape(1,16)
print(d)
# Out:
# [[39 52]
#  [35 56]
#  [32 75]
#  [20 46]
#  [28 40]
#  [29 63]
#  [19 60]
#  [54 45]]
# [[39 52 35 56 32 75 20 46 28 40 29 63 19 60 54 45]]

# %% [markdown]
# **Lab 5**
#
# 1. Create a 8x8x8 matrix with random values ranging from 5 to 9
# 2. Find the diagonal of product of two random 5x5 matrices
# 3. Negate a boolean, or to change the the sign of the float inplace

# %% [markdown]
# **Lab 6**
#
# Given 100 random points in 2D space and find the top 10 closest points to the origin.

# %%
z=np.random.randn(100,2)
np.flip(z[np.argsort(np.sqrt(np.sum(z*z,axis=1)))],axis=0)[0:10]
# Out:
# array([[ 2.45373236,  1.59972287],
#        [-2.0933447 ,  1.62412253],
#        [ 2.10009643,  1.57440993],
#        [ 0.3698096 , -2.34045253],
#        [ 0.69303189,  2.08134546],
#        [-2.10960618,  0.36169866],
#        [ 0.25628995, -2.08284137],
#        [-1.95049015, -0.75995674],
#        [-1.11422898,  1.66341977],
#        [ 1.95594068,  0.37802511]])

# %% [markdown]
# **Lab 7**
#
# Find the value of pi using Monte Carlo simulation.
#
# **Hint:-**
#
# Consider a unit circle which is enclosed in a square. randomly genrate uniformily distributed points inside the square. The fraction of points falling inside the circle is pi/4.

# %%
from numpy import random,sqrt,pi

n = 1000000000
p = random.rand(n,2)

idx = sqrt(p[:,0]**2+p[:,1]**2) < 1

print ('%0.16f' % (sum(idx).astype('double')/n*4),'result')
print ('%0.16f' % pi,'real pi')

# %% [markdown]
# **Home Work**
#
# 1. wap the first two rows of a random 5x5
# array
# 2. How to get the block-sum of a 16x16 matrix
# (block size is 4x4)?
# 3. Sort an array by the nth column
# 4. Subtract the mean of each row of a matrix
# from each element
