# %% [markdown]
# **Lab 1**
# 1. Use git init to create an empty repo
# 2. Add a file to local repo and push to github
# 3. Make additional changes to same file, again push to github
# 4. Add a collaborator to your repo
# 5. Ask you collaborator to make change to the file and push to repo
# 6. You try to make a diff change at the same place in the file and push to repo
# 7. Step6 will fail, Fix merge conflicts and push again
# 8. Verify all the commits in github
# 9. Revert code to previous version

# %%
https://github.com/shailendra83/IITKFTP

# %%
import requests
import pprint
headers={'Authorization': 'token 659d4d6aa67c70b460c342926e30d8a707be0fef'}
r=requests.get('https://api.github.com/user/repos', headers=headers)
pprint.pprint(r.json())

# %% [markdown]
# **Lab 2**
# 1. Remove push access to master branch from your collabortator
# 2. Ask your collaborator to create a new branch
# 3. Push new code changes to that branch
# 4. Create a pull request from that branch to master branch
# 5. Approve and merge the pull request
# 6. Do a git pull and veirfy that you can see the new changes in master branch

# %% [markdown]
# **Lab 3**
# 1. Use python requests to post a comment on your commit
# 2. Use python requests to find top 10 commiters on django repo

# %%
import requests
import pprint
headers={'Authorization': 'token 659d4d6aa67c70b460c342926e30d8a707be0fef'}
json={'body': 'comment from api call', 'path' : 'index.html'}
r=request.post('https://api.github.com/user/repos/shailendra83/IITKFTP/commit/ee883f8287fa5c2404f31dfafdab5504878b9b18',headers=headers, json=json)
r=request.get('https://api.github.com/user/repos',headers=headers)
print(r.json())
pprint.pprint(r.json())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-cbd481bd2345> in <module>()
#       3 headers={'Authorization': 'token 659d4d6aa67c70b460c342926e30d8a707be0fef'}
#       4 json={'body': 'comment from api call', 'path' : 'index.html'}
# ----> 5 r=request.post('https://api.github.com/user/repos/shailendra83/IITKFTP/commit/ee883f8287fa5c2404f31dfafdab5504878b9b18',headers=headers, json=json)
#       6 r=request.get('https://api.github.com/user/repos',headers=headers)
#       7 print(r.json())
#
# NameError: name 'request' is not defined

# %% [markdown]
# **Lab 4**
# 1. Create a 8x8x8 array with random values
# 2. From the matrix in (1) Negate all elements
# whose values are between 3 to 8
# 3. Multiply a 8x3 matrix by 3x2 matrix and
# prints the columns as 1 D array

# %%
import numpy as np
z=np.random.randint(10,50,(8,8,8))
z
# Out:
# array([[[45, 21, 46, 17, 35, 40, 47, 44],
#         [10, 12, 25, 10, 33, 13, 13, 31],
#         [11, 23, 20, 25, 12, 41, 43, 43],
#         [13, 13, 43, 27, 36, 12, 44, 47],
#         [13, 38, 24, 45, 14, 26, 23, 13],
#         [15, 21, 10, 41, 41, 17, 38, 38],
#         [13, 20, 35, 28, 28, 42, 16, 36],
#         [16, 19, 25, 45, 42, 43, 33, 44]],
#
#        [[33, 33, 42, 40, 45, 34, 22, 32],
#         [21, 38, 26, 31, 34, 40, 29, 27],
#         [17, 14, 29, 14, 31, 42, 22, 43],
#         [16, 31, 39, 40, 27, 10, 49, 13],
#         [29, 46, 29, 24, 22, 19, 23, 11],
#         [24, 43, 24, 26, 10, 13, 24, 37],
#         [19, 23, 40, 29, 30, 12, 45, 37],
#         [23, 46, 26, 24, 21, 15, 46, 32]],
#
#        [[41, 11, 19, 24, 24, 35, 14, 25],
#         [36, 31, 12, 10, 22, 44, 22, 38],
#         [43, 33, 10, 32, 15, 23, 48, 42],
#         [22, 43, 20, 32, 19, 33, 22, 26],
#         [23, 44, 13, 36, 16, 42, 34, 38],
#         [30, 30, 41, 38, 31, 40, 34, 49],
#         [10, 13, 43, 45, 34, 49, 30, 27],
#         [10, 24, 33, 35, 20, 34, 30, 14]],
#
#        [[42, 40, 13, 27, 33, 11, 25, 47],
#         [37, 33, 30, 27, 12, 46, 17, 12],
#         [20, 28, 35, 36, 33, 49, 20, 39],
#         [14, 29, 46, 11, 34, 19, 21, 14],
#         [30, 10, 25, 11, 12, 34, 10, 23],
#         [47, 10, 25, 37, 26, 29, 28, 26],
#         [17, 26, 35, 32, 44, 18, 17, 18],
#         [32, 38, 40, 48, 41, 36, 26, 11]],
#
#        [[37, 47, 30, 46, 38, 28, 31, 42],
#         [15, 28, 31, 20, 43, 35, 24, 29],
#         [30, 37, 40, 36, 27, 11, 33, 18],
#         [46, 35, 32, 18, 30, 28, 27, 11],
#         [44, 15, 41, 12, 30, 45, 40, 26],
#         [27, 26, 22, 33, 33, 15, 25, 26],
#         [23, 15, 41, 12, 26, 31, 29, 28],
#         [20, 33, 40, 11, 14, 42, 47, 15]],
#
#        [[11, 48, 41, 11, 48, 33, 17, 49],
#         [36, 13, 26, 41, 20, 32, 13, 38],
#         [30, 22, 38, 46, 44, 21, 40, 32],
#         [34, 11, 26, 49, 16, 20, 10, 37],
#         [45, 47, 34, 25, 25, 32, 19, 34],
#         [38, 19, 19, 10, 21, 34, 18, 37],
#         [47, 44, 26, 12, 37, 32, 21, 17],
#         [17, 21, 32, 43, 39, 46, 21, 19]],
#
#        [[10, 34, 19, 26, 49, 16, 21, 13],
#         [12, 39, 17, 30, 40, 49, 18, 44],
#         [30, 28, 29, 26, 21, 27, 36, 36],
#         [38, 31, 32, 38, 24, 12, 22, 23],
#         [28, 41, 21, 30, 21, 45, 16, 13],
#         [24, 22, 22, 45, 31, 31, 41, 48],
#         [17, 18, 30, 37, 41, 19, 11, 27],
#         [31, 28, 29, 48, 37, 30, 10, 14]],
#
#        [[41, 23, 20, 25, 17, 13, 12, 13],
#         [41, 31, 28, 32, 44, 48, 37, 11],
#         [49, 36, 45, 46, 47, 20, 31, 31],
#         [18, 30, 35, 29, 14, 10, 17, 37],
#         [20, 45, 33, 10, 22, 32, 35, 18],
#         [30, 49, 25, 47, 14, 31, 16, 27],
#         [30, 24, 36, 21, 36, 22, 30, 25],
#         [18, 24, 18, 13, 41, 15, 18, 34]]])

# %%
import numpy as np
z = np.random.randint(1,10,(8,8))
mask =(z>3)&(z<8)
z[mask]= -1*z[mask]
z
# Out:
# array([[-5,  2, -4,  9, -4, -4,  2, -7],
#        [ 2, -4, -5,  1, -7,  1,  3, -5],
#        [ 9, -7,  3, -6,  1,  9, -6,  8],
#        [-7, -7,  1, -6,  8,  8,  2,  2],
#        [ 1,  2, -6, -4,  8, -7, -5,  9],
#        [-7,  9, -5,  9,  9, -4, -6,  2],
#        [ 8, -4,  2,  1,  3, -7, -5, -4],
#        [ 1,  2,  9,  9,  8, -4,  8,  3]])

# %%
import numpy as np
a=np.random.randint(1,10,(8,3))
b=np.random.randint(1,10,(3,2))
c=np.dot(a,b)
print(c)
d=c.reshape(1,2)
print(d)
# Out:
# [[ 61  62]
#  [ 29  34]
#  [ 21  15]
#  [ 40  29]
#  [ 72  60]
#  [107  88]
#  [ 27  21]
#  [ 77  58]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-776cddb13658> in <module>()
#       4 c=np.dot(a,b)
#       5 print(c)
# ----> 6 d=c.reshape(1,2)
#       7 print(d)
#
# ValueError: cannot reshape array of size 16 into shape (1,2)

# %% [markdown]
# **Lab 5**
#
# 1. Create a 8x8x8 matrix with random values ranging from 5 to 9
# 2. Find the diagonal of product of two random 5x5 matrices
# 3. Negate a boolean, or to change the the sign of the float inplace

# %%
import numpy as np
n=np.random.randint(5,9,(8,8))
m=np.random.randint(5,9,(8,8))
c=np.dot(n,m)
c
# Out:
# array([[300, 356, 357, 319, 307, 341, 391, 314],
#        [280, 336, 337, 305, 291, 325, 368, 294],
#        [289, 350, 340, 308, 293, 330, 375, 296],
#        [305, 369, 363, 323, 315, 352, 399, 319],
#        [288, 338, 347, 308, 298, 330, 377, 299],
#        [268, 325, 316, 292, 276, 314, 355, 283],
#        [268, 328, 322, 291, 272, 311, 353, 283],
#        [314, 374, 366, 326, 318, 356, 408, 324]])

# %%
Z = np.random.randint(0,2,100)
np.logical_not(Z, out=Z)

Z = np.random.uniform(-1.0,1.0,100)
np.negative(Z, out=Z)
# Out:
# array([ 0.89246126,  0.00717676,  0.00478374,  0.75610387,  0.30738941,
#         0.51631259,  0.946381  ,  0.78586777, -0.53792734,  0.45476624,
#         0.61970072,  0.14978997,  0.48149498, -0.07274534, -0.55155931,
#        -0.63803246, -0.70829832, -0.87380259,  0.56437837,  0.73529386,
#        -0.7284237 ,  0.89910715,  0.25979104,  0.79702401, -0.55999473,
#         0.97944862,  0.40682937,  0.29409648,  0.85733991, -0.36348928,
#        -0.71896369, -0.55778902,  0.07098918,  0.08760066,  0.85332511,
#        -0.6996881 ,  0.70041537, -0.3823484 , -0.90786082,  0.57083484,
#        -0.37647732, -0.08666799,  0.41871259, -0.44050368,  0.00345054,
#        -0.08590676, -0.54092944,  0.02616235, -0.13493752, -0.59082346,
#         0.01350777,  0.60650409, -0.98090291,  0.41517893, -0.65359183,
#        -0.24153308, -0.0569773 , -0.75699128,  0.31510765, -0.71289232,
#        -0.42083852, -0.48059022, -0.50354058,  0.6457757 , -0.18132904,
#        -0.91895136,  0.466083  , -0.37247622,  0.49442321,  0.41292357,
#        -0.45548036, -0.62327083,  0.49621055,  0.47343356, -0.46754056,
#         0.67400514, -0.78847713,  0.42936993, -0.25526418, -0.69889581,
#        -0.11652604,  0.71328881, -0.51586261, -0.73112748,  0.86816148,
#        -0.60364937, -0.38709393,  0.98918203, -0.52821271,  0.58440922,
#        -0.05049591,  0.65916311,  0.90396682,  0.24468178,  0.18237634,
#         0.23537359, -0.89957901, -0.64870495,  0.45562192,  0.50950716])

# %%
np.diag(c)
# Out:
# array([300, 336, 340, 323, 298, 314, 353, 324])

# %% [markdown]
# **Lab 6**
#
# Given 100 random points in 2D space and find the top 10 closest points to the origin.

# %%
import numpy as np
z=np.random.randn(100,2)
np.flip(z[np.argsort(np.sqrt(np.sum(z*z,axis=1)))],axis=0)[0:10]
# Out:
# array([[ 3.53858274, -0.85798125],
#        [-2.406719  , -1.72053205],
#        [ 1.40730783, -2.36658007],
#        [-2.49610927, -0.60738535],
#        [ 0.43758111, -2.28085698],
#        [-0.65413443,  2.18768493],
#        [-1.56459927, -1.62247463],
#        [-1.95629968, -1.09169989],
#        [-0.1889418 ,  2.22623854],
#        [-2.07549859, -0.80993411]])

# %%
z[np.argsort(np.sqrt(np.sum(z*z,axis=1)))]
# Out:
# array([[-0.08233664,  0.20964688],
#        [-0.28135173, -0.21057923],
#        [ 0.33881963,  0.09408528],
#        [ 0.02522027, -0.36676415],
#        [ 0.30904533,  0.2508959 ],
#        [-0.35973606,  0.17390433],
#        [ 0.34584581,  0.23195115],
#        [ 0.27500227, -0.3431576 ],
#        [-0.2477213 , -0.39523978],
#        [-0.07015143, -0.48103099],
#        [ 0.41454502, -0.41531383],
#        [-0.34567348, -0.54087551],
#        [ 0.46557514, -0.46966942],
#        [-0.59952003,  0.28188906],
#        [-0.66486435,  0.01266323],
#        [-0.51881847,  0.41706543],
#        [-0.30348727, -0.60107549],
#        [ 0.69049593,  0.01935093],
#        [-0.22631167,  0.65469254],
#        [ 0.29813984, -0.64345262],
#        [ 0.70102946, -0.21964283],
#        [-0.39512858,  0.62743731],
#        [-0.73297136,  0.22293449],
#        [-0.27429817, -0.71547043],
#        [ 0.30004051, -0.72444678],
#        [ 0.19857014,  0.76107085],
#        [ 0.36187838, -0.735082  ],
#        [-0.16134409, -0.83471396],
#        [ 0.85272669, -0.06162889],
#        [-0.79994461, -0.35052079],
#        [ 0.35386398,  0.84495789],
#        [-0.41609574,  0.82663092],
#        [-0.23102573, -0.914261  ],
#        [ 0.61706747,  0.72550979],
#        [ 0.87485185, -0.39605011],
#        [ 0.14604906, -0.95039858],
#        [-0.17160507, -0.95829741],
#        [-0.97617372,  0.24939405],
#        [-0.83550975,  0.56436831],
#        [-0.98827898,  0.22816847],
#        [-0.50456796,  0.90734419],
#        [-0.29100999, -1.01436654],
#        [-1.07723122,  0.14455302],
#        [ 1.12323512, -0.04798663],
#        [-0.6843029 ,  0.90441165],
#        [-0.41232833, -1.05911945],
#        [ 0.36722433, -1.08025582],
#        [ 0.42651439,  1.07943081],
#        [ 0.89069935,  0.76581982],
#        [-1.10892475, -0.40085116],
#        [-1.24621718, -0.09871604],
#        [ 0.59650459,  1.10342972],
#        [-1.2377075 , -0.24991821],
#        [ 1.10829013,  0.64365927],
#        [ 0.86254336, -0.97608563],
#        [ 0.01516563, -1.30415021],
#        [ 1.26809365, -0.34381901],
#        [-1.32546805,  0.23158753],
#        [ 1.34000846,  0.20576733],
#        [-1.2954883 ,  0.50704099],
#        [ 0.37889061, -1.362996  ],
#        [-1.23812557, -0.68705859],
#        [-1.3779859 , -0.36076771],
#        [-0.98500606,  1.17908549],
#        [-0.74185464,  1.36769672],
#        [-1.33040377,  0.81308576],
#        [-1.18394951, -1.04331602],
#        [-0.20841425,  1.66036643],
#        [-0.12540291,  1.66953832],
#        [-0.37820605,  1.66157901],
#        [-0.02157079, -1.7057895 ],
#        [ 1.57701959,  0.65897825],
#        [ 1.45796959, -0.90255153],
#        [-1.24410909, -1.18076745],
#        [ 1.74830563,  0.18330996],
#        [ 0.82761761,  1.5512074 ],
#        [ 0.78238275,  1.59011347],
#        [ 0.11658503, -1.78942819],
#        [ 0.13681247,  1.79160446],
#        [ 1.88650475, -0.21969027],
#        [-1.42059286, -1.30547657],
#        [ 0.19697656,  1.95886109],
#        [ 1.71160069, -1.02018952],
#        [ 0.63321738, -1.92165747],
#        [ 2.03273603,  0.12443579],
#        [-1.35286841, -1.53975755],
#        [ 0.37470951,  2.0306546 ],
#        [ 1.40714776,  1.55892563],
#        [ 0.24250821, -2.10779435],
#        [-0.74467124,  2.04033869],
#        [-2.07549859, -0.80993411],
#        [-0.1889418 ,  2.22623854],
#        [-1.95629968, -1.09169989],
#        [-1.56459927, -1.62247463],
#        [-0.65413443,  2.18768493],
#        [ 0.43758111, -2.28085698],
#        [-2.49610927, -0.60738535],
#        [ 1.40730783, -2.36658007],
#        [-2.406719  , -1.72053205],
#        [ 3.53858274, -0.85798125]])

# %% [markdown]
# **Lab 7**
#
# Find the value of pi using Monte Carlo simulation.
#
# **Hint:-**
#
# Consider a unit circle which is enclosed in a square. randomly genrate uniformily distributed points inside the square. The fraction of points falling inside the circle is pi/4.

# %%
from numpy import random,sqrt,pi
n=100000000
p=random.rand(n,2)
idx = sqrt(p[:,0]**2+p[:,1]**2)<1
print(sum(idx)/n*4,"result")
print(pi,"real pi")
# Out:
# 3.14155712 result
# 3.141592653589793 real pi

# %% [markdown]
# **Home Work**
#
# 1. wap the first two rows of a random 5x5
# array
# 2. How to get the block-sum of a 16x16 matrix
# (block size is 4x4)?
# 3. Sort an array by the nth column
# 4. Subtract the mean of each row of a matrix
# from each element

# %%
X = np.random.rand(5,10)

# Recent versions of numpy
Y = X - X.mean(axis=1, keepdims=True)

# Older versions of numpy
Y = X - X.mean(axis=1).reshape(-1, 1)

print(Y)
# Out:
# [[ 0.04121923 -0.06191168  0.61049838 -0.06214455 -0.16544053 -0.23960172
#    0.20756223 -0.11188814 -0.3278978   0.10960459]
#  [ 0.11539108  0.37536778  0.2637612  -0.17568633 -0.55479792  0.00472067
#    0.28134445 -0.14390471  0.19313424 -0.35933046]
#  [ 0.10790511 -0.21857285  0.14033359 -0.14260776  0.04606769  0.08913371
#    0.29793465 -0.44363844  0.01729238  0.1061519 ]
#  [ 0.42694515 -0.10519672  0.04017944  0.35758063 -0.31604204 -0.32343559
#   -0.06491259 -0.41901081  0.38144455  0.02244797]
#  [-0.33373288 -0.39570635  0.0593224  -0.06905713  0.4156728  -0.43552383
#    0.25998254  0.35561718  0.04433609  0.0990892 ]]

# %%
import numpy as np
x = np.random.random((5,5))
print("original array")
print(x)
# Out:
# original array
# [[0.64648315 0.7473717  0.29018319 0.29013558 0.800063  ]
#  [0.85207769 0.23204543 0.32674654 0.19726765 0.25850669]
#  [0.59411296 0.25405909 0.7464704  0.91235953 0.08263763]
#  [0.90085057 0.94417509 0.65590954 0.68505525 0.42842255]
#  [0.0375468  0.36350734 0.84826943 0.35331994 0.65688635]]

# %%
Z = np.ones((16,16))
k = 4
S = np.add.reduceat(np.add.reduceat(Z, np.arange(0, Z.shape[0], k), axis=0),
                                       np.arange(0, Z.shape[1], k), axis=1)
print(S)
# Out:
# [[16. 16. 16. 16.]
#  [16. 16. 16. 16.]
#  [16. 16. 16. 16.]
#  [16. 16. 16. 16.]]

# %%
Z = np.random.randint(0,10,(3,3))
print(Z)
print(Z[Z[:,1].argsort()])
# Out:
# [[3 9 1]
#  [8 9 4]
#  [1 7 6]]
# [[1 7 6]
#  [3 9 1]
#  [8 9 4]]

# %%
X = np.random.rand(5,10)
Y = X - X.mean(axis=1, keepdims=True)
Y = X - X.mean(axis=1).reshape(-1,1)
print(Y)
# Out:
# [[-0.13952466 -0.1110064   0.05385058  0.19508728  0.05625439 -0.46336719
#    0.28367146  0.41481087 -0.34021947  0.05044313]
#  [-0.28886859 -0.05973412  0.34167729  0.22739983 -0.12105013 -0.15720561
#   -0.00625962 -0.21421297 -0.14911927  0.42737319]
#  [ 0.07579609  0.05389742  0.31797119  0.2905799  -0.3538379  -0.35530974
#    0.14537036  0.39698197 -0.31893492 -0.25251438]
#  [ 0.28917325 -0.14302878 -0.32555376  0.43152946 -0.31518211 -0.45934711
#   -0.20369485 -0.06017797  0.33132478  0.4549571 ]
#  [ 0.18014636 -0.37164512 -0.38163463  0.04551799 -0.21945955  0.39783108
#    0.48347883 -0.45678662 -0.04569059  0.36824226]]
