#         [-1.74899214e+00,  1.17484810e+00, -5.57346701e-01,
#           8.44041796e-01, -5.11705483e-01, -2.97985686e-01,
#          -1.70341617e-01, -8.69244735e-01],
#         [-1.24882071e+00,  3.30805842e-01, -4.01615491e-02,
#          -2.47396397e-01, -6.49845156e-01,  4.36734389e-01,
#           6.64630917e-01, -1.50294977e-02],
#         [ 7.84559919e-01, -1.06739646e-01,  6.72638865e-01,
#          -5.69631981e-01,  5.41143714e-01,  5.71945742e-01,
#           3.20733199e-01,  3.60779175e-01]],
#
#        [[-3.92383460e-01,  9.64216143e-01, -7.18331499e-01,
#          -1.43685924e+00,  9.34163440e-01, -1.50096642e-03,
#          -3.83908476e-01, -1.98466892e-01],
#         [-1.42970842e+00,  1.27023041e-01, -9.42561521e-02,
#          -1.35034296e+00,  5.01873156e-02,  1.13161865e+00,
#           1.08700818e+00, -1.35593686e-01],
#         [ 4.22905333e-01,  4.11477329e-01, -2.85074007e+00,
#           8.20406179e-01, -4.74111980e-02, -6.73322049e-01,
#          -2.87834956e-01,  7.32739257e-01],
#         [-1.85568699e-01, -5.16402437e-01,  1.23885467e+00,
#           2.00363118e+00,  1.79099801e-02, -1.01692992e-01,
#           8.93905396e-01,  8.40650131e-01],
#         [-1.40571927e+00, -2.26363903e-01,  2.26389417e+00,
#           1.44400759e+00,  1.35030141e+00,  2.00396817e-01,
#           4.18971311e-01,  1.64251084e+00],
#         [-6.65375264e-01, -8.76156465e-01, -2.46905916e-01,
#          -5.36040599e-01, -1.14210129e+00, -1.05233094e-01,
#          -1.13421868e+00,  1.50851382e+00],
#         [-6.30293876e-01,  5.80253195e-01, -2.07080846e-01,
#          -3.82780981e-01,  2.70479299e-01,  1.19921424e+00,
#          -7.58939427e-01, -1.00899048e-01],
#         [-1.41445568e+00, -2.27487913e-01, -8.63851408e-01,
#          -5.97685669e-01,  1.13605621e+00, -1.18830203e+00,
#           1.36546263e+00, -2.36296055e+00]]])

# %%
import numpy as np
a=np.random.randint(1,9,(8,8,8))
mask=(a>3)& (a<8)
a[mask]=-1*a[mask]
a
# Out:
# array([[[ 1,  3,  8,  8, -6, -6,  3, -7],
#         [-7,  8,  8,  8,  8, -4, -4,  8],
#         [ 2, -4, -7,  8, -6, -6, -6, -6],
#         [ 2,  8, -5,  3,  3, -5, -5,  2],
#         [ 2, -5,  1,  2,  2, -5,  1,  3],
#         [-7,  8, -5, -5,  2, -5, -4, -6],
#         [ 1,  2,  3,  1, -4, -6, -4,  8],
#         [ 3, -4,  8,  2,  8,  8,  3, -4]],
#
#        [[-5, -6, -7,  1,  8, -6,  2, -4],
#         [ 8,  1,  8, -5, -5,  2, -4, -7],
#         [-7,  2, -5, -4,  1,  3,  8, -4],
#         [ 2,  1,  2,  8,  2, -7,  8,  2],
#         [ 2, -7, -7, -6,  3, -6,  8, -4],
#         [ 3, -4, -5,  2,  3,  3, -6,  3],
#         [-6,  1,  3, -6,  1,  2,  3, -6],
#         [ 1, -5, -6,  8,  1, -7,  1,  2]],
#
#        [[-7, -4,  1, -5,  1, -5,  8, -7],
#         [ 2,  3,  1,  2, -6, -6, -4, -7],
#         [ 3,  1, -7,  2, -7, -4,  3, -5],
#         [-5, -4,  1, -4,  8,  2,  1,  2],
#         [ 3,  1, -6, -7,  1, -5,  1, -5],
#         [ 1,  3, -7,  2,  8, -4, -7,  3],
#         [-5, -6, -4, -7,  2, -4,  2, -5],
#         [ 8,  2,  2,  2,  8,  3, -4,  3]],
#
#        [[-5, -4, -7, -7, -5,  1, -6, -4],
#         [ 8,  8,  3,  8,  3, -4, -7,  2],
#         [ 2,  2,  1,  3, -5, -7, -4, -4],
#         [ 2,  1, -7,  2, -6, -7, -5, -7],
#         [-5,  3, -4, -5, -6,  3,  3, -7],
#         [-6, -6, -5, -5, -5,  8, -5,  3],
#         [ 8,  3,  8, -4,  1, -7,  1, -7],
#         [ 8,  2, -4,  8,  8, -5,  2, -4]],
#
#        [[ 2, -5,  1, -7, -7, -6,  2, -7],
#         [-4, -7,  3, -5,  3, -4,  2,  1],
#         [-5,  3,  3,  2,  2, -4,  2, -4],
#         [-5, -5, -6,  3,  2, -6, -5, -4],
#         [ 3,  8, -5,  2,  8, -5, -5,  3],
#         [ 2,  2,  8, -4,  2, -7,  1,  1],
#         [-6, -7,  1,  1, -7,  8, -7, -7],
#         [-6,  1,  2, -4,  8,  1, -7, -7]],
#
#        [[-6,  8,  2,  1,  2,  1,  1,  2],
#         [-5,  8,  8,  1,  1, -6,  8,  1],
#         [-5, -4, -6,  3, -6,  3,  8,  8],
#         [ 3, -7, -4, -6,  3, -5, -7, -7],
#         [-5, -7,  1,  2, -4,  1, -5,  2],
#         [-6, -4,  3, -6,  3, -6,  3, -4],
#         [-5,  1, -5, -4,  1, -5,  2,  8],
#         [-7,  1, -4,  2,  3,  3,  3,  8]],
#
#        [[-4,  8, -6, -5, -4,  2, -6, -4],
#         [ 8,  2, -6,  1,  2, -5,  2, -5],
#         [ 3, -4, -5, -4, -4,  1,  3, -7],
#         [-7, -4, -7, -5,  1, -5,  8, -7],
#         [ 3,  8,  3,  3,  3,  2,  1,  1],
#         [ 3,  1,  3,  1,  8, -5,  8,  8],
#         [ 2, -4,  8,  8,  8,  1,  3, -4],
#         [ 3,  3, -7, -5, -6, -4,  2,  3]],
#
#        [[-5,  8,  3,  2,  2, -7,  1, -6],
#         [-7,  2, -6,  3, -6,  1,  8, -4],
#         [-4,  3, -5, -4, -7,  3, -6,  8],
#         [-4,  3,  1,  2, -7,  2,  2, -7],
#         [-6, -6, -7,  8,  1, -7, -6, -7],
#         [-6, -7,  1,  8, -5, -7,  8,  1],
#         [-4,  1, -5,  8,  1, -6,  2, -5],
#         [ 8, -4,  3, -5,  2, -4,  8,  8]]])

# %%
a=np.random.randint(4,9,(8,3))
print(a)
b=np.random.randint(2,9,(3,2))
print(b)
res=np.dot(a,b)
result=res.flatten()
result
# Out:
# [[4 7 4]
#  [5 5 6]
#  [4 4 5]
#  [6 7 5]
#  [7 7 5]
#  [7 8 6]
#  [4 6 8]
#  [8 5 7]]
# [[3 3]
#  [3 5]
#  [3 3]]
# array([45, 59, 48, 58, 39, 47, 54, 68, 57, 71, 63, 79, 54, 66, 60, 70])

# %% [markdown]
# **Lab 5**
#
# 1. Create a 8x8x8 matrix with random values ranging from 5 to 9
# 2. Find the diagonal of product of two random 5x5 matrices
# 3. Negate a boolean, or to change the the sign of the float inplace

# %%
# Out:
# array([[[6, 6, 5, 7, 5, 7, 6, 8],
#         [8, 8, 8, 8, 7, 8, 7, 5],
#         [5, 5, 5, 5, 5, 6, 5, 8],
#         [8, 6, 7, 7, 8, 8, 8, 6],
#         [7, 6, 7, 7, 5, 7, 8, 8],
#         [5, 7, 6, 6, 5, 7, 6, 6],
#         [7, 7, 6, 6, 6, 8, 8, 6],
#         [7, 8, 7, 7, 8, 5, 7, 7]],
#
#        [[7, 6, 5, 6, 6, 5, 7, 6],
#         [8, 7, 5, 8, 7, 7, 6, 6],
#         [7, 7, 8, 7, 5, 7, 5, 5],
#         [5, 8, 7, 5, 5, 8, 7, 5],
#         [5, 6, 6, 8, 5, 5, 7, 5],
#         [6, 8, 5, 8, 8, 5, 5, 6],
#         [6, 5, 6, 5, 8, 5, 8, 7],
#         [6, 5, 7, 8, 8, 8, 5, 7]],
#
#        [[8, 5, 8, 8, 7, 5, 6, 6],
#         [7, 7, 7, 7, 6, 6, 8, 5],
#         [8, 8, 5, 6, 7, 7, 8, 8],
#         [7, 6, 6, 7, 5, 7, 6, 6],
#         [7, 6, 5, 7, 5, 6, 7, 6],
#         [6, 5, 8, 5, 7, 7, 8, 5],
#         [6, 8, 6, 8, 8, 5, 7, 6],
#         [7, 7, 6, 5, 5, 7, 6, 7]],
#
#        [[6, 7, 6, 7, 7, 7, 6, 8],
#         [8, 8, 7, 8, 5, 6, 7, 5],
#         [5, 8, 7, 7, 5, 8, 5, 6],
#         [5, 7, 5, 6, 7, 7, 6, 8],
#         [6, 5, 7, 5, 8, 5, 8, 5],
#         [5, 6, 5, 8, 5, 6, 6, 8],
#         [5, 6, 7, 8, 6, 8, 5, 6],
#         [7, 5, 7, 7, 7, 6, 7, 6]],
#
#        [[8, 7, 5, 6, 6, 7, 5, 7],
#         [7, 5, 5, 5, 6, 8, 8, 8],
#         [7, 5, 7, 5, 5, 8, 7, 7],
#         [5, 6, 5, 7, 7, 7, 8, 6],
#         [5, 7, 8, 7, 5, 8, 6, 6],
#         [6, 6, 5, 6, 7, 6, 7, 7],
#         [6, 5, 6, 6, 6, 6, 5, 6],
#         [7, 6, 6, 8, 5, 5, 8, 5]],
#
#        [[8, 6, 5, 8, 6, 8, 6, 6],
#         [5, 6, 8, 6, 7, 6, 7, 6],
#         [7, 5, 7, 5, 8, 5, 8, 8],
#         [5, 5, 5, 8, 6, 5, 6, 5],
#         [7, 7, 5, 6, 8, 6, 8, 8],
#         [5, 5, 7, 7, 8, 7, 7, 5],
#         [5, 6, 8, 8, 8, 5, 7, 5],
#         [6, 6, 6, 5, 5, 5, 8, 6]],
#
#        [[5, 8, 8, 7, 7, 8, 6, 8],
#         [7, 5, 8, 5, 6, 6, 5, 7],
#         [6, 7, 8, 7, 8, 8, 6, 6],
#         [8, 5, 8, 6, 7, 6, 7, 5],
#         [8, 8, 5, 5, 8, 8, 6, 5],
#         [7, 7, 5, 8, 5, 8, 5, 8],
#         [7, 7, 5, 5, 5, 5, 7, 5],
#         [5, 8, 5, 5, 7, 6, 8, 7]],
#
#        [[6, 6, 7, 5, 6, 6, 7, 7],
#         [7, 7, 8, 8, 6, 7, 6, 6],
#         [7, 7, 8, 8, 7, 7, 7, 7],
#         [6, 8, 7, 8, 7, 8, 5, 6],
#         [6, 6, 6, 8, 8, 5, 8, 5],
#         [7, 5, 6, 7, 6, 7, 5, 6],
#         [8, 8, 5, 5, 5, 8, 6, 5],
#         [7, 5, 5, 5, 6, 7, 7, 6]]])

# %% [markdown]
# **Lab 6**
#
# Given 100 random points in 2D space and find the top 10 closest points to the origin.

# %%
z=np.random.randn(100,2)
z.shape
np.flip(z[np.argsort(np.sqrt(np.sum(z*z,axis=1)))],axis=0)[0:10]
# Out:
# array([[ 1.43220748, -2.82577911],
#        [ 2.96337711, -0.63538602],
#        [ 0.32665369,  2.64409222],
#        [-2.56348017,  0.41308501],
#        [ 1.51157706,  2.09524562],
#        [ 2.46773465,  0.05889341],
#        [-0.56295794,  2.298829  ],
#        [-1.16182699,  1.79438299],
#        [-1.72391478, -1.24835278],
#        [ 2.06974069, -0.24532483]])

# %% [markdown]
# **Lab 7**
#
# Find the value of pi using Monte Carlo simulation.
#
# **Hint:-**
#
# Consider a unit circle which is enclosed in a square. randomly genrate uniformily distributed points inside the square. The fraction of points falling inside the circle is pi/4.

# %%
import random
import math

count_inside = 0
for count in range(0, 100000):
    d = math.hypot(random.random(), random.random())
    if d < 1: count_inside += 1
count += 1
a=4.0 * count_inside / count
print(a)
# Out:
# 3.13584

# %% [markdown]
# **Home Work**
#
# 1. wap the first two rows of a random 5x5
# array
# 2. How to get the block-sum of a 16x16 matrix
# (block size is 4x4)?
# 3. Sort an array by the nth column
# 4. Subtract the mean of each row of a matrix
# from each element

# %%
a=np.random.randn(6,6)
print(a)
#print(a[0])
#print(a[1])
a[0:2,:]
# Out:
# [[ 1.22878469  0.63426002  1.09281461 -0.24377956 -0.23455727  1.32376467]
#  [-1.35388035 -0.29156975  1.0402361   0.56164685  1.24116185 -2.17702136]
#  [-0.56122053 -1.64110474  0.88115319 -0.25199624 -0.40409033 -1.94393261]
#  [ 0.29859573  0.98419174 -1.51560161 -0.22943132  0.22697518  0.07259185]
#  [-1.26215839 -0.61376249 -1.77719097 -0.26581268  1.6561341  -0.15930228]
#  [-2.05215081 -0.30415388 -0.31449338  0.11980792 -1.05737863 -0.43254074]]
# array([[ 1.22878469,  0.63426002,  1.09281461, -0.24377956, -0.23455727,
#          1.32376467],
#        [-1.35388035, -0.29156975,  1.0402361 ,  0.56164685,  1.24116185,
#         -2.17702136]])

# %%
a=np.random.randn(5,5)
print(a)
a.sort()
print(a)
# Out:
# [[-0.52770966  1.07828793  1.16861488 -0.57177084  0.03611601]
#  [-0.12717887  1.24661062 -1.32568861  0.54745835 -0.1146288 ]
#  [ 0.33101238  0.06355471 -0.35544607  0.48819227  1.5911654 ]
#  [-0.20042173  1.51677542 -0.58014263 -1.15719808  0.09111413]
#  [ 0.99525997 -0.73216735 -0.92335812  0.24794338  0.14953524]]
# [[-0.57177084 -0.52770966  0.03611601  1.07828793  1.16861488]
#  [-1.32568861 -0.12717887 -0.1146288   0.54745835  1.24661062]
#  [-0.35544607  0.06355471  0.33101238  0.48819227  1.5911654 ]
#  [-1.15719808 -0.58014263 -0.20042173  0.09111413  1.51677542]
#  [-0.92335812 -0.73216735  0.14953524  0.24794338  0.99525997]]

# %%
import numpy as np
a=np.arange(256)
c=a.reshape((16,16))
d=c.reshape((4,4))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-275a8f64a029> in <module>()
#       2 a=np.arange(256)
#       3 c=a.reshape((16,16))
# ----> 4 d=c.reshape((4,4))
#
# ValueError: cannot reshape array of size 256 into shape (4,4)

# %%
import pandas as pd

dictionary ={'a':1, 'b':2, 'c':3, 'd':4, 'e':5}  
  
# Creating series of Dictionary type 
sd = pd.Series(dictionary)
print(sd)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
dictionary ={'a':1, 'b':2, 'c':3, 'd':4, 'e':5}  
  
# Creating series of Dictionary type 
sd = pd.Series(dictionary)
