# %% [markdown]
# **Lab 1**
# 1. Use git init to create an empty repo
# 2. Add a file to local repo and push to github
# 3. Make additional changes to same file, again push to github
# 4. Add a collaborator to your repo
# 5. Ask you collaborator to make change to the file and push to repo
# 6. You try to make a diff change at the same place in the file and push to repo
# 7. Step6 will fail, Fix merge conflicts and push again
# 8. Verify all the commits in github
# 9. Revert code to previous version

# %% [markdown]
# **Lab 2**
# 1. Remove push access to master branch from your collabortator
# 2. Ask your collaborator to create a new branch
# 3. Push new code changes to that branch
# 4. Create a pull request from that branch to master branch
# 5. Approve and merge the pull request
# 6. Do a git pull and veirfy that you can see the new changes in master branch

# %% [markdown]
# **Lab 3**
# 1. Use python requests to post a comment on your commit
# 2. Use python requests to find top 10 commiters on django repo

# %% [markdown]
# **Lab 4**
# 1. Create a 8x8x8 array with random values
# 2. From the matrix in (1) Negate all elements
# whose values are between 3 to 8
# 3. Multiply a 8x3 matrix by 3x2 matrix and
# prints the columns as 1 D array

# %% [markdown]
# **Lab 5**
#
# 1. Create a 8x8x8 matrix with random values ranging from 5 to 9
# 2. Find the diagonal of product of two random 5x5 matrices
# 3. Negate a boolean, or to change the the sign of the float inplace

# %%
import numpy as np
z=np.random.randint(5,9,(8,8,8))
z
# Out:
# array([[[7, 6, 5, 8, 7, 6, 8, 7],
#         [5, 6, 8, 7, 7, 5, 8, 8],
#         [8, 6, 6, 5, 8, 7, 7, 5],
#         [5, 5, 6, 7, 6, 5, 5, 5],
#         [7, 8, 8, 6, 5, 5, 5, 6],
#         [5, 7, 5, 6, 7, 5, 7, 8],
#         [8, 7, 7, 6, 5, 8, 8, 6],
#         [5, 6, 7, 5, 7, 7, 5, 7]],
#
#        [[6, 6, 8, 8, 6, 5, 5, 7],
#         [6, 5, 5, 8, 8, 5, 8, 7],
#         [5, 6, 8, 5, 5, 8, 8, 5],
#         [6, 5, 7, 6, 5, 6, 5, 6],
#         [7, 5, 5, 7, 7, 6, 6, 6],
#         [5, 7, 6, 8, 8, 5, 6, 6],
#         [7, 7, 7, 6, 8, 8, 6, 7],
#         [7, 6, 8, 5, 7, 6, 7, 8]],
#
#        [[8, 6, 7, 5, 6, 8, 8, 8],
#         [6, 8, 7, 8, 5, 6, 7, 6],
#         [7, 5, 5, 7, 5, 6, 8, 8],
#         [7, 5, 8, 7, 5, 7, 8, 7],
#         [7, 7, 5, 6, 5, 8, 8, 6],
#         [6, 5, 8, 8, 6, 6, 8, 7],
#         [7, 8, 5, 5, 7, 8, 6, 7],
#         [8, 7, 8, 7, 8, 8, 8, 8]],
#
#        [[8, 8, 8, 8, 7, 5, 6, 7],
#         [7, 5, 7, 8, 6, 5, 5, 7],
#         [5, 6, 6, 7, 7, 7, 7, 6],
#         [7, 8, 7, 8, 7, 5, 7, 5],
#         [6, 6, 5, 7, 5, 8, 8, 6],
#         [7, 5, 7, 8, 6, 8, 5, 5],
#         [5, 8, 5, 7, 6, 5, 8, 6],
#         [5, 8, 8, 7, 8, 8, 7, 5]],
#
#        [[7, 6, 8, 6, 7, 7, 7, 6],
#         [5, 5, 8, 5, 8, 7, 5, 8],
#         [7, 8, 5, 6, 8, 8, 6, 8],
#         [5, 5, 7, 8, 7, 6, 8, 7],
#         [5, 5, 6, 7, 5, 5, 8, 5],
#         [5, 8, 7, 7, 8, 5, 6, 7],
#         [7, 8, 8, 8, 6, 7, 8, 6],
#         [5, 8, 6, 7, 5, 7, 6, 5]],
#
#        [[7, 5, 7, 6, 8, 7, 7, 6],
#         [8, 7, 8, 5, 7, 8, 5, 5],
#         [7, 8, 7, 7, 7, 6, 7, 8],
#         [8, 7, 8, 8, 7, 8, 6, 5],
#         [5, 5, 7, 8, 5, 7, 5, 7],
#         [5, 7, 6, 8, 6, 5, 8, 7],
#         [5, 6, 5, 7, 8, 6, 8, 7],
#         [6, 6, 8, 8, 5, 8, 8, 8]],
#
#        [[7, 5, 7, 8, 5, 8, 7, 7],
#         [6, 8, 7, 5, 6, 8, 5, 6],
#         [5, 8, 5, 8, 8, 8, 8, 7],
#         [6, 6, 5, 5, 8, 7, 6, 5],
#         [8, 6, 8, 5, 5, 7, 8, 6],
#         [5, 5, 6, 7, 8, 8, 8, 6],
#         [8, 8, 7, 7, 8, 5, 6, 8],
#         [8, 6, 7, 6, 6, 5, 6, 8]],
#
#        [[8, 7, 8, 5, 7, 6, 5, 7],
#         [6, 7, 5, 6, 8, 7, 6, 6],
#         [8, 7, 8, 8, 8, 8, 5, 8],
#         [5, 7, 8, 8, 5, 6, 6, 7],
#         [8, 8, 5, 5, 7, 7, 7, 5],
#         [5, 8, 5, 8, 7, 7, 7, 6],
#         [6, 8, 7, 7, 7, 6, 8, 5],
#         [5, 7, 6, 6, 5, 7, 8, 5]]])

# %%
import numpy as np
n1=np.random.randint(4,9,(5,5))
print(n1)
n2=np.random.randint(2,6,(5,5))
print(n2)
np.fill_diagonal(n1,n1*n2)
n1
# Out:
# [[6 5 8 6 4]
#  [6 8 6 8 4]
#  [6 7 4 6 8]
#  [7 7 8 8 5]
#  [5 6 4 8 5]]
# [[4 2 3 4 2]
#  [5 5 3 3 3]
#  [3 5 3 3 5]
#  [3 3 4 5 2]
#  [2 5 3 2 3]]
# array([[24,  5,  8,  6,  4],
#        [ 6, 10,  6,  8,  4],
#        [ 6,  7, 24,  6,  8],
#        [ 7,  7,  8, 24,  5],
#        [ 5,  6,  4,  8,  8]])

# %%
import numpy as np
n1=np.random.randint(2,9,(8,3))
n2=np.random.randint(2,9,(3,2))

# %% [markdown]
# **Lab 6**
#
# Given 100 random points in 2D space and find the top 10 closest points to the origin.

# %%
cordinates=np

# %% [markdown]
# **Lab 7**
#
# Find the value of pi using Monte Carlo simulation.
#
# **Hint:-**
#
# Consider a unit circle which is enclosed in a square. randomly genrate uniformily distributed points inside the square. The fraction of points falling inside the circle is pi/4.

# %%
import random
import math
count_inside=0
for count in range(0,10000):
  d=math.hypot(random.random(),random.random())
  if d<1:count_inside+=1
count +=1
a=4.0*count_inside/count
print(a)
# Out:
# 3.116

# %% [markdown]
# **Home Work**
#
# 1. wap the first two rows of a random 5x5
# array
# 2. How to get the block-sum of a 16x16 matrix
# (block size is 4x4)?
# 3. Sort an array by the nth column
# 4. Subtract the mean of each row of a matrix
# from each element

# %%
import numpy as np
a=np.random.randn(5,5)
print(a)
a[0:2,:]
# Out:
# [[ 0.76764455 -0.67026351  1.33104912 -0.66095407 -1.44725085]
#  [ 1.35440475  0.18627317  0.04185065  0.68085263 -0.63875881]
#  [-1.2515787  -0.07132935  0.48244022 -0.1340995   0.74974858]
#  [-1.00398096 -0.10619796 -0.3191959  -0.82207359 -0.88392205]
#  [-0.40401684  0.00336508  3.14830194 -0.16166647 -0.23346642]]
# array([[ 0.76764455, -0.67026351,  1.33104912, -0.66095407, -1.44725085],
#        [ 1.35440475,  0.18627317,  0.04185065,  0.68085263, -0.63875881]])

# %%
a=np.random.randn(5,5)
print(a)
a.sort()
print(a)
# Out:
# [[-0.01353161  1.07982577 -0.64020147 -0.64105787 -0.28417829]
#  [ 0.97012313 -1.15915985  1.78701848 -0.55919426  0.47169145]
#  [ 0.0949099   1.07936044  0.58146529  0.24720428  0.00253422]
#  [-0.23095313 -0.35075882  0.21284945  0.20103236  2.40466104]
#  [ 0.87552371 -0.38007701  0.71191747  0.09853114 -0.07917356]]
# [[-0.64105787 -0.64020147 -0.28417829 -0.01353161  1.07982577]
#  [-1.15915985 -0.55919426  0.47169145  0.97012313  1.78701848]
#  [ 0.00253422  0.0949099   0.24720428  0.58146529  1.07936044]
#  [-0.35075882 -0.23095313  0.20103236  0.21284945  2.40466104]
#  [-0.38007701 -0.07917356  0.09853114  0.71191747  0.87552371]]

# %%
z=np.ones((16,16))
k=4
s=np.add.reduceat(np.add.reduceat(z,np.arange(0,z.shape[0],k),axis=0), np.arange(0,z.shape[1],k),axis=1)
print(s)
# Out:
# [[16. 16. 16. 16.]
#  [16. 16. 16. 16.]
#  [16. 16. 16. 16.]
#  [16. 16. 16. 16.]]

# %%
a=np.array([])
