# %% [markdown]
# **Lab 1**
# 1. Use git init to create an empty repo
# 2. Add a file to local repo and push to github
# 3. Make additional changes to same file, again push to github
# 4. Add a collaborator to your repo
# 5. Ask you collaborator to make change to the file and push to repo
# 6. You try to make a diff change at the same place in the file and push to repo
# 7. Step6 will fail, Fix merge conflicts and push again
# 8. Verify all the commits in github
# 9. Revert code to previous version

# %% [markdown]
# **Lab 2**
# 1. Remove push access to master branch from your collabortator
# 2. Ask your collaborator to create a new branch
# 3. Push new code changes to that branch
# 4. Create a pull request from that branch to master branch
# 5. Approve and merge the pull request
# 6. Do a git pull and veirfy that you can see the new changes in master branch

# %% [markdown]
# **Lab 3**
# 1. Use python requests to post a comment on your commit
# 2. Use python requests to find top 10 commiters on django repo

# %%
import requests
import pprint
headers = { 'Authorization':'token 20e41acf65d3b1dbbda3e275f8632ba767aae465'}
json = {'body' : 'comment from api call','path':'README.md'}
r = requests.post('https://api.github.com/repos/krd612/krd612/commits/8bc60617d25023db31f27ee3641309c54bc1a525/comments', headers=headers,json=json)
pprint.pprint(r.json())
# Out:
# {'author_association': 'OWNER',
#  'body': 'comment from api call',
#  'commit_id': '8bc60617d25023db31f27ee3641309c54bc1a525',
#  'created_at': '2019-11-10T16:29:59Z',
#  'html_url': 'https://github.com/krd612/krd612/commit/8bc60617d25023db31f27ee3641309c54bc1a525#commitcomment-35884958',
#  'id': 35884958,
#  'line': None,
#  'node_id': 'MDEzOkNvbW1pdENvbW1lbnQzNTg4NDk1OA==',
#  'path': 'README.md',
#  'position': None,
#  'updated_at': '2019-11-10T16:29:59Z',
#  'url': 'https://api.github.com/repos/krd612/krd612/comments/35884958',
#  'user': {'avatar_url': 'https://avatars3.githubusercontent.com/u/57562760?v=4',
#           'events_url': 'https://api.github.com/users/krd612/events{/privacy}',
#           'followers_url': 'https://api.github.com/users/krd612/followers',
#           'following_url': 'https://api.github.com/users/krd612/following{/other_user}',
#           'gists_url': 'https://api.github.com/users/krd612/gists{/gist_id}',
#           'gravatar_id': '',
#           'html_url': 'https://github.com/krd612',
#           'id': 57562760,
#           'login': 'krd612',
#           'node_id': 'MDQ6VXNlcjU3NTYyNzYw',
#           'organizations_url': 'https://api.github.com/users/krd612/orgs',
#           'received_events_url': 'https://api.github.com/users/krd612/received_events',
#           'repos_url': 'https://api.github.com/users/krd612/repos',
#           'site_admin': False,
#           'starred_url': 'https://api.github.com/users/krd612/starred{/owner}{/repo}',
#           'subscriptions_url': 'https://api.github.com/users/krd612/subscriptions',
#           'type': 'User',
#           'url': 'https://api.github.com/users/krd612'}}

# %% [markdown]
# **Lab 4**
# 1. Create a 8x8x8 array with random values
# 2. From the matrix in (1) Negate all elements
# whose values are between 3 to 8
# 3. Multiply a 8x3 matrix by 3x2 matrix and
# prints the columns as 1 D array

# %%
import numpy as np
x=np.random.randint(1,5,(8,8,8))
x
# Out:
# array([[[1, 1, 3, 3, 3, 1, 4, 1],
#         [4, 1, 4, 4, 3, 3, 4, 2],
#         [2, 2, 3, 3, 1, 1, 3, 4],
#         [1, 3, 3, 3, 1, 4, 4, 4],
#         [4, 4, 4, 1, 1, 4, 2, 1],
#         [3, 3, 4, 2, 2, 3, 4, 1],
#         [3, 2, 4, 1, 4, 4, 1, 3],
#         [1, 1, 3, 1, 4, 3, 2, 4]],
#
#        [[4, 1, 3, 3, 3, 1, 4, 1],
#         [3, 4, 3, 2, 2, 1, 2, 4],
#         [4, 2, 2, 2, 3, 4, 2, 2],
#         [1, 2, 4, 1, 3, 1, 1, 2],
#         [2, 1, 3, 3, 2, 1, 1, 3],
#         [4, 2, 3, 4, 2, 1, 3, 3],
#         [2, 2, 2, 2, 1, 1, 1, 1],
#         [4, 4, 2, 3, 4, 2, 1, 3]],
#
#        [[4, 4, 1, 1, 4, 1, 4, 4],
#         [2, 3, 4, 3, 4, 1, 3, 3],
#         [2, 4, 3, 2, 1, 1, 4, 3],
#         [1, 3, 2, 4, 2, 1, 3, 3],
#         [3, 3, 1, 4, 3, 1, 1, 4],
#         [3, 4, 3, 1, 2, 1, 3, 3],
#         [4, 1, 1, 3, 3, 1, 3, 4],
#         [3, 4, 4, 2, 3, 2, 3, 3]],
#
#        [[1, 1, 1, 1, 4, 4, 1, 1],
#         [2, 3, 2, 4, 1, 2, 4, 1],
#         [2, 4, 3, 4, 2, 3, 1, 2],
#         [3, 4, 2, 4, 4, 4, 3, 2],
#         [3, 4, 3, 3, 1, 4, 3, 3],
#         [3, 1, 1, 1, 3, 4, 4, 3],
#         [2, 4, 2, 1, 3, 1, 2, 2],
#         [1, 4, 2, 2, 2, 3, 3, 1]],
#
#        [[1, 2, 4, 3, 3, 1, 1, 4],
#         [4, 2, 4, 3, 2, 4, 4, 1],
#         [3, 4, 4, 2, 1, 1, 1, 2],
#         [3, 3, 3, 1, 3, 3, 1, 2],
#         [2, 1, 2, 2, 2, 3, 1, 3],
#         [2, 3, 3, 1, 4, 4, 4, 2],
#         [1, 4, 2, 1, 3, 1, 2, 1],
#         [1, 2, 4, 3, 3, 2, 3, 1]],
#
#        [[2, 3, 3, 4, 4, 2, 2, 4],
#         [3, 4, 3, 1, 1, 2, 4, 3],
#         [2, 4, 4, 4, 2, 2, 4, 1],
#         [1, 3, 2, 4, 3, 3, 2, 1],
#         [2, 4, 4, 1, 1, 4, 4, 1],
#         [3, 3, 1, 4, 1, 3, 1, 4],
#         [4, 2, 2, 2, 4, 4, 3, 1],
#         [4, 1, 2, 2, 4, 2, 3, 2]],
#
#        [[1, 1, 3, 4, 2, 1, 4, 3],
#         [3, 2, 4, 3, 1, 2, 2, 4],
#         [3, 3, 4, 4, 2, 1, 4, 4],
#         [1, 1, 2, 4, 3, 4, 4, 2],
#         [2, 2, 4, 2, 3, 1, 4, 4],
#         [1, 3, 3, 1, 4, 4, 3, 3],
#         [3, 2, 2, 2, 4, 2, 1, 4],
#         [4, 1, 1, 2, 2, 1, 3, 2]],
#
#        [[4, 3, 3, 1, 1, 2, 4, 3],
#         [2, 4, 4, 1, 3, 3, 2, 1],
#         [1, 2, 3, 1, 2, 1, 2, 1],
#         [4, 3, 2, 2, 3, 3, 1, 1],
#         [3, 2, 4, 3, 2, 4, 3, 1],
#         [3, 3, 4, 3, 4, 4, 3, 4],
#         [3, 2, 3, 4, 1, 3, 4, 3],
#         [1, 3, 3, 1, 2, 4, 3, 4]]])

# %%
import numpy as np
x=np.random.randint(1,5,(8,8,8))
mask=(x>3) & (x<8)
x[mask]= -1*x[mask]
x
# Out:
# array([[[-4,  2,  1,  2,  2,  2, -4,  3],
#         [-4,  3,  2,  2,  2, -4,  2,  3],
#         [-4,  2,  2,  3,  2,  3,  3, -4],
#         [ 1,  3,  2,  3,  3, -4, -4,  1],
#         [ 2,  1,  1, -4, -4,  1,  1, -4],
#         [ 3,  3,  1,  2, -4,  3,  2,  3],
#         [-4,  2,  1,  2,  3, -4,  2, -4],
#         [-4, -4, -4,  3,  2,  1,  2,  3]],
#
#        [[-4, -4,  1,  3, -4,  3,  1,  1],
#         [ 2,  1,  3,  2,  3, -4,  1, -4],
#         [-4,  3,  1, -4,  2,  3,  2,  1],
#         [ 3,  3,  1,  2,  3,  3,  1,  3],
#         [ 1,  3,  1,  1,  3,  2,  3,  1],
#         [ 3, -4,  2,  3,  1,  2, -4,  3],
#         [-4,  3,  2,  1,  2, -4,  2,  2],
#         [ 1,  3, -4,  2,  3, -4, -4, -4]],
#
#        [[ 3,  2,  2,  3, -4,  1, -4,  2],
#         [ 2, -4,  2,  3,  3,  1, -4,  2],
#         [-4,  2,  3,  1,  1,  2, -4, -4],
#         [ 2, -4,  3,  3,  1,  3,  1, -4],
#         [-4,  1, -4, -4,  1,  1, -4, -4],
#         [ 3,  2, -4,  2, -4, -4,  3,  3],
#         [ 2,  1,  2, -4,  2,  3,  3,  2],
#         [ 3,  1,  3,  3,  2, -4, -4,  1]],
#
#        [[ 1,  3,  2,  3, -4,  1, -4,  2],
#         [ 1,  2,  1,  3, -4,  2,  2,  2],
#         [ 2,  1, -4,  2,  1,  3,  3,  1],
#         [ 2,  1,  3,  3,  2,  1,  3,  1],
#         [ 3, -4,  1,  3,  1,  1,  1, -4],
#         [-4,  2,  1,  3,  2, -4, -4,  2],
#         [ 2,  1,  1,  2,  3,  2,  3, -4],
#         [-4,  2,  2, -4,  1,  1, -4,  2]],
#
#        [[-4,  1,  3,  2,  1, -4,  2, -4],
#         [ 2,  1, -4,  3,  3,  2,  3, -4],
#         [-4,  1,  2, -4,  1,  3,  3,  2],
#         [ 1,  1, -4,  3, -4,  1,  2,  1],
#         [ 1,  3,  1, -4,  1,  2, -4,  2],
#         [ 2,  1,  3,  1,  3,  1,  2,  1],
#         [ 2,  1,  2,  3,  2, -4,  3,  2],
#         [ 1,  2, -4,  3, -4,  2,  2, -4]],
#
#        [[ 2, -4,  1,  3,  3,  2,  3, -4],
#         [ 1,  1,  3,  1, -4,  2, -4,  1],
#         [ 1,  1,  2,  3,  2,  3,  2,  3],
#         [ 2,  2,  2,  1,  1,  3, -4,  3],
#         [ 1,  3,  1,  1, -4,  2, -4,  1],
#         [ 2,  1,  2,  3,  2,  2, -4,  3],
#         [ 2,  3, -4,  2,  3,  2,  3,  3],
#         [ 3,  3,  2,  1,  1,  1,  1, -4]],
#
#        [[-4,  3,  3,  2,  2,  2,  2,  3],
#         [-4,  3,  2,  3,  2,  3,  1,  2],
#         [-4, -4,  3,  2, -4,  1, -4, -4],
#         [-4,  1, -4, -4,  2, -4,  2,  1],
#         [-4, -4,  1, -4,  3,  2, -4,  2],
#         [ 1,  1, -4,  3,  2, -4, -4,  3],
#         [-4,  2, -4,  1,  3,  2,  1,  2],
#         [ 2,  3,  3,  1, -4,  3,  1,  2]],
#
#        [[ 3,  3, -4,  3,  3,  3,  2,  3],
#         [ 3,  2, -4,  3,  1,  3,  1, -4],
#         [ 2, -4, -4,  2, -4,  2,  3, -4],
#         [ 3,  3,  3,  2,  2, -4,  1,  2],
#         [-4, -4,  1,  1, -4,  2, -4,  3],
#         [ 1,  2,  1, -4,  3,  2,  2,  1],
#         [ 1,  1,  2,  3,  3,  1,  1, -4],
#         [ 1,  1,  1,  3,  3, -4,  2,  2]]])

# %%
import numpy as np
x=np.random.randint(1,10,(8,3))
y=np.random.randint(1,10,(3,2))
z=np.dot(x,y)
res=z.flatten()
res
# Out:
# array([ 60, 118,  87, 133, 117, 177,  96, 154,  66,  84, 108, 174,  69,
#        121,  63, 129])

# %% [markdown]
# **Lab 5**
#
# 1. Create a 8x8x8 matrix with random values ranging from 5 to 9
# 2. Find the diagonal of product of two random 5x5 matrices
# 3. Negate a boolean, or to change the the sign of the float inplace

# %%
x=np.random.randint(5,9,(8,8,8))
x
# Out:
# array([[[7, 5, 5, 8, 5, 7, 7, 6],
#         [8, 8, 8, 6, 6, 6, 7, 8],
#         [6, 7, 5, 6, 7, 5, 6, 6],
#         [7, 6, 6, 7, 5, 6, 5, 5],
#         [7, 8, 6, 5, 8, 8, 6, 7],
#         [7, 6, 8, 5, 6, 6, 7, 8],
#         [7, 5, 7, 7, 6, 5, 5, 8],
#         [8, 8, 6, 7, 6, 7, 8, 8]],
#
#        [[7, 5, 5, 6, 5, 6, 8, 5],
#         [6, 7, 5, 6, 5, 6, 8, 7],
#         [6, 5, 6, 6, 7, 6, 7, 8],
#         [7, 5, 5, 7, 8, 8, 6, 5],
#         [5, 7, 8, 7, 8, 7, 6, 8],
#         [8, 8, 6, 6, 7, 6, 7, 5],
#         [7, 6, 8, 8, 6, 6, 5, 8],
#         [8, 6, 6, 6, 6, 7, 6, 7]],
#
#        [[7, 6, 5, 5, 7, 8, 5, 6],
#         [6, 5, 7, 5, 7, 6, 5, 8],
#         [5, 7, 5, 6, 5, 6, 6, 8],
#         [6, 6, 5, 7, 5, 6, 7, 7],
#         [8, 5, 6, 5, 5, 8, 7, 7],
#         [7, 6, 8, 8, 8, 5, 6, 7],
#         [5, 5, 7, 7, 7, 7, 6, 6],
#         [7, 7, 5, 8, 6, 5, 5, 8]],
#
#        [[5, 8, 8, 8, 5, 5, 8, 6],
#         [7, 8, 5, 7, 7, 6, 8, 6],
#         [5, 5, 8, 6, 7, 6, 5, 8],
#         [8, 5, 6, 5, 6, 7, 7, 6],
#         [8, 7, 6, 5, 8, 5, 5, 8],
#         [8, 6, 8, 5, 8, 6, 5, 6],
#         [8, 5, 7, 7, 6, 7, 7, 7],
#         [7, 5, 5, 6, 6, 6, 6, 6]],
#
#        [[5, 5, 8, 6, 6, 8, 7, 6],
#         [5, 5, 6, 5, 5, 8, 5, 8],
#         [6, 6, 5, 5, 8, 5, 8, 8],
#         [8, 5, 6, 5, 7, 6, 7, 7],
#         [8, 7, 7, 6, 6, 8, 8, 6],
#         [5, 8, 7, 6, 8, 6, 8, 6],
#         [6, 7, 6, 5, 6, 6, 6, 8],
#         [6, 6, 8, 5, 5, 5, 6, 5]],
#
#        [[6, 5, 8, 5, 5, 5, 6, 6],
#         [7, 8, 7, 6, 7, 6, 5, 5],
#         [5, 7, 5, 8, 8, 5, 5, 7],
#         [5, 8, 6, 5, 5, 5, 6, 6],
#         [6, 8, 5, 5, 8, 5, 6, 6],
#         [8, 7, 8, 7, 7, 5, 7, 7],
#         [7, 6, 5, 5, 6, 7, 5, 7],
#         [7, 5, 7, 7, 5, 5, 5, 8]],
#
#        [[7, 7, 6, 8, 5, 5, 8, 7],
#         [6, 6, 8, 6, 7, 6, 6, 8],
#         [7, 6, 5, 5, 7, 6, 5, 5],
#         [5, 8, 7, 6, 5, 7, 7, 5],
#         [8, 8, 5, 5, 6, 7, 8, 8],
#         [6, 8, 5, 5, 8, 8, 6, 5],
#         [7, 5, 6, 7, 7, 8, 5, 7],
#         [5, 8, 8, 8, 7, 6, 8, 8]],
#
#        [[5, 7, 7, 6, 6, 5, 8, 5],
#         [5, 6, 5, 7, 8, 6, 8, 8],
#         [5, 7, 7, 7, 8, 5, 7, 8],
#         [5, 6, 7, 8, 6, 6, 5, 8],
#         [6, 8, 8, 8, 6, 7, 8, 6],
#         [7, 5, 8, 6, 5, 5, 8, 7],
#         [7, 6, 7, 8, 7, 5, 7, 7],
#         [5, 8, 5, 6, 5, 5, 6, 7]]])

# %%
x=np.random.randint(3,8,(5,5))
y=np.random.randint(3,8,(5,5))
np.fill_diagonal(x,x*y)
print(x)
# Out:
# [[35  3  3  3  3]
#  [ 4 12  4  6  4]
#  [ 5  3 12  4  5]
#  [ 3  7  4  9  3]
#  [ 6  3  6  7 12]]

# %% [markdown]
# **Lab 6**
#
# Given 100 random points in 2D space and find the top 10 closest points to the origin.

# %%
z=np.random.randn(100,2)
z[np.argsort(np.sqrt(np.sum(z*z,axis=1)))]
np.flip(z[np.argsort(np.sqrt(np.sum(z*z,axis=1)))],axis=0)[0:10]
# Out:
# array([[-3.10058894, -1.2623313 ],
#        [-0.75905623,  2.97618574],
#        [-0.21765536,  3.04510527],
#        [-0.97662958,  2.71266208],
#        [-2.19951453,  1.79485312],
#        [-1.49145891,  2.4004017 ],
#        [ 0.53663243, -2.72662493],
#        [ 2.05289931,  1.71270906],
#        [-2.17685198,  1.16737974],
#        [-1.65401418,  1.81221875]])

# %%
cos1 = np.random.randn(100,2)
dist = np.sqrt(cos1[:,0]**2+cos1[:,1]**2)
top_10 = np.argsort(dist)[:10]
print(cos1[top_10])
# Out:
# [[-0.10697499 -0.15131437]
#  [ 0.21219448 -0.15835533]
#  [ 0.1473377  -0.22918098]
#  [-0.22941332 -0.16654411]
#  [-0.2764635  -0.10302917]
#  [-0.1359513  -0.33993273]
#  [-0.28455358  0.23415961]
#  [ 0.01036018 -0.39204342]
#  [ 0.17768399  0.3906074 ]
#  [ 0.30080379  0.30788529]]

# %% [markdown]
# **Lab 7**
#
# Find the value of pi using Monte Carlo simulation.
#
# **Hint:-**
#
# Consider a unit circle which is enclosed in a square. randomly genrate uniformily distributed points inside the square. The fraction of points falling inside the circle is pi/4.

# %%
from numpy import random,sqrt,pi
num=100000000
val=random.rand(num,2)
res=sqrt(val[:,0]**2+val[:,1]**2)<1
print(sum(res)/num*4,'Solution')
 
print(pi,'Real PI value')
# Out:
# 3.1417106 Solution
# 3.141592653589793 Real PI value

# %% [markdown]
# **Home Work**
#
# 1. wap the first two rows of a random 5x5
# array
# 2. How to get the block-sum of a 16x16 matrix
# (block size is 4x4)?
# 3. Sort an array by the nth column
# 4. Subtract the mean of each row of a matrix
# from each element

# %%
import numpy as np
x = np.random.rand(5, 5)
print("Original array: ")
print(x)
y= x[:2, :]
print("First 2 rows of the above array:")
print(y)
# Out:
# Original array:
# [[0.76867062 0.02093253 0.56754541 0.18317155 0.79058247]
#  [0.94251224 0.98240968 0.6180396  0.81565109 0.06788809]
#  [0.65977136 0.06703857 0.32935705 0.36183767 0.80054779]
#  [0.77727033 0.61093619 0.69737386 0.95435965 0.28232468]
#  [0.9863226  0.05395312 0.59720034 0.29397767 0.03391261]]
# First 2 rows of the above array:
# [[0.76867062 0.02093253 0.56754541 0.18317155 0.79058247]
#  [0.94251224 0.98240968 0.6180396  0.81565109 0.06788809]]

# %%
arr = np.array([[3., 1, 4], [1, 5, 9], [2, 6, 5], [3, 5, 8]])
row_means = np.mean(arr, axis=1)
row_means
# Out:
# array([2.66666667, 5.        , 4.33333333, 5.33333333])

# %%
# arr = arr[arr[:,n].argsort()]
mat = np.array([[11,32,3],[5,4,2],[16,12,4]])
mat_sort = mat[mat[:,2].argsort()]
print(mat_sort)
# Out:
# [[ 5  4  2]
#  [11 32  3]
#  [16 12  4]]

# %%
Z=np.ones((16,16))
k=4
S=np.add.reduceat(np.add.reduceat(Z,np.arange(0,Z.shape[0],k),axis=0), np.arange(0,Z.shape[1],k),axis=1)
print(S)
# Out:
# [[16. 16. 16. 16.]
#  [16. 16. 16. 16.]
#  [16. 16. 16. 16.]
#  [16. 16. 16. 16.]]
