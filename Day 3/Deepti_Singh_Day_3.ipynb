# %% [markdown]
# **Lab 1**
#
# Using the dataset at https://bit.ly/2JIORnq
# 1. Assign it to a variable called users and use the 'user_id' as index
# 2. What is the age with least occurrence?
# 3. What is the mean age of users?
# 4. What is the most frequent occupation?

# %%
import pandas pd
pd.Series({'a':1,'b':2,'c':3})
# Out:
#   File "<ipython-input-1-0d83d827f9b8>", line 1
#     import pandas pd
#                    ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import numpy as np

u_data = pd.read_csv("https://bit.ly/2JIORnq", delimiter='|')
u_data
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %%
type(u_data.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
indexedData = u_data.set_index('user_id')
indexedData
# Out:
#          age gender     occupation zip_code
# user_id
# 1         24      M     technician    85711
# 2         53      F          other    94043
# 3         23      M         writer    32067
# 4         24      M     technician    43537
# 5         33      F          other    15213
# ...      ...    ...            ...      ...
# 939       26      F        student    33319
# 940       32      M  administrator    02215
# 941       20      M        student    97229
# 942       48      F      librarian    78209
# 943       22      M        student    77841
#
# [943 rows x 4 columns]

# %%
u_data['age'].value_counts()
# Out:
# 30    39
# 25    38
# 22    37
# 28    36
# 27    35
#       ..
# 11     1
# 10     1
# 73     1
# 66     1
# 7      1
# Name: age, Length: 61, dtype: int64

# %%
u_data['age'].mean()
# Out:
# 34.05196182396607

# %%
users = pd.read_csv("https://bit.ly/2JIORnq", delimiter='|')
b=users.set_index("user_id")
counts = users['age'].value_counts()
c=counts.tail(10)
d=users["age"].mean()
counts_occupation= users['occupation'].value_counts()
most_occupation=counts_occupation.head()
print(counts)
# Out:
# 30    39
# 25    38
# 22    37
# 28    36
# 27    35
#       ..
# 11     1
# 10     1
# 73     1
# 66     1
# 7      1
# Name: age, Length: 61, dtype: int64

# %% [markdown]
# **Lab 2**
#
# Dataset: https://bit.ly/2UUomN0
# 1. What is the price of each item?
# 2. What was the quantity of the most expensive item ordered?
# 3. How many times were a Veggie Salad Bowl ordered?
# 4. How many times people ordered more than one Canned Soda?

# %%
import pandas as pd

data_p = pd.read_csv("https://bit.ly/2UUomN0", delimiter='\t')
data_p
# Out:
#       order_id  ...  item_price
# 0            1  ...      $2.39
# 1            1  ...      $3.39
# 2            1  ...      $3.39
# 3            1  ...      $2.39
# 4            2  ...     $16.98
# ...        ...  ...         ...
# 4617      1833  ...     $11.75
# 4618      1833  ...     $11.75
# 4619      1834  ...     $11.25
# 4620      1834  ...      $8.75
# 4621      1834  ...      $8.75
#
# [4622 rows x 5 columns]

# %%
import pandas as pd
import numpy as np
df= pd.read_csv("https://bit.ly/2UUomN0", delimiter='\t')
df['item_price'] = df['item_price'].map(lambda x: float(x.strip()[1:]))
df['item_price'] = df['item_price'].astype(float)
d1=df.sort_values(by=['quantity', 'item_name','item_price'])
df = df.drop_duplicates(subset='item_name', keep='first')
df['Unit_Price']= df['item_price']/df['quantity']
df.sort_values(by=['Unit_Price']).max()
# Out:
# order_id                   1500
# quantity                      3
# item_name     Veggie Soft Tacos
# item_price                23.78
# Unit_Price                11.89
# dtype: object

# %%
df= pd.read_csv("https://bit.ly/2UUomN0", delimiter='\t')
d=[df['item_name']=='Veggie Salad Bowl']
x= np.count_nonzero(d)
x
# Out:
# 18

# %%
df[df['item_name']=='Canned Soda']
p=df['quantity']>1
q=np.count_nonzero(p)
q
# Out:
# 267

# %% [markdown]
# **Lab 3**
#
# Dataset: https://bit.ly/1N5br3h
# 1. Assign Columns for the dataset
# 2. Is there any missing value in the dataframe?
# 3. delete the column class
# 4. set the values of the rows 10 to 29 of the column 'petal_length' to NaN
# 5. Delete the rows that have NaN
# 6. Reset the index so it begins with 0 again
# 7. BONUS: Create & Answer your own question

# %%
import numpy as np
import pandas as pd

col_Names=["Sepal_length", "Sepal_width", "Petal_length","Petal_width","class"]
df= pd.read_csv("https://bit.ly/1N5br3h", delimiter=',')
df= pd.read_csv("https://bit.ly/1N5br3h",names=col_Names)
b=df.isnull()
df_class=df.drop(columns='class')
d=df['Petal_length']
d[10:29]=np.nan
df1=df.dropna()
df1
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
#      Sepal_length  Sepal_width  Petal_length  Petal_width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [131 rows x 5 columns]

# %% [markdown]
# **Lab 4**
#
# DataSet: https://bit.ly/2CudMVh
# 1. Assign it to a variable called drinks.
# 2. Which continent drinks more beer on average?
# 3. For each continent print the statistics for wine consumption.
# 4. Display the mean alcohol consumption per continent for every column.
# 5. Display the median alcohol consumption per continent for every column.
# 6. Display the mean, min and max values for spirit consumption.

# %%
import pandas as pd
drinks=pd.read_csv("https://bit.ly/2CudMVh", delimiter=',')
d=drinks.groupby(['continent']).mean()
d1=d.sort_values(by=['continent','beer_servings']).max()
d1
# Out:
# beer_servings                   193.777778
# spirit_servings                 132.555556
# wine_servings                   142.222222
# total_litres_of_pure_alcohol      8.617778
# dtype: float64

# %%
import pandas as pd
drinks=pd.read_csv("https://bit.ly/2CudMVh", delimiter=',')
d=drinks.groupby(['continent']).mean()
d1=d.sort_values(by=['continent','beer_servings']).max()
drinks_cont=drinks.groupby(['continent']).describe()
drinks_cont_stats=drinks_cont['wine_servings']
drinks_mean_alc=d['total_litres_of_pure_alcohol']
drinks_med=drinks.groupby(['continent']).median()
drinks_med=drinks_med['total_litres_of_pure_alcohol']
drinks_cont_stats_spr=drinks_cont['spirit_servings']
drinks_cont_stats_spr[['mean', 'min', 'max']]
# Out:
#                  mean   min    max
# continent
# AF          16.339623   0.0  152.0
# AS          60.840909   0.0  326.0
# EU         132.555556   0.0  373.0
# OC          58.437500   0.0  254.0
# SA         114.750000  25.0  302.0
