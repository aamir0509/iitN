# %% [markdown]
# **Lab 1**
#
# Using the dataset at https://bit.ly/2JIORnq
# 1. Assign it to a variable called users and use the 'user_id' as index
# 2. What is the age with least occurrence?
# 3. What is the mean age of users?
# 4. What is the most frequent occupation?

# %%
import pandas as pd
users = pd.read_csv('u.user', delimiter = "|",index_col='user_id')
print(users) #Answer 1
#group_by_age=users.groupby(by="age")
#print(group_by_age)
x=users['age'].value_counts()
print(x)
x.index
x.nsmallest(1) #Answer 2
y=users['age'].sum()
print(y)
z=users['age'].count()
print(z)
print('%f is the mean age of users' %(y/z)) #Answer 3
group_by_occupation=users.groupby(by="occupation")
print(group_by_occupation)
q=users['occupation'].value_counts()
print(q)
print(q.nlargest(1)) #Answer 4
# Out:
#          age gender     occupation zip_code
# user_id
# 1         24      M     technician    85711
# 2         53      F          other    94043
# 3         23      M         writer    32067
# 4         24      M     technician    43537
# 5         33      F          other    15213
# ...      ...    ...            ...      ...
# 939       26      F        student    33319
# 940       32      M  administrator    02215
# 941       20      M        student    97229
# 942       48      F      librarian    78209
# 943       22      M        student    77841
#
# [943 rows x 4 columns]
# 30    39
# 25    38
# 22    37
# 28    36
# 27    35
#       ..
# 11     1
# 10     1
# 73     1
# 66     1
# 7      1
# Name: age, Length: 61, dtype: int64
# 32111
# 943
# 34.051962 is the mean age of users
# ...
# student          196
# other            105
# educator          95
# administrator     79
# engineer          67
# programmer        66
# librarian         51
# writer            45
# ...

# %% [markdown]
# **Lab 2**
#
# Dataset: https://bit.ly/2UUomN0
# 1. What is the price of each item?
# 2. What was the quantity of the most expensive item ordered?
# 3. How many times were a Veggie Salad Bowl ordered?
# 4. How many times people ordered more than one Canned Soda?

# %%
import pandas as pd
users = pd.read_csv('chipotle.tsv', delimiter = "\t",index_col='order_id')
#users['item_price'] = pd.to_numeric(users['item_price'], errors='coerce')
#users[users.columns[1:]] = users[users.columns[1:]].apply(lambda x: x.str.replace('$','')).apply(lambda x: x.str.replace(',','')).astype(np.float64)
#users[users.columns[0:]].replace('[\$,]', '', regex=True).astype(float)
users[['item_price']] = users[['item_price']].replace('[\$,]','',regex=True).astype(float)
print(users)
group_by_item_name=users.groupby("item_name")['item_price']
print(group_by_item_name.head)
#group_by_item_name.drop_duplicates()
#transformed = (group_by_item_name.groupby(lambda x,y: x.item_price,y.quantity).transform(lambda x,y: (x.item_price / y.quantity)))
#df['$/hour'] = np.where(df['hours'] < 1, df['hours'], df['$']/df['hours'])
# Out:
#           quantity  ... item_price
# order_id            ...
# 1                1  ...       2.39
# 1                1  ...       3.39
# 1                1  ...       3.39
# 1                1  ...       2.39
# 2                2  ...      16.98
# ...            ...  ...        ...
# 1833             1  ...      11.75
# 1833             1  ...      11.75
# 1834             1  ...      11.25
# 1834             1  ...       8.75
# 1834             1  ...       8.75
#
# [4622 rows x 4 columns]
# <bound method GroupBy.head of <pandas.core.groupby.generic.SeriesGroupBy object at 0x7fe4670442e8>>

# %% [markdown]
# **Lab 3**
#
# Dataset: https://bit.ly/1N5br3h
# 1. Assign Columns for the dataset
# 2. Is there any missing value in the dataframe?
# 3. delete the column class
# 4. set the values of the rows 10 to 29 of the column 'petal_length' to NaN
# 5. Delete the rows that have NaN
# 6. Reset the index so it begins with 0 again
# 7. BONUS: Find the average petal length and sepal length for every class of flowers.

# %%
import pandas as pd
import numpy as np
users = pd.read_csv('iris.data', delimiter = ",")
users.columns=['Petal Length','Petal Width','Sepal Length','Sepal Width','Species'] #Answer 1
print(users)
#users.isna().sum()
#data.isnull().sum()
#users.isnull().sum(axis=1)
users.isnull().values.sum()
users.isnull().sum() #Answer 2
users = users.drop(columns="Species")
print(users) #Answer 3
users.loc[10:30,"Petal Length"] = np.NaN
print(users[10:30]) #Answer 4
users=users.dropna(how='any')
print(users[10:30]) #Answer 5
users.reset_index() #Answer 6
print(users)
users = pd.read_csv('iris.data', delimiter = ",")
users.columns=['Petal Length','Petal Width','Sepal Length','Sepal Width','Species'] #Answer 1
print(users)
#group_by_class_flower=users.groupby("Species")['Petal Length','Sepal Length'].mean().mean()
users['Species'] groupby([users ])
print(group_by_class_flower)
# Out:
#   File "<ipython-input-1-8b66aff2bab2>", line 23
#     users['Species'] groupby([users ])
#                            ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import matplotlib.pyplot as plt
data=np.random.random(100)
plt.plot(data)
F=plt.figure("My Figure")
ax1=F.add_subplot(2,2,1)
ax2=F.add_subplot(2,2,2)
ax3=F.add_subplot(2,2,3)
ax4=F.add_subplot(2,2,4)
ax1.plot(np.random.randn(50).cumsum(),'k--')
ax2.hist(np.random.randn(100),bins=20,color='k',alpha=0.3)
ax3.scatter(np.arange(30),np.arange(30)+3*np.random.randn(30))
ax4.bar(['A','B','C','D','E'],np.random.randint(20,40,5))
F.show()
F.savefig('xyz.pdf',format='pdf')

# %% [markdown]
# **Lab 4**
#
# DataSet: https://bit.ly/2CudMVh
# 1. Assign it to a variable called drinks.
# 2. Which continent drinks more beer on average?
# 3. For each continent print the statistics for wine consumption.
# 4. Display the mean alcohol consumption per continent for every column.
# 5. Display the median alcohol consumption per continent for every column.
# 6. Display the mean, min and max values for spirit consumption.
