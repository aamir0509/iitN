# %% [markdown]
# **Lab 1**
#
# Using the dataset at https://bit.ly/2JIORnq
# 1. Assign it to a variable called users and use the 'user_id' as index
# 2. What is the age with least occurrence?
# 3. What is the mean age of users?
# 4. What is the most frequent occupation?

# %%
import pandas as pd
users=pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user",delimiter='|')
print(users)
min_age=users['age'].min()
print(min_age)
mean_age=users['age'].mean()
print(mean_age)
frequent_occ=users['occupation'].value_counts().head(1)
print(frequent_occ)
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]
# 7
# 34.05196182396607
# student    196
# Name: occupation, dtype: int64

# %% [markdown]
# **Lab 2**
#
# Dataset: https://bit.ly/2UUomN0
# 1. What is the price of each item?
# 2. What was the quantity of the most expensive item ordered?
# 3. How many times were a Veggie Salad Bowl ordered?
# 4. How many times people ordered more than one Canned Soda?

# %%
import pandas as pd
grocery=pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv",delimiter='\t')
print(grocery.head(0))
grocery[['item_name','item_price']].drop_duplicates()

# %%
import pandas as pd
grocery=pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv",delimiter='\t')
print(grocery.head(0))
grocery[['item_name','item_price']].drop_duplicates()

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv", sep = '\t', error_bad_lines = False)

df.dropna(axis = 0, how = 'any', inplace = True)

df['item_price'] = df['item_price'].str.replace('$','')

df['item_price'] = df['item_price'].astype(float)

#price = df.groupby('item_name').apply(lambda x : x['item_price'].sum())

df.drop_duplicates(keep='first', inplace=False)

with pd.option_context('display.max_rows', None, 'display.max_columns', None):  

     display(df)

 

maximum_price = df['item_price'].max()

Maximum_price

 

df = df.drop('choice_description', axis = 1)

maximum = df.groupby('item_name')[['item_price','quantity']].sum()

maximum['unit_price'] = (maximum['item_price']/maximum['quantity'])

#maximum

maximum_1 = maximum['unit_price'].max()

maximum_2 = maximum[maximum['unit_price'] >= maximum_1]

maximum_2

 

frequency = df[df["item_name"] == 'Veggie Salad Bowl'].sum()
display(frequency['quantity'])
# Out:
#       order_id  quantity              item_name  \
# 1            1         1                   Izze
# 2            1         1       Nantucket Nectar
# 4            2         2           Chicken Bowl
# 5            3         1           Chicken Bowl
# 7            4         1          Steak Burrito
# 8            4         1       Steak Soft Tacos
# 9            5         1          Steak Burrito
# 11           6         1   Chicken Crispy Tacos
# 12           6         1     Chicken Soft Tacos
# 13           7         1           Chicken Bowl
# 16           8         1        Chicken Burrito
# 17           9         1        Chicken Burrito
# 18           9         2            Canned Soda
# 19          10         1           Chicken Bowl
# 21          11         1       Barbacoa Burrito
# 22          11         1       Nantucket Nectar
# 23          12         1        Chicken Burrito
# 24          12         1                   Izze
# ...

# %%
json_str = '''
[{"name":'nitesh',"gender":'m',"age":32},{"name":'raghu',"gender":'m',age:33},{"name":'tanu',"gender":'f',"age":30}]
'''
import json
json.loads(json_str)
pd.read_json(json_str)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-6-f307df707272> in <module>()
#       3 '''
#       4 import json
# ----> 5 json.loads(json_str)
#       6 pd.read_json(json_str)
#
# /usr/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# /usr/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# ...

# %% [markdown]
# **Lab 3**
#
# Dataset: https://bit.ly/1N5br3h
# 1. Assign Columns for the dataset
# 2. Is there any missing value in the dataframe?
# 3. delete the column class
# 4. set the values of the rows 10 to 29 of the column 'petal_length' to NaN
# 5. Delete the rows that have NaN
# 6. Reset the index so it begins with 0 again
# 7. BONUS: Create & Answer your own question

# %%
import pandas as pd

df = pd.read_csv('https://bit.ly/1N5br3h', sep = ',', header = None)

df = df.set_axis(['sepal_length','sepal_width','petal_length','petal_width','class'], axis = 1, inplace = False)

df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
df.drop(['class'], axis = 1, inplace = True)
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
import numpy as np

df.iloc[10:30,-2] = np.NaN
df.head(30)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width
# 0            5.1          3.5           1.4          0.2
# 1            4.9          3.0           1.4          0.2
# 2            4.7          3.2           1.3          0.2
# 3            4.6          3.1           1.5          0.2
# 4            5.0          3.6           1.4          0.2
# 5            5.4          3.9           1.7          0.4
# 6            4.6          3.4           1.4          0.3
# 7            5.0          3.4           1.5          0.2
# 8            4.4          2.9           1.4          0.2
# 9            4.9          3.1           1.5          0.1
# 10           5.4          3.7           NaN          0.2
# 11           4.8          3.4           NaN          0.2
# 12           4.8          3.0           NaN          0.1
# 13           4.3          3.0           NaN          0.1
# 14           5.8          4.0           NaN          0.2
# ...

# %%
df.dropna(axis=0,inplace=True)
df.head(n=50)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width
# 0            5.1          3.5           1.4          0.2
# 1            4.9          3.0           1.4          0.2
# 2            4.7          3.2           1.3          0.2
# 3            4.6          3.1           1.5          0.2
# 4            5.0          3.6           1.4          0.2
# 5            5.4          3.9           1.7          0.4
# 6            4.6          3.4           1.4          0.3
# 7            5.0          3.4           1.5          0.2
# 8            4.4          2.9           1.4          0.2
# 9            4.9          3.1           1.5          0.1
# 30           4.8          3.1           1.6          0.2
# 31           5.4          3.4           1.5          0.4
# 32           5.2          4.1           1.5          0.1
# 33           5.5          4.2           1.4          0.2
# 34           4.9          3.1           1.5          0.1
# ...

# %%
df=df.reset_index()
del df['index']
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 125           6.7          3.0           5.2          2.3
# 126           6.3          2.5           5.0          1.9
# 127           6.5          3.0           5.2          2.0
# 128           6.2          3.4           5.4          2.3
# 129           5.9          3.0           5.1          1.8
#
# [130 rows x 4 columns]

# %% [markdown]
# **Lab 4**
#
# DataSet: https://bit.ly/2CudMVh
# 1. Assign it to a variable called drinks.
# 2. Which continent drinks more beer on average?
# 3. For each continent print the statistics for wine consumption.
# 4. Display the mean alcohol consumption per continent for every column.
# 5. Display the median alcohol consumption per continent for every column.
# 6. Display the mean, min and max values for spirit consumption.

# %%
import pandas as pd

 

drinks = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv", sep = ',')

drinks
# Out:
#          country  beer_servings  ...  total_litres_of_pure_alcohol  continent
# 0    Afghanistan              0  ...                           0.0         AS
# 1        Albania             89  ...                           4.9         EU
# 2        Algeria             25  ...                           0.7         AF
# 3        Andorra            245  ...                          12.4         EU
# 4         Angola            217  ...                           5.9         AF
# ..           ...            ...  ...                           ...        ...
# 188    Venezuela            333  ...                           7.7         SA
# 189      Vietnam            111  ...                           2.0         AS
# 190        Yemen              6  ...                           0.1         AS
# 191       Zambia             32  ...                           2.5         AF
# 192     Zimbabwe             64  ...                           4.7         AF
#
# [193 rows x 6 columns]

# %%
drinks_2 = drinks.groupby('continent').aggregate({'beer_servings': 'mean'})

drinks_2
# Out:
#            beer_servings
# continent
# AF             61.471698
# AS             37.045455
# EU            193.777778
# OC             89.687500
# SA            175.083333

# %%
drinks_3 = drinks.groupby('continent').aggregate({'wine_servings': ['mean','median','sum','var','std']})

drinks_3
# Out:
#           wine_servings
#                    mean median   sum          var        std
# continent
# AF            16.264151    2.0   862  1509.044267  38.846419
# AS             9.068182    1.0   399   469.460359  21.667034
# EU           142.222222  128.0  6400  9490.994949  97.421738
# OC            35.625000    8.5   570  4167.450000  64.555790
# SA            62.416667   12.0   749  7853.537879  88.620189

# %%
drinks_4 = drinks.groupby('continent').aggregate({'beer_servings':'mean','spirit_servings':'mean','wine_servings':'mean'})

drinks_4
# Out:
#            beer_servings  spirit_servings  wine_servings
# continent
# AF             61.471698        16.339623      16.264151
# AS             37.045455        60.840909       9.068182
# EU            193.777778       132.555556     142.222222
# OC             89.687500        58.437500      35.625000
# SA            175.083333       114.750000      62.416667

# %%
drinks_5 = drinks.groupby('continent').aggregate({'beer_servings':'median','spirit_servings':'median','wine_servings':'median'})

drinks_5
# Out:
#            beer_servings  spirit_servings  wine_servings
# continent
# AF                  32.0              3.0            2.0
# AS                  17.5             16.0            1.0
# EU                 219.0            122.0          128.0
# OC                  52.5             37.0            8.5
# SA                 162.5            108.5           12.0

# %%
drinks_6 = drinks.groupby('continent').aggregate({'spirit_servings':['mean','min','max']})

drinks_6
# Out:
#           spirit_servings
#                      mean min  max
# continent
# AF              16.339623   0  152
# AS              60.840909   0  326
# EU             132.555556   0  373
# OC              58.437500   0  254
# SA             114.750000  25  302

# %% [markdown]
# Matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt
data=np.random.randn(200)
plt.plot(data)

# %%
fig=plt.figure('figure1')
ax1=fig.add_subplot(2,2,1)
ax2=fig.add_subplot(2,2,2)
ax3=fig.add_subplot(2,2,3)
ax4=fig.add_subplot(2,2,4)
ax1.plot(np.random.randn(100).cumsum(),'k--')
ax2.hist(np.random.rand(100),bins=10,color='k',alpha=0.3)
fig.show()

# %% [markdown]
# https://matplotlib.org/
#
# https://github.com/justmarkham/python-data-analysis-workshop/blob/master/05-pandas.py

# %%
drinks.groupby('continent').beer_servings.mean().plot(kind='pie')

# %%
drinks.groupby('continent').beer_servings.mean().plot(kind='pie',autopct="%1.1f%%")

# %%
import matplotlib.pyplot as plt
drinks_3 = drinks.groupby('continent').aggregate({'beer_servings': 'mean'})
fig, ax = plt.subplots(figsize=(15,7))
plt.plot(drinks_3)
plt.show()

# %%
drinks_4 = drinks.groupby('continent').aggregate({'total_litres_of_pure_alcohol': 'mean'}).plot.line()
drinks_4

# %% [markdown]
# Plot pie chart of percentage cunsumption of wine in continent, explde max percentage.

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(10, 10))
plt.pie(drinks.groupby('continent').aggregate({'wine_servings': 'mean'}), autopct='%1.0f%%')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(10, 10))
plt.plot(drinks.groupby('continent').aggregate({'total_litres_of_pure_alcohol': 'mean'}))
plt.show()

# %%
labels=drinks.groupby('continent').mean()
labels.plot(kind='bar')

# %%
import pandas as pd
sprt=pd.read_excel("/content/fifa1.xlsx")
sprt
# Out:
#        Unnamed: 0      ID  ... GKReflexes  Release Clause
# 0               0  158023  ...        8.0       â‚¬226.5M
# 1               1   20801  ...       11.0       â‚¬127.1M
# 2               2  190871  ...       11.0       â‚¬228.1M
# 3               3  193080  ...       94.0       â‚¬138.6M
# 4               4  192985  ...       13.0       â‚¬196.4M
# ...           ...     ...  ...        ...             ...
# 18202       18202  238813  ...        9.0         â‚¬143K
# 18203       18203  243165  ...       12.0         â‚¬113K
# 18204       18204  241638  ...       13.0         â‚¬165K
# 18205       18205  246268  ...        9.0         â‚¬143K
# 18206       18206  246269  ...        9.0         â‚¬165K
#
# [18207 rows x 89 columns]

# %%
import pandas as pd
df = pd.read_excel('/content/fifa1.xlsx')
df.head()
# Out:
#    Unnamed: 0      ID  ... GKReflexes  Release Clause
# 0           0  158023  ...        8.0       â‚¬226.5M
# 1           1   20801  ...       11.0       â‚¬127.1M
# 2           2  190871  ...       11.0       â‚¬228.1M
# 3           3  193080  ...       94.0       â‚¬138.6M
# 4           4  192985  ...       13.0       â‚¬196.4M
#
# [5 rows x 89 columns]

# %%
df_drop_column = df.drop(['Unnamed: 0','Photo','Flag','Club Logo' ], axis = 1, inplace = True)
df.head()
# Out:
#        ID               Name  Age  ... GKPositioning  GKReflexes  Release Clause
# 0  158023           L. Messi   31  ...          14.0         8.0       â‚¬226.5M
# 1   20801  Cristiano Ronaldo   33  ...          14.0        11.0       â‚¬127.1M
# 2  190871          Neymar Jr   26  ...          15.0        11.0       â‚¬228.1M
# 3  193080             De Gea   27  ...          88.0        94.0       â‚¬138.6M
# 4  192985       K. De Bruyne   27  ...          10.0        13.0       â‚¬196.4M
#
# [5 rows x 85 columns]

# %%
df_describe = df.describe()
df_describe
# Out:
#                   ID           Age  ...  GKPositioning    GKReflexes
# count   18207.000000  18207.000000  ...   18159.000000  18159.000000
# mean   214298.338606     25.122206  ...      16.388898     16.710887
# std     29965.244204      4.669943  ...      17.034669     17.955119
# min        16.000000     16.000000  ...       1.000000      1.000000
# 25%    200315.500000     21.000000  ...       8.000000      8.000000
# 50%    221759.000000     25.000000  ...      11.000000     11.000000
# 75%    236529.500000     28.000000  ...      14.000000     14.000000
# max    246620.000000     45.000000  ...      90.000000     94.000000
#
# [8 rows x 43 columns]
